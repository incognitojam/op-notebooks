# %%
# %load_ext autoreload
# %autoreload 2

# %%
from vins import load_vins

vins = load_vins()
# vins = ['WF0NXXGCHNJR69712']
# Out:
# Loaded 1263 VINs (filter_comment=None, include_openpilot=False, skipped=80)
# Loaded AsBuilt data for 1263 VINs

# %%
import random

import pandas as pd

from asbuilt import AsBuiltData
from settings import VEHICLE_SETTINGS

pd.set_option('display.max_columns', None)

rows = []
for vin in ('WF0NXXGCHNJR69712', *random.sample(vins, 10)):
  abd = AsBuiltData.from_vin(vin)
  rows.append([vin, *map(lambda s: abd.get_setting_value(s), VEHICLE_SETTINGS)])

columns = [('', 'VIN'), *map(lambda s: (s.ecu.name, s.comment), VEHICLE_SETTINGS)]

df = pd.DataFrame(rows, columns=pd.MultiIndex.from_tuples(columns))
df
# Out:
#                       ImageProcessingModuleA                          \
#                   VIN                Vehicle   Enable ACC Enable TJA
# 0   WF0NXXGCHNJR69712           C519 (Focus)          Off        Off
# 1   1FADP3F23JL320684                Missing      Missing    Missing
# 2   1FM5K8FW0NNA11399        U625 (Explorer)  RadarFusion         On
# 3   2FMPK4J93PBA06358           CD539 (Edge)          Off        Off
# 4   3FA6P0HD4LR264457         Unknown (0xA8)    Undefined  Undefined
# 5   1FTFW1E57MKD06979         Unknown (0x00)    Undefined  Undefined
# 6   1FMSK8DH1LGB19569        U625 (Explorer)          Off        Off
# 7   1FMDE5DH4PLC18172         Unknown (0x4B)          Off        Off
# 8   2FMPK3G96KBB67135           CD539 (Edge)          Off        Off
# 9   1FMSK8FH4MGB36719        U625 (Explorer)  RadarFusion         On
# 10  3FTTW8F92PRA08417         Unknown (0x4D)          Off        Off
#
#    AntiLockBrakeSystem                                      \
#      Wheel base preset   Steering Gear Cruise Control Mode
# 0             Reserved       EPAS 21:1              Normal
# 1              Missing         Missing             Missing
# 2             Reserved        Reserved      Unknown (0x01)
# 3                122in       EPAS 17:1            Adaptive
# 4                141in  Unknown (0x03)            Adaptive
# 5                145in       EPAS 17:1              Normal
# 6             Reserved       EPAS 17:1      Unknown (0x01)
# 7                122in        Reserved            Adaptive
# 8                141in       EPAS 17:1            Adaptive
# 9             Reserved       EPAS 17:1      Unknown (0x01)
# 10            Reserved        Reserved              Normal
#
#                                             AccessoryProtocolInterfaceModule  \
#    Collision Mitigation by Braking (CMbB) Steering Wheel Angle Sensor (SWAS)
# 0                                 Without                           Absolute
# 1                                 Missing                           Relative
# 2                                 Without                           Absolute
# 3                                    With                           Absolute
# 4                                 Missing                           Absolute
# 5                                    With                           Absolute
# 6                                 Without                           Absolute
# 7                                    With                           Absolute
# 8                                    With                           Absolute
# 9                                 Without                           Absolute
# 10                                Without                            Missing
#
#                                                                   \
#    Brand Identification Hybrid (HEV) Transmission Type Fuel Type
# 0                  Ford           No            Manual    Diesel
# 1              Reserved           No         Automatic    Diesel
# 2                  Ford          Yes         Automatic  Gasoline
# 3                  Ford           No         Automatic  Gasoline
# 4                  Ford           No         Automatic  Gasoline
# 5                  Ford           No         Automatic  Gasoline
# 6                  Ford           No         Automatic  Gasoline
# 7                  Ford           No         Automatic  Gasoline
# 8                  Ford           No         Automatic  Gasoline
# 9                  Ford           No         Automatic  Gasoline
# 10              Missing      Missing           Missing   Missing
#
#                                                                        \
#    Plug-in Hybrid (PHEV) Common Global Electrical Architecture (CGEA)
# 0                     No                                     CGEA 1.3
# 1                     No                                      Missing
# 2                     No                                     CGEA 1.3
# 3                     No                            CGEA 1.2 or C1MCA
# 4                     No                                     CGEA 1.3
# 5                     No                            CGEA 1.2 or C1MCA
# 6                     No                                     CGEA 1.3
# 7                     No                            CGEA 1.2 or C1MCA
# 8                     No                                     CGEA 1.3
# 9                     No                                     CGEA 1.3
# 10               Missing                                      Missing
#
#                                                                                \
#    Heated Windshield Country Code (First Letter) Country Code (Second Letter)
# 0                Yes                           U                            K
# 1            Missing              Unknown (0x04)                            U
# 2                 No                           U                            S
# 3                 No              Unknown (0x04)               Unknown (0x02)
# 4                 No                           U                            S
# 5                 No              Unknown (0x06)               Unknown (0x12)
# 6                 No                           U                            S
# 7                 No              Unknown (0x04)               Unknown (0x12)
# 8                 No                           U                            S
# 9                 No                           U                            S
# 10           Missing                     Missing                      Missing
#
#                                                                         \
#      Vehicle Style GPS Antenna Location/Mount Type    Electric Vehicle
# 0            Focus         Roof Mount (UK Default)  Non-HEV, BEV, PHEV
# 1             None         Roof Mount (UK Default)  Non-HEV, BEV, PHEV
# 2          SUV/CUV         Roof Mount (UK Default)     U625 (Explorer)
# 3   Unknown (0x8A)                  Unknown (0x05)      Unknown (0x53)
# 4            Sedan         Roof Mount (UK Default)  Non-HEV, BEV, PHEV
# 5            Focus                  Unknown (0x05)      Unknown (0x53)
# 6          SUV/CUV         Roof Mount (UK Default)     U625 (Explorer)
# 7           Fiesta                  Unknown (0x05)      Unknown (0x53)
# 8          SUV/CUV         Roof Mount (UK Default)  Non-HEV, BEV, PHEV
# 9          SUV/CUV         Roof Mount (UK Default)     U625 (Explorer)
# 10         Missing                         Missing             Missing
#
#                                                                           \
#    Drivetrain Type Bluetooth Vehicle Nameplate ID Front Track Rear Track
# 0              FWD                     Ford Focus    64.05 in   64.05 in
# 1              FWD                        Missing     Missing    Missing
# 2              AWD                  Ford Explorer    68.45 in   68.20 in
# 3       Dually 2WD                           SYNC     0.06 in  122.88 in
# 4              FWD                    Ford Fusion    68.50 in   68.20 in
# 5              4WD                           SYNC     2.62 in    0.00 in
# 6              AWD                  Ford Explorer    68.45 in   68.20 in
# 7   Unknown (0x0C)                           SYNC     2.62 in  122.88 in
# 8              FWD                      Ford Edge    70.75 in   70.67 in
# 9              AWD                  Ford Explorer    68.45 in   68.20 in
# 10         Missing                        Missing     Missing    Missing
#
#                                                             \
#    Wheel Base Vehicle Weight Distance from IP to Rear Axle
# 0     0.38 in        1100 kg                Unknown (0x00)
# 1     Missing        Missing                       Missing
# 2     0.46 in        2900 kg                Unknown (0x00)
# 3     0.00 in        2500 kg                Unknown (0x00)
# 4     0.43 in         700 kg                Unknown (0x00)
# 5     0.00 in        3200 kg                Unknown (0x00)
# 6     0.46 in        2600 kg                Unknown (0x00)
# 7     0.00 in        2700 kg                Unknown (0x00)
# 8     0.43 in         800 kg                Unknown (0x00)
# 9     0.46 in        2600 kg                Unknown (0x00)
# 10    Missing        Missing                       Missing
#
#                                                                               \
#    Distance from IP to Rear Axle (cont.)  ACC Menu Forward Collision Warning
# 0                         Unknown (0x61)   Enabled                      None
# 1                                Missing   Missing                   Missing
# 2                         Unknown (0x76)   Enabled                       FCW
# 3                         Unknown (0x80)  Disabled                      None
# 4                         Unknown (0x6A)  Disabled                      None
# 5                         Unknown (0xC8)  Disabled                       FCW
# 6                         Unknown (0x76)  Disabled                       FCW
# 7                         Unknown (0x83)  Disabled                       FCW
# 8                         Unknown (0x70)  Disabled                      None
# 9                         Unknown (0x76)   Enabled                       FCW
# 10                               Missing   Missing                   Missing
#
#                                                         \
#     FCW Menu FCW Braking Evasive Steering Assist (ESA)
# 0    Enabled     Enabled                       Enabled
# 1    Missing     Missing                       Missing
# 2   Disabled     Enabled                       Enabled
# 3   Disabled    Disabled                      Disabled
# 4   Disabled    Disabled                      Disabled
# 5    Enabled     Enabled                      Disabled
# 6   Disabled     Enabled                      Disabled
# 7    Enabled     Enabled                      Disabled
# 8   Disabled    Disabled                      Disabled
# 9   Disabled     Enabled                       Enabled
# 10   Missing     Missing                       Missing
#
#                                                                 \
#    Lane Change Assist (LCA) Lane Keeping Sensitivity  ACC Mode
# 0                   Enabled                  Enabled   Enabled
# 1                   Missing                  Missing   Missing
# 2                   Enabled                 Disabled   Enabled
# 3                  Disabled                 Disabled  Disabled
# 4                  Disabled                 Disabled  Disabled
# 5                   Enabled                 Disabled  Disabled
# 6                   Enabled                 Disabled  Disabled
# 7                   Enabled                 Disabled  Disabled
# 8                  Disabled                 Disabled  Disabled
# 9                   Enabled                 Disabled   Enabled
# 10                  Missing                  Missing   Missing
#
#
#       Lane Assist NCAP Aid Lane Assist NCAP Alert
# 0   Off, Reduced, Enhanced      High, Normal, Low
# 1                  Missing                Missing
# 2                 Disabled               Disabled
# 3                 Disabled               Disabled
# 4                 Disabled               Disabled
# 5                 Disabled               Disabled
# 6                 Disabled               Disabled
# 7                 Disabled               Disabled
# 8                 Disabled               Disabled
# 9                 Disabled               Disabled
# 10                 Missing                Missing
