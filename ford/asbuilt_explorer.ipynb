# %%
# %load_ext autoreload
# %autoreload 2

# %%
from vins import load_vins

vins = load_vins()
# vins = ['WF0NXXGCHNJR69712']
# Out:
# Loaded 1263 VINs (filter_comment=None, include_openpilot=False, skipped=80)
# Loaded AsBuilt data for 1263 VINs

# %%
import random

import pandas as pd

from asbuilt import AsBuiltData
from settings import VEHICLE_SETTINGS

pd.set_option('display.max_columns', None)

rows = []
for vin in ('WF0NXXGCHNJR69712', *random.sample(vins, 5)):
  abd = AsBuiltData.from_vin(vin)
  rows.append([vin, *map(lambda s: abd.get_setting_value(s), VEHICLE_SETTINGS)])

columns = [('', 'VIN'), *map(lambda s: (s.ecu.name, s.comment), VEHICLE_SETTINGS)]

df = pd.DataFrame(rows, columns=pd.MultiIndex.from_tuples(columns))
df
# Out:
#                      ImageProcessingModuleA            AntiLockBrakeSystem  \
#                  VIN             Enable ACC Enable TJA   Wheel base preset
# 0  WF0NXXGCHNJR69712                    Off        Off            Reserved
# 1  1FM5K8GC3PGB77377            RadarFusion         On            Reserved
# 2  1FMCU0KZ3NUA24995            RadarFusion         On            Reserved
# 3  1FTFW1EDXPFC77997         Unknown (0x03)  Undefined               145in
# 4  1FM5K8FW8MNA12198            RadarFusion         On            Reserved
# 5  1FMCU0BZ9MUA39421                    Off        Off            Reserved
#
#                                                                             \
#   Steering Gear Cruise Control Mode Collision Mitigation by Braking (CMbB)
# 0     EPAS 21:1              Normal                                Without
# 1     EPAS 17:1      Unknown (0x01)                                Without
# 2     EPAS 17:1      Unknown (0x01)                                Without
# 3     EPAS 17:1              Normal                                   With
# 4      Reserved      Unknown (0x01)                                Without
# 5     EPAS 17:1      Unknown (0x01)                                Without
#
#     AccessoryProtocolInterfaceModule                                    \
#   Steering Wheel Angle Sensor (SWAS) Brand Identification Hybrid (HEV)
# 0                           Absolute                 Ford           No
# 1                           Absolute                 Ford           No
# 2                           Absolute                 Ford           No
# 3                           Absolute              Lincoln          Yes
# 4                           Absolute                 Ford          Yes
# 5                           Absolute                 Ford          Yes
#
#                                                      \
#   Transmission Type Fuel Type Plug-in Hybrid (PHEV)
# 0            Manual    Diesel                    No
# 1         Automatic  Gasoline                    No
# 2         Automatic       CNG                   Yes
# 3         Automatic  Gasoline                    No
# 4         Automatic  Gasoline                    No
# 5         Automatic  Gasoline                    No
#
#                                                                   \
#   Common Global Electrical Architecture (CGEA) Heated Windshield
# 0                                     CGEA 1.3               Yes
# 1                                     CGEA 1.3                No
# 2                                     CGEA 1.3                No
# 3                                     CGEA 1.3                No
# 4                                     CGEA 1.3                No
# 5                                     CGEA 1.3                No
#
#                                                                           \
#   Country Code (First Letter) Country Code (Second Letter) Vehicle Style
# 0                           U                            K         Focus
# 1                           U                            S       SUV/CUV
# 2                           U                            S       SUV/CUV
# 3              Unknown (0x86)               Unknown (0x16)        Fiesta
# 4                           U                            S       SUV/CUV
# 5                           U                            S       SUV/CUV
#
#                                                                         \
#   GPS Antenna Location/Mount Type     Electric Vehicle Drivetrain Type
# 0         Roof Mount (UK Default)   Non-HEV, BEV, PHEV             FWD
# 1         Roof Mount (UK Default)      U625 (Explorer)             AWD
# 2         Roof Mount (UK Default)  CX482 (Escape/Kuga)             FWD
# 3                  Unknown (0x05)       Unknown (0x53)             4WD
# 4         Roof Mount (UK Default)      U625 (Explorer)             AWD
# 5         Roof Mount (UK Default)  CX482 (Escape/Kuga)             FWD
#
#                                                                       \
#   Bluetooth Vehicle Nameplate ID       Front Track        Rear Track
# 0                     Ford Focus  Unknown (0x1905)  Unknown (0x1905)
# 1                  Ford Explorer  Unknown (0x1ABD)  Unknown (0x1AA4)
# 2                    Ford Escape  Unknown (0x1806)  Unknown (0x1810)
# 3                           SYNC  Unknown (0x2186)   Unknown (0x400)
# 4                  Ford Explorer  Unknown (0x1ABD)  Unknown (0x1AA4)
# 5                    Ford Escape  Unknown (0x1806)  Unknown (0x1810)
#
#                                                                  \
#        Wheel Base  Vehicle Weight Distance from IP to Rear Axle
# 0  Unknown (0x26)  Unknown (0x0B)                Unknown (0x00)
# 1  Unknown (0x2E)  Unknown (0x1B)                Unknown (0x00)
# 2  Unknown (0x29)  Unknown (0x16)                Unknown (0x00)
# 3  Unknown (0x00)  Unknown (0x21)                Unknown (0x00)
# 4  Unknown (0x2E)  Unknown (0x1D)                Unknown (0x00)
# 5  Unknown (0x29)  Unknown (0x15)                Unknown (0x00)
#
#                                                                              \
#   Distance from IP to Rear Axle (cont.)  ACC Menu Forward Collision Warning
# 0                        Unknown (0x61)   Enabled                      None
# 1                        Unknown (0x76)   Enabled                       FCW
# 2                        Unknown (0x88)   Enabled                       FCW
# 3                        Unknown (0xC8)   Enabled                       FCW
# 4                        Unknown (0x76)   Enabled                       FCW
# 5                        Unknown (0x88)  Disabled                       FCW
#
#                                                        \
#    FCW Menu FCW Braking Evasive Steering Assist (ESA)
# 0   Enabled     Enabled                       Enabled
# 1  Disabled     Enabled                       Enabled
# 2  Disabled     Enabled                       Enabled
# 3   Enabled     Enabled                       Enabled
# 4  Disabled     Enabled                       Enabled
# 5  Disabled     Enabled                      Disabled
#
#                                                                \
#   Lane Change Assist (LCA) Lane Keeping Sensitivity  ACC Mode
# 0                  Enabled                  Enabled   Enabled
# 1                  Enabled                 Disabled   Enabled
# 2                  Enabled                 Disabled   Enabled
# 3                  Enabled                 Disabled   Enabled
# 4                  Enabled                 Disabled   Enabled
# 5                  Enabled                 Disabled  Disabled
#
#
#      Lane Assist NCAP Aid Lane Assist NCAP Alert
# 0  Off, Reduced, Enhanced      High, Normal, Low
# 1                Disabled               Disabled
# 2                Disabled               Disabled
# 3                Disabled               Disabled
# 4                Disabled               Disabled
# 5                Disabled               Disabled
