# %%
from tqdm.contrib.concurrent import process_map

from notebooks.ford.asbuilt import AsBuiltData
from notebooks.ford.decode import search, print_breakdown


df_nhtsa = await search(
  min_model_year=2019,
  include_openpilot=True,
  skip_missing_asbuilt=True,
)

# pre-load asbuilt
process_map(AsBuiltData.from_vin, df_nhtsa['VIN'].unique(), desc='Loading AsBuilt Data', chunksize=100)

print()
print_breakdown(df_nhtsa, include_model_year=False)
# Out:
# Loaded 36764 VINs (filter_comment=None, include_openpilot=True, skipped=163, missing_asbuilt=0)
# Downloading NHTSA data: 100%|██████████| 36764/36764 [00:02<00:00, 14248.77it/s]
# Loading AsBuilt Data:   0%|          | 0/32332 [00:00<?, ?it/s]
# Model
#                       2
# Aviator            1107
# Bronco              996
# Bronco Sport       1500
# Continental          23
# Corsair             986
# Ecosport            322
# Edge               2450
# Escape             3133
# Expedition          725
# Expedition MAX      629
# Explorer           2960
# F-150              6926
# F-250              1500
# F-350              1034
# F-450               196
# F-550                 1
# Fiesta              147
# Flex                137
# Fusion              908
# GT                    3
# MKC                  55
# MKT                   7
# MKZ                 100
# Maverick            994
# Mustang             871
# Mustang Mach-E      839
# Nautilus           1169
# Navigator           303
# Navigator L         230
# Ranger              533
# Taurus               40
# Transit            1166
# Transit Connect     340
# dtype: int64

# %%
import pandas as pd

from notebooks.ford.platforms import find_openpilot_platform
from notebooks.ford.settings import VehicleSetting, VehicleSettings


parameters = {
  'Wheelbase (ABS)': [VehicleSettings.abs_wheel_base],
  'Wheelbase (APIM)': [VehicleSettings.apim_wheel_base, VehicleSettings.apim_sync4_wheel_base],
  'Wheelbase (IPMA)': [VehicleSettings.ipma_vehicle_cfg_wheelbase],
  'Payload (ABS)': [VehicleSettings.abs_payload],
  'Weight (APIM)': [VehicleSettings.apim_vehicle_weight, VehicleSettings.apim_sync4_vehicle_weight],
  'Steer Ratio (ABS)': [VehicleSettings.abs_steering_gear],
  'Steer Ratio (APIM)': [VehicleSettings.apim_sync4_steering_gear_ratio],
  'Steer Ratio (IPMA)': [VehicleSettings.ipma_vehicle_cfg_steering_ratio],
}

def get_parameter(asbuilt: AsBuiltData, settings: list[VehicleSetting]):
  for setting in settings:
    if not asbuilt.is_present(setting.ecu):
      continue
    return asbuilt.get_setting_value(setting)
  return 'Missing ECU'

def get_parameters(row):
  asbuilt = AsBuiltData.from_vin(row['VIN'])
  return pd.Series({k: get_parameter(asbuilt, v) for k, v in parameters.items()})


df_cars = df_nhtsa[['VIN', 'Make', 'Model', 'ModelYear', 'Trim', 'Series', 'ElectrificationLevel']].copy()

df_cars['CarName'] = df_cars['Make'] + ' ' + df_cars['Model'] + ' ' + df_cars['ModelYear'].astype(str)
df_cars['CarInfoPlatform'] = df_cars['CarName'].apply(find_openpilot_platform)

df_cars = df_cars.join(df_cars.apply(get_parameters, axis=1))
df_cars.head()
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /mnt/c/Users/camer/AppData/Local/Programs/Microsoft VS Code
#                  VIN  Make     Model  ModelYear Trim     Series  \
# 0  1FMCU9GN2PUB45529  FORD    Escape       2023          Active
# 1  3FTTW8E99NRA19557  FORD  Maverick       2022       SUPERCREW
# 2  1FTEW1E5XLKD78382  FORD     F-150       2020
# 3  1FMCU9H92NUA40763  FORD    Escape       2022             SEL
# 4  1FMCU9BZ0NUA42388  FORD    Escape       2022              SE
#
#   ElectrificationLevel             CarName        CarInfoPlatform  \
# 0                  ICE    FORD Escape 2023                   None
# 1                  ICE  FORD Maverick 2022  FORD MAVERICK 1ST GEN
# 2                  ICE     FORD F-150 2020                   None
# 3                  ICE    FORD Escape 2022    FORD ESCAPE 4TH GEN
# 4                 FHEV    FORD Escape 2022    FORD ESCAPE 4TH GEN
#
#   Wheelbase (ABS) Wheelbase (APIM) Wheelbase (IPMA)  \
# 0  Unknown (0x00)           2.71 m           2.71 m
# 1  Unknown (0x00)      Missing ECU      Missing ECU
# 2          3.68 m           3.68 m      Missing ECU
# 3  Unknown (0x00)           2.69 m      Missing ECU
# 4  Unknown (0x00)           2.69 m      Missing ECU
#
#                 Payload (ABS) Weight (APIM) Steer Ratio (ABS)  \
# 0                Base Payload       2000 kg         EPAS 17:1
# 1         Mid Payload Upgrade   Missing ECU    Unknown (0x00)
# 2                Base Payload       7000 kg         EPAS 17:1
# 3                Base Payload       2100 kg         EPAS 17:1
# 4  Heavy Duty Payload Upgrade       2100 kg         EPAS 17:1
#
#   Steer Ratio (APIM) Steer Ratio (IPMA)
# 0               17:1              15.52
# 1        Missing ECU        Missing ECU
# 2        Missing ECU        Missing ECU
# 3        Missing ECU        Missing ECU
# 4        Missing ECU        Missing ECU

# %%
df_parameters = df_cars[~df_cars['CarInfoPlatform'].isna()][['CarInfoPlatform', 'ElectrificationLevel', *parameters.keys()]].copy()

# for parameter in parameters.keys():
#   df_parameters[parameter] = df_parameters[parameter].astype('category')

rows = []
for group in df_parameters.groupby(['CarInfoPlatform', 'ElectrificationLevel', 'Payload (ABS)'], as_index=True):
  print(group[0])
  for parameter in parameters.keys():
    if parameter == 'Payload (ABS)':
      continue
    print(group[1][parameter].value_counts())
    print()
  print()
  print()
  row = dict({'CarInfoPlatform': group[0][0], 'ElectrificationLevel': group[0][1], 'Payload (ABS)': group[0][2]}, **{parameter: sorted(group[1][parameter].unique()) for parameter in parameters.keys() if parameter != 'Payload (ABS)'})
  rows.append(row)

df_platform_parameters = pd.DataFrame(rows)
df_platform_parameters.set_index(['CarInfoPlatform', 'ElectrificationLevel', 'Payload (ABS)'], inplace=True)
df_platform_parameters
# Out:
# (<CAR.BRONCO_SPORT_MK1: 'FORD BRONCO SPORT 1ST GEN'>, 'ICE', 'Base Payload')
# Wheelbase (ABS)
# Unknown (0x00)    787
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 2.67 m    786
# 0.00 m      1
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    787
# Name: count, dtype: int64
#
# Weight (APIM)
# 2100 kg    786
# 0 kg         1
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    787
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    787
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    787
# Name: count, dtype: int64
#
#
#
# (<CAR.BRONCO_SPORT_MK1: 'FORD BRONCO SPORT 1ST GEN'>, 'ICE', 'Mid Payload Upgrade')
# Wheelbase (ABS)
# Unknown (0x00)    143
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 2.67 m    141
# 2.69 m      2
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    143
# Name: count, dtype: int64
#
# Weight (APIM)
# 2100 kg    143
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    143
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    143
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    143
# Name: count, dtype: int64
#
#
#
# (<CAR.ESCAPE_MK4: 'FORD ESCAPE 4TH GEN'>, 'FHEV', 'Heavy Duty Payload Upgrade')
# Wheelbase (ABS)
# Unknown (0x00)    305
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 2.69 m    305
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    305
# Name: count, dtype: int64
#
# Weight (APIM)
# 2100 kg    240
# 2000 kg     65
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    305
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    305
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    305
# Name: count, dtype: int64
#
#
#
# (<CAR.ESCAPE_MK4: 'FORD ESCAPE 4TH GEN'>, 'ICE', 'Base Payload')
# Wheelbase (ABS)
# Unknown (0x00)    1800
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 2.69 m    1799
# 3.02 m       1
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    1800
# Name: count, dtype: int64
#
# Weight (APIM)
# 2000 kg    1081
# 1900 kg     508
# 2100 kg     210
# 2700 kg       1
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    1800
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    1800
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    1800
# Name: count, dtype: int64
#
#
#
# (<CAR.ESCAPE_MK4: 'FORD ESCAPE 4TH GEN'>, 'PHEV', 'Unknown (0x05)')
# Wheelbase (ABS)
# Unknown (0x00)    59
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 2.69 m    59
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    59
# Name: count, dtype: int64
#
# Weight (APIM)
# 2200 kg    59
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    59
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    59
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    59
# Name: count, dtype: int64
#
#
#
# (<CAR.EXPLORER_MK6: 'FORD EXPLORER 6TH GEN'>, 'HEV', 'Unknown (0x04)')
# Wheelbase (ABS)
# Unknown (0x00)    151
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 3.02 m    151
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    151
# Name: count, dtype: int64
#
# Weight (APIM)
# 2900 kg    151
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# Unknown (0x00)    151
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    151
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    151
# Name: count, dtype: int64
#
#
#
# (<CAR.EXPLORER_MK6: 'FORD EXPLORER 6TH GEN'>, 'ICE', 'Base Payload')
# Wheelbase (ABS)
# Unknown (0x00)    4
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 3.02 m    4
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    4
# Name: count, dtype: int64
#
# Weight (APIM)
# 2600 kg    4
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    4
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    4
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    4
# Name: count, dtype: int64
#
#
#
# (<CAR.EXPLORER_MK6: 'FORD EXPLORER 6TH GEN'>, 'ICE', 'Heavy Duty Payload Upgrade')
# Wheelbase (ABS)
# Unknown (0x00)    1126
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 3.02 m    1125
# 2.85 m       1
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    1126
# Name: count, dtype: int64
#
# Weight (APIM)
# 2900 kg    557
# 2700 kg    473
# 2800 kg     93
# 2600 kg      2
# 1200 kg      1
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    1126
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    1126
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    1126
# Name: count, dtype: int64
#
#
#
# (<CAR.EXPLORER_MK6: 'FORD EXPLORER 6TH GEN'>, 'ICE', 'Mid Payload Upgrade')
# Wheelbase (ABS)
# Unknown (0x00)    1960
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 3.02 m    1956
# 2.85 m       1
# 2.72 m       1
# 0.00 m       1
# 4.06 m       1
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    1960
# Name: count, dtype: int64
#
# Weight (APIM)
# 2600 kg    1956
# 700 kg        1
# 1600 kg       1
# 1000 kg       1
# 5200 kg       1
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    1960
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    1960
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    1960
# Name: count, dtype: int64
#
#
#
# (<CAR.EXPLORER_MK6: 'FORD EXPLORER 6TH GEN'>, 'PHEV', 'Unknown (0x05)')
# Wheelbase (ABS)
# Unknown (0x00)    80
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 3.02 m    80
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    80
# Name: count, dtype: int64
#
# Weight (APIM)
# 3200 kg    80
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# Unknown (0x00)    80
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    80
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    80
# Name: count, dtype: int64
#
#
#
# (<CAR.F_150_MK14: 'FORD F-150 14TH GEN'>, 'BEV', 'Base Payload')
# Wheelbase (ABS)
# 3.10 m    218
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 3.68 m    218
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# 3.70 m    218
# Name: count, dtype: int64
#
# Weight (APIM)
# 3700 kg    98
# 3900 kg    89
# 3800 kg    31
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    218
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# 17:1    218
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# 18.0    218
# Name: count, dtype: int64
#
#
#
# (<CAR.F_150_MK14: 'FORD F-150 14TH GEN'>, 'HEV', 'Base Payload')
# Wheelbase (ABS)
# 3.68 m    222
# 3.99 m     26
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 3.68 m    222
# 3.99 m     26
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# 3.68 m    222
# 3.99 m     26
# Name: count, dtype: int64
#
# Weight (APIM)
# 3300 kg    248
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    248
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# 17:1    248
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# 18.0    248
# Name: count, dtype: int64
#
#
#
# (<CAR.F_150_MK14: 'FORD F-150 14TH GEN'>, 'ICE', 'Base Payload')
# Wheelbase (ABS)
# 3.68 m    1003
# 3.99 m      67
# 3.10 m      10
# 3.58 m       6
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 3.68 m    1002
# 3.99 m      66
# 3.11 m      10
# 3.58 m       6
# 0.00 m       2
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# 3.68 m    817
# 3.70 m    186
# 3.99 m     67
# 3.11 m     10
# 3.58 m      6
# Name: count, dtype: int64
#
# Weight (APIM)
# 3200 kg     685
# 3000 kg     147
# 3300 kg      96
# 2900 kg      92
# 3100 kg      34
# 3400 kg      17
# 2800 kg      10
# 2700 kg       3
# 19200 kg      2
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    1070
# EPAS 21:1      16
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# 17:1    1070
# 20:1      16
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# 18.0    1070
# 21.0      16
# Name: count, dtype: int64
#
#
#
# (<CAR.F_150_MK14: 'FORD F-150 14TH GEN'>, 'ICE', 'Heavy Duty Payload Upgrade')
# Wheelbase (ABS)
# 3.58 m    1
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 3.58 m    1
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# 3.58 m    1
# Name: count, dtype: int64
#
# Weight (APIM)
# 3600 kg    1
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 21:1    1
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# 20:1    1
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# 21.0    1
# Name: count, dtype: int64
#
#
#
# (<CAR.F_150_MK14: 'FORD F-150 14TH GEN'>, 'ICE', 'Mid Payload Upgrade')
# Wheelbase (ABS)
# 3.68 m    3
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 3.68 m    3
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# 3.68 m    3
# Name: count, dtype: int64
#
# Weight (APIM)
# 3200 kg    2
# 3000 kg    1
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    3
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# 17:1    3
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# 18.0    3
# Name: count, dtype: int64
#
#
#
# (<CAR.MAVERICK_MK1: 'FORD MAVERICK 1ST GEN'>, 'HEV', 'Base Payload')
# Wheelbase (ABS)
# Unknown (0x00)    200
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# Missing ECU    200
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    200
# Name: count, dtype: int64
#
# Weight (APIM)
# Missing ECU    200
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# Unknown (0x00)    200
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    200
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    200
# Name: count, dtype: int64
#
#
#
# (<CAR.MAVERICK_MK1: 'FORD MAVERICK 1ST GEN'>, 'HEV', 'Mid Payload Upgrade')
# Wheelbase (ABS)
# Unknown (0x00)    70
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 3.07 m         44
# Missing ECU    26
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    70
# Name: count, dtype: int64
#
# Weight (APIM)
# 2400 kg        44
# Missing ECU    26
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# Unknown (0x00)    70
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    70
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    70
# Name: count, dtype: int64
#
#
#
# (<CAR.MAVERICK_MK1: 'FORD MAVERICK 1ST GEN'>, 'ICE', 'Base Payload')
# Wheelbase (ABS)
# Unknown (0x00)    367
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# Missing ECU    367
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    367
# Name: count, dtype: int64
#
# Weight (APIM)
# Missing ECU    367
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# Unknown (0x00)    367
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    367
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    367
# Name: count, dtype: int64
#
#
#
# (<CAR.MAVERICK_MK1: 'FORD MAVERICK 1ST GEN'>, 'ICE', 'Mid Payload Upgrade')
# Wheelbase (ABS)
# Unknown (0x00)    151
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 3.07 m         101
# Missing ECU     50
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# Missing ECU    151
# Name: count, dtype: int64
#
# Weight (APIM)
# 2400 kg        85
# Missing ECU    50
# 2300 kg        16
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# Unknown (0x00)    151
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# Missing ECU    151
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# Missing ECU    151
# Name: count, dtype: int64
#
#
#
# (<CAR.MUSTANG_MACH_E_MK1: 'FORD MUSTANG MACH-E 1ST GEN'>, 'BEV', 'Base Payload')
# Wheelbase (ABS)
# Unknown (0x00)    563
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 2.98 m    563
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# 2.98 m    563
# Name: count, dtype: int64
#
# Weight (APIM)
# 2500 kg    269
# 2600 kg    183
# 2400 kg    111
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    563
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# 17:1    563
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# 14.6    563
# Name: count, dtype: int64
#
#
#
# (<CAR.MUSTANG_MACH_E_MK1: 'FORD MUSTANG MACH-E 1ST GEN'>, 'BEV', 'Mid Payload Upgrade')
# Wheelbase (ABS)
# Unknown (0x00)    250
# Name: count, dtype: int64
#
# Wheelbase (APIM)
# 2.98 m    250
# Name: count, dtype: int64
#
# Wheelbase (IPMA)
# 2.98 m    250
# Name: count, dtype: int64
#
# Weight (APIM)
# 2700 kg    250
# Name: count, dtype: int64
#
# Steer Ratio (ABS)
# EPAS 17:1    250
# Name: count, dtype: int64
#
# Steer Ratio (APIM)
# 17:1    250
# Name: count, dtype: int64
#
# Steer Ratio (IPMA)
# 14.6    250
# Name: count, dtype: int64
#                                                                                               Wheelbase (ABS)  \
# CarInfoPlatform             ElectrificationLevel Payload (ABS)
# FORD BRONCO SPORT 1ST GEN   ICE                  Base Payload                                [Unknown (0x00)]
#                                                  Mid Payload Upgrade                         [Unknown (0x00)]
# FORD ESCAPE 4TH GEN         FHEV                 Heavy Duty Payload Upgrade                  [Unknown (0x00)]
#                             ICE                  Base Payload                                [Unknown (0x00)]
#                             PHEV                 Unknown (0x05)                              [Unknown (0x00)]
# FORD EXPLORER 6TH GEN       HEV                  Unknown (0x04)                              [Unknown (0x00)]
#                             ICE                  Base Payload                                [Unknown (0x00)]
#                                                  Heavy Duty Payload Upgrade                  [Unknown (0x00)]
#                                                  Mid Payload Upgrade                         [Unknown (0x00)]
#                             PHEV                 Unknown (0x05)                              [Unknown (0x00)]
# FORD F-150 14TH GEN         BEV                  Base Payload                                        [3.10 m]
#                             HEV                  Base Payload                                [3.68 m, 3.99 m]
#                             ICE                  Base Payload                [3.10 m, 3.58 m, 3.68 m, 3.99 m]
#                                                  Heavy Duty Payload Upgrade                          [3.58 m]
#                                                  Mid Payload Upgrade                                 [3.68 m]
# FORD MAVERICK 1ST GEN       HEV                  Base Payload                                [Unknown (0x00)]
#                                                  Mid Payload Upgrade                         [Unknown (0x00)]
#                             ICE                  Base Payload                                [Unknown (0x00)]
#                                                  Mid Payload Upgrade                         [Unknown (0x00)]
# FORD MUSTANG MACH-E 1ST GEN BEV                  Base Payload                                [Unknown (0x00)]
#                                                  Mid Payload Upgrade                         [Unknown (0x00)]
#
#                                                                                                      Wheelbase (APIM)  \
# CarInfoPlatform             ElectrificationLevel Payload (ABS)
# FORD BRONCO SPORT 1ST GEN   ICE                  Base Payload                                        [0.00 m, 2.67 m]
#                                                  Mid Payload Upgrade                                 [2.67 m, 2.69 m]
# FORD ESCAPE 4TH GEN         FHEV                 Heavy Duty Payload Upgrade                                  [2.69 m]
#                             ICE                  Base Payload                                        [2.69 m, 3.02 m]
#                             PHEV                 Unknown (0x05)                                              [2.69 m]
# FORD EXPLORER 6TH GEN       HEV                  Unknown (0x04)                                              [3.02 m]
#                             ICE                  Base Payload                                                [3.02 m]
#                                                  Heavy Duty Payload Upgrade                          [2.85 m, 3.02 m]
#                                                  Mid Payload Upgrade         [0.00 m, 2.72 m, 2.85 m, 3.02 m, 4.06 m]
#                             PHEV                 Unknown (0x05)                                              [3.02 m]
# FORD F-150 14TH GEN         BEV                  Base Payload                                                [3.68 m]
#                             HEV                  Base Payload                                        [3.68 m, 3.99 m]
#                             ICE                  Base Payload                [0.00 m, 3.11 m, 3.58 m, 3.68 m, 3.99 m]
#                                                  Heavy Duty Payload Upgrade                                  [3.58 m]
#                                                  Mid Payload Upgrade                                         [3.68 m]
# FORD MAVERICK 1ST GEN       HEV                  Base Payload                                           [Missing ECU]
#                                                  Mid Payload Upgrade                            [3.07 m, Missing ECU]
#                             ICE                  Base Payload                                           [Missing ECU]
#                                                  Mid Payload Upgrade                            [3.07 m, Missing ECU]
# FORD MUSTANG MACH-E 1ST GEN BEV                  Base Payload                                                [2.98 m]
#                                                  Mid Payload Upgrade                                         [2.98 m]
#
#                                                                                                      Wheelbase (IPMA)  \
# CarInfoPlatform             ElectrificationLevel Payload (ABS)
# FORD BRONCO SPORT 1ST GEN   ICE                  Base Payload                                           [Missing ECU]
#                                                  Mid Payload Upgrade                                    [Missing ECU]
# FORD ESCAPE 4TH GEN         FHEV                 Heavy Duty Payload Upgrade                             [Missing ECU]
#                             ICE                  Base Payload                                           [Missing ECU]
#                             PHEV                 Unknown (0x05)                                         [Missing ECU]
# FORD EXPLORER 6TH GEN       HEV                  Unknown (0x04)                                         [Missing ECU]
#                             ICE                  Base Payload                                           [Missing ECU]
#                                                  Heavy Duty Payload Upgrade                             [Missing ECU]
#                                                  Mid Payload Upgrade                                    [Missing ECU]
#                             PHEV                 Unknown (0x05)                                         [Missing ECU]
# FORD F-150 14TH GEN         BEV                  Base Payload                                                [3.70 m]
#                             HEV                  Base Payload                                        [3.68 m, 3.99 m]
#                             ICE                  Base Payload                [3.11 m, 3.58 m, 3.68 m, 3.70 m, 3.99 m]
#                                                  Heavy Duty Payload Upgrade                                  [3.58 m]
#                                                  Mid Payload Upgrade                                         [3.68 m]
# FORD MAVERICK 1ST GEN       HEV                  Base Payload                                           [Missing ECU]
#                                                  Mid Payload Upgrade                                    [Missing ECU]
#                             ICE                  Base Payload                                           [Missing ECU]
#                                                  Mid Payload Upgrade                                    [Missing ECU]
# FORD MUSTANG MACH-E 1ST GEN BEV                  Base Payload                                                [2.98 m]
#                                                  Mid Payload Upgrade                                         [2.98 m]
#
#                                                                                                                  Weight (APIM)  \
# CarInfoPlatform             ElectrificationLevel Payload (ABS)
# FORD BRONCO SPORT 1ST GEN   ICE                  Base Payload                                                  [0 kg, 2100 kg]
#                                                  Mid Payload Upgrade                                                 [2100 kg]
# FORD ESCAPE 4TH GEN         FHEV                 Heavy Duty Payload Upgrade                                 [2000 kg, 2100 kg]
#                             ICE                  Base Payload                             [1900 kg, 2000 kg, 2100 kg, 2700 kg]
#                             PHEV                 Unknown (0x05)                                                      [2200 kg]
# FORD EXPLORER 6TH GEN       HEV                  Unknown (0x04)                                                      [2900 kg]
#                             ICE                  Base Payload                                                        [2600 kg]
#                                                  Heavy Duty Payload Upgrade      [1200 kg, 2600 kg, 2700 kg, 2800 kg, 2900 kg]
#                                                  Mid Payload Upgrade              [1000 kg, 1600 kg, 2600 kg, 5200 kg, 700 kg]
#                             PHEV                 Unknown (0x05)                                                      [3200 kg]
# FORD F-150 14TH GEN         BEV                  Base Payload                                      [3700 kg, 3800 kg, 3900 kg]
#                             HEV                  Base Payload                                                        [3300 kg]
#                             ICE                  Base Payload                [19200 kg, 2700 kg, 2800 kg, 2900 kg, 3000 kg,...
#                                                  Heavy Duty Payload Upgrade                                          [3600 kg]
#                                                  Mid Payload Upgrade                                        [3000 kg, 3200 kg]
# FORD MAVERICK 1ST GEN       HEV                  Base Payload                                                    [Missing ECU]
#                                                  Mid Payload Upgrade                                    [2400 kg, Missing ECU]
#                             ICE                  Base Payload                                                    [Missing ECU]
#                                                  Mid Payload Upgrade                           [2300 kg, 2400 kg, Missing ECU]
# FORD MUSTANG MACH-E 1ST GEN BEV                  Base Payload                                      [2400 kg, 2500 kg, 2600 kg]
#                                                  Mid Payload Upgrade                                                 [2700 kg]
#
#                                                                                   Steer Ratio (ABS)  \
# CarInfoPlatform             ElectrificationLevel Payload (ABS)
# FORD BRONCO SPORT 1ST GEN   ICE                  Base Payload                           [EPAS 17:1]
#                                                  Mid Payload Upgrade                    [EPAS 17:1]
# FORD ESCAPE 4TH GEN         FHEV                 Heavy Duty Payload Upgrade             [EPAS 17:1]
#                             ICE                  Base Payload                           [EPAS 17:1]
#                             PHEV                 Unknown (0x05)                         [EPAS 17:1]
# FORD EXPLORER 6TH GEN       HEV                  Unknown (0x04)                    [Unknown (0x00)]
#                             ICE                  Base Payload                           [EPAS 17:1]
#                                                  Heavy Duty Payload Upgrade             [EPAS 17:1]
#                                                  Mid Payload Upgrade                    [EPAS 17:1]
#                             PHEV                 Unknown (0x05)                    [Unknown (0x00)]
# FORD F-150 14TH GEN         BEV                  Base Payload                           [EPAS 17:1]
#                             HEV                  Base Payload                           [EPAS 17:1]
#                             ICE                  Base Payload                [EPAS 17:1, EPAS 21:1]
#                                                  Heavy Duty Payload Upgrade             [EPAS 21:1]
#                                                  Mid Payload Upgrade                    [EPAS 17:1]
# FORD MAVERICK 1ST GEN       HEV                  Base Payload                      [Unknown (0x00)]
#                                                  Mid Payload Upgrade               [Unknown (0x00)]
#                             ICE                  Base Payload                      [Unknown (0x00)]
#                                                  Mid Payload Upgrade               [Unknown (0x00)]
# FORD MUSTANG MACH-E 1ST GEN BEV                  Base Payload                           [EPAS 17:1]
#                                                  Mid Payload Upgrade                    [EPAS 17:1]
#
#                                                                             Steer Ratio (APIM)  \
# CarInfoPlatform             ElectrificationLevel Payload (ABS)
# FORD BRONCO SPORT 1ST GEN   ICE                  Base Payload                    [Missing ECU]
#                                                  Mid Payload Upgrade             [Missing ECU]
# FORD ESCAPE 4TH GEN         FHEV                 Heavy Duty Payload Upgrade      [Missing ECU]
#                             ICE                  Base Payload                    [Missing ECU]
#                             PHEV                 Unknown (0x05)                  [Missing ECU]
# FORD EXPLORER 6TH GEN       HEV                  Unknown (0x04)                  [Missing ECU]
#                             ICE                  Base Payload                    [Missing ECU]
#                                                  Heavy Duty Payload Upgrade      [Missing ECU]
#                                                  Mid Payload Upgrade             [Missing ECU]
#                             PHEV                 Unknown (0x05)                  [Missing ECU]
# FORD F-150 14TH GEN         BEV                  Base Payload                           [17:1]
#                             HEV                  Base Payload                           [17:1]
#                             ICE                  Base Payload                     [17:1, 20:1]
#                                                  Heavy Duty Payload Upgrade             [20:1]
#                                                  Mid Payload Upgrade                    [17:1]
# FORD MAVERICK 1ST GEN       HEV                  Base Payload                    [Missing ECU]
#                                                  Mid Payload Upgrade             [Missing ECU]
#                             ICE                  Base Payload                    [Missing ECU]
#                                                  Mid Payload Upgrade             [Missing ECU]
# FORD MUSTANG MACH-E 1ST GEN BEV                  Base Payload                           [17:1]
#                                                  Mid Payload Upgrade                    [17:1]
#
#                                                                             Steer Ratio (IPMA)
# CarInfoPlatform             ElectrificationLevel Payload (ABS)
# FORD BRONCO SPORT 1ST GEN   ICE                  Base Payload                    [Missing ECU]
#                                                  Mid Payload Upgrade             [Missing ECU]
# FORD ESCAPE 4TH GEN         FHEV                 Heavy Duty Payload Upgrade      [Missing ECU]
#                             ICE                  Base Payload                    [Missing ECU]
#                             PHEV                 Unknown (0x05)                  [Missing ECU]
# FORD EXPLORER 6TH GEN       HEV                  Unknown (0x04)                  [Missing ECU]
#                             ICE                  Base Payload                    [Missing ECU]
#                                                  Heavy Duty Payload Upgrade      [Missing ECU]
#                                                  Mid Payload Upgrade             [Missing ECU]
#                             PHEV                 Unknown (0x05)                  [Missing ECU]
# FORD F-150 14TH GEN         BEV                  Base Payload                           [18.0]
#                             HEV                  Base Payload                           [18.0]
#                             ICE                  Base Payload                     [18.0, 21.0]
#                                                  Heavy Duty Payload Upgrade             [21.0]
#                                                  Mid Payload Upgrade                    [18.0]
# FORD MAVERICK 1ST GEN       HEV                  Base Payload                    [Missing ECU]
#                                                  Mid Payload Upgrade             [Missing ECU]
#                             ICE                  Base Payload                    [Missing ECU]
#                                                  Mid Payload Upgrade             [Missing ECU]
# FORD MUSTANG MACH-E 1ST GEN BEV                  Base Payload                           [14.6]
#                                                  Mid Payload Upgrade                    [14.6]
