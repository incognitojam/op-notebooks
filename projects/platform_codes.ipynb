# %%
import pandas as pd
from tqdm.contrib.concurrent import process_map

from notebooks.ford.asbuilt import AsBuiltData
from notebooks.ford.decode import search, print_breakdown


df_nhtsa = await search(
  min_model_year=2017,
  include_openpilot=True,
  include_police=True,
  skip_missing_asbuilt=True,
)

# pre-load asbuilt
process_map(AsBuiltData.from_vin, df_nhtsa['VIN'].unique(), desc='Loading AsBuilt Data', chunksize=100)

print()
print_breakdown(df_nhtsa, include_model_year=False)
# Out:
# Loaded 36764 VINs (filter_comment=None, include_openpilot=True, skipped=163, missing_asbuilt=0)
# Downloading NHTSA data: 100%|██████████| 36764/36764 [00:02<00:00, 15308.07it/s]
# Loading AsBuilt Data:   0%|          | 0/36762 [00:00<?, ?it/s]
# Model
#                       2
# Aviator            1107
# Bronco              996
# Bronco Sport       1500
# C-Max                 5
# Continental          23
# Corsair             986
# Ecosport            406
# Edge               2685
# Escape             3568
# Expedition          835
# Expedition MAX      733
# Explorer           3364
# F-150              8253
# F-150 Lightning     385
# F-250              1720
# F-350              1158
# F-450               207
# F-550                 1
# Fiesta              195
# Flex                189
# Focus               169
# Fusion             1163
# GT                    3
# MKC                  55
# MKT                   7
# MKZ                 100
# Maverick            994
# Mustang             952
# Mustang Mach-E      839
# Nautilus           1169
# Navigator           303
# Navigator L         230
# Ranger              533
# Taurus              122
# Transit            1391
# Transit Connect     414
# dtype: int64

# %%
from notebooks.ford.ecu import FordEcu
from panda.python.uds import DATA_IDENTIFIER_TYPE


def get_platform_code(row):
  abd = AsBuiltData.from_vin(row['VIN'])

  eps_fw = abd.get_identifier(FordEcu.PowerSteeringControlModule, DATA_IDENTIFIER_TYPE.VEHICLE_MANUFACTURER_ECU_SOFTWARE_NUMBER)
  if eps_fw is None:
    platform_code = None
  else:
    prefix, core, _ = eps_fw.split('-')
    platform_code = f'{core}-{prefix[1:]}'

  return pd.Series({
    'PlatformCode': platform_code,
    'PlatformYear': prefix[0] if platform_code else None,
  })


df = df_nhtsa[['VIN', 'Make', 'Model', 'ModelYear']].copy()
df['CarName'] = df['Make'] + ' ' + df['Model'] + ' ' + df['ModelYear'].astype(str)
df.drop(columns=['Make', 'Model', 'ModelYear'], inplace=True)
df = df.join(df_nhtsa.apply(get_platform_code, axis=1))
df.head()
# Out:
#                  VIN               CarName PlatformCode PlatformYear
# 0  3FTTW8F93NRA33503    FORD Maverick 2022   14D003-Z6C            N
# 1  1FMCU0G65LUB57012      FORD Escape 2020   14D003-X6C            L
# 2  MAJ6S3KL8LC349784    FORD Ecosport 2020   14C217-N15            G
# 3  1FT8W3DT7NEE61262       FORD F-350 2022         None         None
# 4  1FMJU1KT9MEA41589  FORD Expedition 2021   14D003-L3V            K

# %%
df_groups = df.groupby(['CarName', 'PlatformCode', 'PlatformYear'], dropna=False).size().reset_index(name='count')
df_groups.head()
# Out:
#             CarName PlatformCode PlatformYear  count
# 0  FORD Bronco 2021   14D003-B3C            M     99
# 1  FORD Bronco 2022   14D003-B3C            M     87
# 2  FORD Bronco 2022   14D003-B3C            N    118
# 3  FORD Bronco 2022   14D003-L38            N      6
# 4  FORD Bronco 2023   14D003-B3C            N    605

# %%
for group in df_groups.groupby(['PlatformCode', 'PlatformYear'], dropna=False):
  print(group[0])
  print(f'CarName: {group[1]["CarName"].unique()}')
  print()
# Out:
# ('14C217-E81', 'A')
# CarName: ['FORD Fiesta 2017' 'FORD Fiesta 2018' 'FORD Fiesta 2019']
#
# ('14C217-N15', 'G')
# CarName: ['FORD Ecosport 2018' 'FORD Ecosport 2019' 'FORD Ecosport 2020'
#  'FORD Ecosport 2021' 'FORD Ecosport 2022']
#
# ('14C217-V6T', 'C')
# CarName: ['FORD Focus 2017' 'FORD Focus 2018' 'FORD Transit Connect 2018']
#
# ('14C217-V6T', 'H')
# CarName: ['FORD C-Max 2018' 'FORD Escape 2018' 'FORD Escape 2019' 'FORD Focus 2018'
#  'FORD Transit Connect 2018']
#
# ('14D003-1MC', 'L')
# CarName: ['FORD Explorer 2020' 'FORD Explorer 2021' 'FORD Explorer 2022'
#  'LINCOLN Aviator 2020' 'LINCOLN Aviator 2021' 'LINCOLN Aviator 2022']
#
# ('14D003-1MC', 'M')
# CarName: ['FORD Explorer 2021' 'FORD Explorer 2022' 'LINCOLN Aviator 2020'
#  'LINCOLN Aviator 2021' 'LINCOLN Aviator 2022' 'LINCOLN Aviator 2023']
#
# ('14D003-1MC', 'P')
# CarName: ['FORD Explorer 2020' 'FORD Explorer 2022' 'FORD Explorer 2023'
#  'FORD Explorer 2024' 'LINCOLN Aviator 2020' 'LINCOLN Aviator 2023'
#  'LINCOLN Aviator 2024']
#
# ('14D003-2GC', 'K')
# CarName: ['FORD Edge 2019' 'LINCOLN Nautilus 2019']
#
# ('14D003-2GC', 'M')
# CarName: ['FORD Edge 2021' 'FORD Edge 2022' 'FORD Edge 2023' 'FORD Edge 2024'
#  'LINCOLN Nautilus 2021' 'LINCOLN Nautilus 2022' 'LINCOLN Nautilus 2023']
#
# ('14D003-B3C', 'M')
# CarName: ['FORD Bronco 2021' 'FORD Bronco 2022' 'FORD F-150 2021']
#
# ('14D003-B3C', 'N')
# CarName: ['FORD Bronco 2022' 'FORD Bronco 2023' 'FORD Ranger 2024']
#
# ('14D003-B3C', 'R')
# CarName: ['FORD Bronco 2024']
#
# ('14D003-B53', 'H')
# CarName: ['FORD Explorer 2017' 'FORD Explorer 2018' 'FORD Explorer 2019']
#
# ('14D003-C3C', 'L')
# CarName: ['FORD F-250 2020' 'FORD F-250 2021' 'FORD F-250 2022' 'FORD F-350 2020'
#  'FORD F-350 2021' 'FORD F-350 2022' 'FORD F-450 2020' 'FORD F-450 2021'
#  'FORD F-450 2022']
#
# ('14D003-C3C', 'P')
# CarName: ['FORD F-250 2023' 'FORD F-250 2024' 'FORD F-350 2023' 'FORD F-350 2024'
#  'FORD F-450 2023' 'FORD F-450 2024']
#
# ('14D003-G13', 'G')
# CarName: ['FORD Flex 2018' 'FORD Flex 2019' 'FORD Taurus 2018' 'FORD Taurus 2019'
#  'LINCOLN MKT 2019']
#
# ('14D003-G9C', 'H')
# CarName: ['FORD Edge 2018' 'FORD Fusion 2018']
#
# ('14D003-G9C', 'K')
# CarName: ['FORD Fusion 2019' 'FORD Fusion 2020' 'LINCOLN Continental 2019'
#  'LINCOLN Continental 2020' 'LINCOLN MKZ 2019' 'LINCOLN MKZ 2020']
#
# ('14D003-J7C', 'G')
# CarName: ['LINCOLN MKC 2019']
#
# ('14D003-J9C', 'L')
# CarName: ['FORD Mustang Mach-E 2021' 'FORD Mustang Mach-E 2022'
#  'FORD Mustang Mach-E 2023' 'FORD Mustang Mach-E 2024']
#
# ('14D003-K1C', 'K')
# CarName: ['FORD Edge 2020' 'LINCOLN Nautilus 2020']
#
# ('14D003-K21', 'K')
# CarName: ['FORD Transit 2020' 'FORD Transit 2021' 'FORD Transit 2022'
#  'FORD Transit 2023' 'FORD Transit 2024']
#
# ('14D003-L14', 'J')
# CarName: ['FORD Expedition 2018' 'FORD Expedition MAX 2018' 'FORD Mustang 2018']
#
# ('14D003-L14', 'N')
# CarName: ['FORD Expedition 2022' 'FORD Expedition 2023' 'FORD Expedition 2024'
#  'FORD Expedition MAX 2022' 'FORD Expedition MAX 2023'
#  'FORD Expedition MAX 2024' 'LINCOLN Navigator 2022'
#  'LINCOLN Navigator 2023' 'LINCOLN Navigator 2024'
#  'LINCOLN Navigator L 2022' 'LINCOLN Navigator L 2023'
#  'LINCOLN Navigator L 2024']
#
# ('14D003-L14', 'R')
# CarName: ['FORD Mustang 2024']
#
# ('14D003-L34', 'J')
# CarName: ['FORD F-150 2018']
#
# ('14D003-L34', 'R')
# CarName: ['FORD F-150 2024']
#
# ('14D003-L38', 'N')
# CarName: ['FORD Bronco 2022' 'FORD Bronco 2023' 'FORD F-150 Lightning 2022'
#  'FORD F-150 Lightning 2023']
#
# ('14D003-L38', 'R')
# CarName: ['FORD F-150 Lightning 2022' 'FORD F-150 Lightning 2023'
#  'FORD F-150 Lightning 2024']
#
# ('14D003-L3V', 'K')
# CarName: ['FORD Expedition 2019' 'FORD Expedition 2020' 'FORD Expedition 2021'
#  'FORD Expedition MAX 2019' 'FORD Expedition MAX 2020'
#  'FORD Expedition MAX 2021' 'FORD F-150 2019' 'FORD F-150 2020'
#  'FORD Mustang 2019' 'LINCOLN  2019' 'LINCOLN Navigator 2019'
#  'LINCOLN Navigator 2020' 'LINCOLN Navigator 2021'
#  'LINCOLN Navigator L 2019' 'LINCOLN Navigator L 2020'
#  'LINCOLN Navigator L 2021']
#
# ('14D003-L3V', 'M')
# CarName: ['FORD F-150 2021' 'FORD F-150 2022' 'FORD F-150 2023']
#
# ('14D003-R3C', 'H')
# CarName: ['FORD F-150 2017']
#
# ('14D003-R3C', 'J')
# CarName: ['FORD F-150 2018' 'FORD Mustang 2018' 'FORD Mustang 2019'
#  'FORD Ranger 2019' 'FORD Ranger 2020' 'FORD Ranger 2021'
#  'FORD Ranger 2022' 'FORD Ranger 2023']
#
# ('14D003-R3C', 'L')
# CarName: ['FORD Mustang 2020' 'FORD Mustang 2021' 'FORD Mustang 2022'
#  'FORD Mustang 2023']
#
# ('14D003-R3C', 'P')
# CarName: ['FORD Mustang 2024']
#
# ('14D003-V6C', 'K')
# CarName: ['FORD Transit Connect 2019' 'FORD Transit Connect 2020'
#  'FORD Transit Connect 2021' 'FORD Transit Connect 2022'
#  'FORD Transit Connect 2023']
#
# ('14D003-X6C', 'L')
# CarName: ['FORD Bronco Sport 2021' 'FORD Bronco Sport 2022'
#  'FORD Bronco Sport 2023' 'FORD Bronco Sport 2024' 'FORD Escape 2020'
#  'FORD Escape 2021' 'FORD Escape 2022' 'LINCOLN Corsair 2020'
#  'LINCOLN Corsair 2021' 'LINCOLN Corsair 2022']
#
# ('14D003-Z11', 'P')
# CarName: ['FORD Escape 2023' 'FORD Escape 2024' 'LINCOLN Corsair 2023'
#  'LINCOLN Corsair 2024']
#
# ('14D003-Z1C', 'P')
# CarName: ['LINCOLN Nautilus 2024']
#
# ('14D003-Z6C', 'N')
# CarName: ['FORD Maverick 2022' 'FORD Maverick 2023' 'FORD Maverick 2024']
#
# (nan, nan)
# CarName: ['FORD F-250 2018' 'FORD F-250 2019' 'FORD F-250 2020' 'FORD F-250 2021'
#  'FORD F-250 2022' 'FORD F-250 2023' 'FORD F-250 2024' 'FORD F-350 2018'
#  'FORD F-350 2019' 'FORD F-350 2020' 'FORD F-350 2021' 'FORD F-350 2022'
#  'FORD F-350 2023' 'FORD F-350 2024' 'FORD F-450 2018' 'FORD F-450 2019'
#  'FORD F-450 2020' 'FORD F-450 2021' 'FORD F-450 2022' 'FORD F-450 2023'
#  'FORD F-450 2024' 'FORD F-550 2022' 'FORD GT 2020' 'FORD Transit 2018'
#  'FORD Transit 2019']

# %%
from notebooks.ford.platforms import find_openpilot_platform


def get_openpilot_platform(row):
  return pd.Series({
    'CarInfoPlatform': find_openpilot_platform(row['CarName']),
  })


df_openpilot_platforms = df.join(df.apply(get_openpilot_platform, axis=1))
df_openpilot_platforms.head()
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /mnt/c/Users/camer/AppData/Local/Programs/Microsoft VS Code
#                  VIN               CarName PlatformCode PlatformYear  \
# 0  3FTTW8F93NRA33503    FORD Maverick 2022   14D003-Z6C            N
# 1  1FMCU0G65LUB57012      FORD Escape 2020   14D003-X6C            L
# 2  MAJ6S3KL8LC349784    FORD Ecosport 2020   14C217-N15            G
# 3  1FT8W3DT7NEE61262       FORD F-350 2022         None         None
# 4  1FMJU1KT9MEA41589  FORD Expedition 2021   14D003-L3V            K
#
#          CarInfoPlatform
# 0  FORD MAVERICK 1ST GEN
# 1    FORD ESCAPE 4TH GEN
# 2                   None
# 3                   None
# 4                   None

# %%
df_openpilot_platforms['CarInfoPlatform'].value_counts(dropna=False)
# Out:
# CarInfoPlatform
# None                            27023
# FORD EXPLORER 6TH GEN            3332
# FORD ESCAPE 4TH GEN              2164
# FORD F-150 14TH GEN              1338
# FORD BRONCO SPORT 1ST GEN         930
# FORD MUSTANG MACH-E 1ST GEN       813
# FORD MAVERICK 1ST GEN             788
# FORD F-150 LIGHTNING 1ST GEN      374
# Name: count, dtype: int64

# %%
for group in df_openpilot_platforms.groupby('CarInfoPlatform', dropna=False):
  print(group[0])
  print(f'CarName: {group[1]["CarName"].unique()}')
  print(f'PlatformCode: {group[1]["PlatformCode"].unique()}')
  print(f'PlatformYear: {group[1]["PlatformYear"].unique()}')
  print()
# Out:
# FORD BRONCO SPORT 1ST GEN
# CarName: ['FORD Bronco Sport 2021' 'FORD Bronco Sport 2022']
# PlatformCode: ['14D003-X6C']
# PlatformYear: ['L']
#
# FORD ESCAPE 4TH GEN
# CarName: ['FORD Escape 2020' 'FORD Escape 2022' 'FORD Escape 2021']
# PlatformCode: ['14D003-X6C']
# PlatformYear: ['L']
#
# FORD EXPLORER 6TH GEN
# CarName: ['LINCOLN Aviator 2020' 'FORD Explorer 2022' 'FORD Explorer 2021'
#  'FORD Explorer 2020' 'FORD Explorer 2023' 'LINCOLN Aviator 2021']
# PlatformCode: ['14D003-1MC']
# PlatformYear: ['L' 'M' 'P']
#
# FORD F-150 14TH GEN
# CarName: ['FORD F-150 2023']
# PlatformCode: ['14D003-L3V']
# PlatformYear: ['M']
#
# FORD F-150 LIGHTNING 1ST GEN
# CarName: ['FORD F-150 Lightning 2023' 'FORD F-150 Lightning 2022']
# PlatformCode: ['14D003-L38']
# PlatformYear: ['N' 'R']
#
# FORD MAVERICK 1ST GEN
# CarName: ['FORD Maverick 2022' 'FORD Maverick 2023']
# PlatformCode: ['14D003-Z6C']
# PlatformYear: ['N']
#
# FORD MUSTANG MACH-E 1ST GEN
# CarName: ['FORD Mustang Mach-E 2023' 'FORD Mustang Mach-E 2022'
#  'FORD Mustang Mach-E 2021']
# PlatformCode: ['14D003-J9C']
# PlatformYear: ['L']
#
# nan
# CarName: ['FORD Ecosport 2020' 'FORD F-350 2022' 'FORD Expedition 2021'
#  'FORD Explorer 2019' 'FORD F-150 2019' 'FORD F-150 2021'
#  'FORD Ranger 2019' 'LINCOLN Corsair 2020' 'FORD F-150 2018'
#  'FORD Edge 2021' 'FORD Edge 2020' 'LINCOLN Aviator 2023'
#  'FORD F-250 2019' 'FORD Transit 2024' 'LINCOLN MKC 2019' 'FORD Edge 2024'
#  'FORD F-150 2020' 'FORD Escape 2018' 'FORD Maverick 2024'
#  'FORD Bronco 2022' 'FORD Bronco 2021' 'LINCOLN MKZ 2020'
#  'FORD F-350 2020' 'FORD Mustang 2023' 'FORD Fusion 2019'
#  'FORD F-150 2022' 'FORD Mustang 2024' 'FORD Bronco 2023'
#  'LINCOLN Nautilus 2020' 'FORD Ecosport 2018' 'FORD Expedition MAX 2021'
#  'FORD F-350 2018' 'FORD Flex 2019' 'FORD F-350 2023'
#  'FORD Expedition 2020' 'FORD F-250 2020' 'FORD Edge 2023'
#  'FORD F-250 2022' 'FORD Focus 2018' 'FORD F-350 2019'
#  'LINCOLN Aviator 2024' 'FORD Ranger 2020' 'FORD Transit Connect 2019'
#  'LINCOLN Corsair 2022' 'FORD Ecosport 2019' 'FORD Fusion 2018'
#  'LINCOLN Nautilus 2019' 'FORD Transit 2023' 'LINCOLN Nautilus 2022'
#  'FORD Edge 2018' 'FORD Edge 2019' 'FORD Expedition 2018'
#  'FORD F-250 2023' 'LINCOLN Aviator 2022' 'FORD Flex 2018'
#  'FORD Fusion 2020' 'FORD Bronco Sport 2023' 'FORD F-250 2021'
#  'FORD C-Max 2018' 'FORD Explorer 2018' 'FORD F-350 2021'
#  'FORD Transit 2018' 'FORD Mustang 2018' 'LINCOLN Nautilus 2023'
#  'FORD Mustang 2022' 'LINCOLN Corsair 2021' 'FORD Escape 2023'
#  'FORD Mustang Mach-E 2024' 'FORD Transit 2019' 'FORD Mustang 2019'
#  'FORD Mustang 2021' 'FORD Edge 2022' 'FORD Transit 2020'
#  'FORD Escape 2019' 'FORD Expedition 2023' 'FORD Taurus 2018'
#  'FORD Fiesta 2018' 'FORD Expedition 2019' 'FORD Expedition MAX 2019'
#  'FORD Transit 2021' 'LINCOLN Corsair 2024' 'FORD Mustang 2020'
#  'FORD F-450 2021' 'LINCOLN Navigator L 2022' 'FORD F-250 2018'
#  'FORD Fiesta 2019' 'FORD Ecosport 2022' 'LINCOLN Navigator L 2024'
#  'FORD Transit Connect 2018' 'LINCOLN Continental 2019'
#  'FORD Transit Connect 2021' 'FORD Expedition 2022'
#  'LINCOLN Navigator L 2023' 'FORD Expedition MAX 2023'
#  'LINCOLN Navigator 2022' 'FORD Bronco Sport 2024' 'FORD F-350 2024'
#  'FORD Transit Connect 2020' 'FORD Expedition MAX 2020'
#  'FORD Ecosport 2021' 'FORD Expedition MAX 2018' 'LINCOLN Navigator 2024'
#  'FORD Expedition MAX 2022' 'FORD Escape 2024' 'LINCOLN Navigator 2020'
#  'FORD Expedition 2024' 'FORD F-450 2024' 'LINCOLN Nautilus 2021'
#  'LINCOLN MKT 2019' 'LINCOLN Continental 2020' 'LINCOLN Navigator 2023'
#  'FORD F-150 Lightning 2024' 'FORD Transit Connect 2022'
#  'FORD Explorer 2024' 'FORD F-450 2022' 'FORD Transit Connect 2023'
#  'FORD Ranger 2021' 'FORD F-250 2024' 'LINCOLN Nautilus 2024'
#  'LINCOLN Navigator L 2020' 'FORD Fiesta 2017' 'FORD Taurus 2019'
#  'FORD F-150 2024' 'FORD Ranger 2023' 'FORD F-450 2023'
#  'LINCOLN Corsair 2023' 'FORD Explorer 2017' 'LINCOLN Navigator L 2019'
#  'FORD F-450 2020' 'LINCOLN Navigator 2019' 'LINCOLN Navigator 2021'
#  'FORD Focus 2017' 'FORD Bronco 2024' 'FORD Expedition MAX 2024'
#  'LINCOLN MKZ 2019' 'LINCOLN Navigator L 2021' 'FORD Transit 2022'
#  'FORD Ranger 2022' 'LINCOLN  2019' 'FORD F-450 2019' 'FORD Ranger 2024'
#  'FORD F-450 2018' 'FORD GT 2020' 'FORD F-150 2017' 'FORD F-550 2022']
# PlatformCode: ['14C217-N15' None '14D003-L3V' '14D003-B53' '14D003-B3C' '14D003-R3C'
#  '14D003-X6C' '14D003-2GC' '14D003-K1C' '14D003-1MC' '14D003-K21'
#  '14D003-J7C' '14C217-V6T' '14D003-Z6C' '14D003-G9C' '14D003-C3C'
#  '14D003-G13' '14D003-V6C' '14D003-L14' '14D003-L34' '14D003-Z11'
#  '14D003-J9C' '14C217-E81' '14D003-L38' '14D003-Z1C']
# PlatformYear: ['G' None 'K' 'H' 'M' 'J' 'L' 'P' 'N' 'A' 'R' 'C']

# %%
for group in df_openpilot_platforms.groupby(['PlatformCode', 'PlatformYear'], dropna=False):
  platforms = group[1]['CarInfoPlatform'].unique()
  if len(platforms) == 1 and platforms[0] is None:
    continue
  print(group[0])
  print(f'CarInfoPlatform: {group[1]["CarInfoPlatform"].unique()}')
  print(f'CarName: {group[1]["CarName"].unique()}')
  print()
# Out:
# ('14D003-1MC', 'L')
# CarInfoPlatform: [<CAR.EXPLORER_MK6: 'FORD EXPLORER 6TH GEN'> None]
# CarName: ['LINCOLN Aviator 2020' 'FORD Explorer 2021' 'FORD Explorer 2020'
#  'LINCOLN Aviator 2021' 'LINCOLN Aviator 2022' 'FORD Explorer 2022']
#
# ('14D003-1MC', 'M')
# CarInfoPlatform: [<CAR.EXPLORER_MK6: 'FORD EXPLORER 6TH GEN'> None]
# CarName: ['FORD Explorer 2022' 'FORD Explorer 2021' 'LINCOLN Aviator 2022'
#  'LINCOLN Aviator 2023' 'LINCOLN Aviator 2021' 'LINCOLN Aviator 2020']
#
# ('14D003-1MC', 'P')
# CarInfoPlatform: [None <CAR.EXPLORER_MK6: 'FORD EXPLORER 6TH GEN'>]
# CarName: ['LINCOLN Aviator 2023' 'FORD Explorer 2023' 'LINCOLN Aviator 2024'
#  'FORD Explorer 2024' 'FORD Explorer 2022' 'FORD Explorer 2020'
#  'LINCOLN Aviator 2020']
#
# ('14D003-J9C', 'L')
# CarInfoPlatform: [<CAR.MUSTANG_MACH_E_MK1: 'FORD MUSTANG MACH-E 1ST GEN'> None]
# CarName: ['FORD Mustang Mach-E 2023' 'FORD Mustang Mach-E 2022'
#  'FORD Mustang Mach-E 2024' 'FORD Mustang Mach-E 2021']
#
# ('14D003-L38', 'N')
# CarInfoPlatform: [<CAR.F_150_LIGHTNING_MK1: 'FORD F-150 LIGHTNING 1ST GEN'> None]
# CarName: ['FORD F-150 Lightning 2023' 'FORD F-150 Lightning 2022'
#  'FORD Bronco 2023' 'FORD Bronco 2022']
#
# ('14D003-L38', 'R')
# CarInfoPlatform: [None <CAR.F_150_LIGHTNING_MK1: 'FORD F-150 LIGHTNING 1ST GEN'>]
# CarName: ['FORD F-150 Lightning 2024' 'FORD F-150 Lightning 2022'
#  'FORD F-150 Lightning 2023']
#
# ('14D003-L3V', 'M')
# CarInfoPlatform: [None <CAR.F_150_MK14: 'FORD F-150 14TH GEN'>]
# CarName: ['FORD F-150 2021' 'FORD F-150 2022' 'FORD F-150 2023']
#
# ('14D003-X6C', 'L')
# CarInfoPlatform: [<CAR.ESCAPE_MK4: 'FORD ESCAPE 4TH GEN'> None
#  <CAR.BRONCO_SPORT_MK1: 'FORD BRONCO SPORT 1ST GEN'>]
# CarName: ['FORD Escape 2020' 'LINCOLN Corsair 2020' 'FORD Bronco Sport 2021'
#  'LINCOLN Corsair 2022' 'FORD Escape 2022' 'FORD Escape 2021'
#  'FORD Bronco Sport 2023' 'LINCOLN Corsair 2021' 'FORD Bronco Sport 2024'
#  'FORD Bronco Sport 2022']
#
# ('14D003-Z6C', 'N')
# CarInfoPlatform: [<CAR.MAVERICK_MK1: 'FORD MAVERICK 1ST GEN'> None]
# CarName: ['FORD Maverick 2022' 'FORD Maverick 2024' 'FORD Maverick 2023']

# %%
PSCM_A = '14C217'
PSCM_B = '14D003'

def predict_platform(platform_code: str) -> str | None:
  if platform_code is None:
    return None

  core, prefix = platform_code.split('-')

  # Not recognised
  if core not in (PSCM_A, PSCM_B):
    return None

  # Not supported in openpilot
  if core == PSCM_A:
    return None

  raise ValueError(f'Unknown platform code: {platform_code}')
