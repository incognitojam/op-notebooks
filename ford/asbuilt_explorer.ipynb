# %%
# %load_ext autoreload
# %autoreload 2

# %%
from vins import load_vins

vins = load_vins()
# Out:
# Loaded 1263 VINs (filter_comment=None, include_openpilot=False, skipped=81)
# Loaded AsBuilt data for 1263 VINs

# %%
import random

import pandas as pd

from asbuilt import AsBuiltData
from settings import VEHICLE_SETTINGS

pd.set_option('display.max_columns', None)

rows = []
for vin in ('WF0NXXGCHNJR69712', *random.sample(vins, 9)):
  abd = AsBuiltData.from_vin(vin)
  rows.append([vin, *map(lambda s: abd.get_setting_value(s), VEHICLE_SETTINGS)])

columns = [('', 'VIN'), *map(lambda s: (s.ecu.name, s.comment), VEHICLE_SETTINGS)]

df = pd.DataFrame(rows, columns=pd.MultiIndex.from_tuples(columns))
df
# Out:
#                       ImageProcessingModuleA                 \
#                  VIN                 Vehicle Distance Alert
# 0  WF0NXXGCHNJR69712            C519 (Focus)            Off
# 1  5LM5J7XC5MGL14695  U611 (Lincoln Aviator)             On
# 2  1FMCU0DZ9LUA38118     CX482 (Escape/Kuga)             On
# 3  2FMPK4K99KBB31985            CD539 (Edge)             On
# 4  1FMSK8DH2MGA20826         U625 (Explorer)            Off
# 5  1FMCU0F67LUB95052     CX482 (Escape/Kuga)            Off
# 6  1FM5K8HW7MNA12805         U625 (Explorer)             On
# 7  1FM5K8FW0NNA10396         U625 (Explorer)             On
# 8  1FMSK7DH1NGA93522         U625 (Explorer)            Off
# 9  1FM5K8GC8PGA20217         U625 (Explorer)             On
#
#                                                                   \
#   Forward Collision Warning HUD High Beam Lane Departure Warning
# 0                           Off       Off                     On
# 1                           Off      AHBC                     On
# 2                           Off      AHBC                     On
# 3                           Off      AHBC                     On
# 4                           Off      AHBC                     On
# 5                           Off      AHBC                     On
# 6                           Off      AHBC                     On
# 7                           Off      AHBC                     On
# 8                           Off      AHBC                     On
# 9                           Off      AHBC                     On
#
#                                                                  \
#   Lane Keeping Aid Driver Alert System Traffic Sign Recognition
# 0               On                 Off                       On
# 1               On                  On                       On
# 2               On                  On                      Off
# 3               On                  On                      Off
# 4               On                  On                      Off
# 5               On                  On                      Off
# 6               On                  On                       On
# 7               On                  On                       On
# 8               On                  On                      Off
# 9               On                  On                       On
#
#                                                                              \
#   Traffic Sign Recognition Mode Traffic Sign Recognition Feature LKS Switch
# 0                   Camera Only                             SLIF    Network
# 1                        Fusion                             SLIF    Network
# 2                        Fusion                              Off    Network
# 3                        Fusion                              Off    Network
# 4                        Fusion                              Off    Network
# 5                        Fusion                              Off    Network
# 6                        Fusion                             SLIF    Network
# 7                        Fusion                             SLIF    Network
# 8                        Fusion                              Off    Network
# 9                        Fusion                             SLIF    Network
#
#                                                                           \
#   Pre-Collision Assist Type   Enable ACC Driving Side Region and Country
# 0              Radar Fusion          Off         Left               0x25
# 1              Radar Fusion  RadarFusion        Right               0x7A
# 2              Radar Fusion  RadarFusion        Right               0x76
# 3              Radar Fusion  RadarFusion        Right               0x76
# 4               Camera Only          Off        Right               0x75
# 5               Camera Only          Off        Right               0x75
# 6              Radar Fusion  RadarFusion        Right               0x7A
# 7              Radar Fusion  RadarFusion        Right               0x4A
# 8               Camera Only          Off        Right               0x75
# 9              Radar Fusion  RadarFusion        Right               0x7A
#
#                                                                                \
#   Enable TJA Windshield Type LKS Actuator Shift by Wire Speed Limit Sign Unit
# 0        Off        Acoustic         EPAS           Off                   MPH
# 1         On       IR Coated         EPAS            On                   MPH
# 2         On        Acoustic         EPAS            On                   MPH
# 3         On        Acoustic         EPAS            On                   MPH
# 4        Off       IR Coated         EPAS            On                   MPH
# 5        Off        Acoustic         EPAS            On                   MPH
# 6         On       IR Coated         EPAS            On                   MPH
# 7         On       IR Coated         EPAS            On                   KPH
# 8        Off       IR Coated         EPAS            On                   MPH
# 9         On       IR Coated         EPAS            On                   MPH
#
#   PowerSteeringControlModule                                      \
#       Lane Departure Warning Lane Keeping Aid Traffic Jam Assist
# 0                    Enabled          Enabled           Disabled
# 1                    Enabled          Enabled            Enabled
# 2                    Enabled          Enabled            Enabled
# 3                    Enabled          Enabled            Enabled
# 4                    Enabled          Enabled           Disabled
# 5                    Enabled          Enabled           Disabled
# 6                    Enabled          Enabled            Enabled
# 7                    Enabled          Enabled            Enabled
# 8                    Enabled          Enabled           Disabled
# 9                    Enabled          Enabled            Enabled
#
#                         AntiLockBrakeSystem                              \
#   Lane Centering Assist          Wheel Base                     Payload
# 0              Disabled            Reserved         Mid Payload Upgrade
# 1               Enabled            Reserved  Heavy Duty Payload Upgrade
# 2               Enabled            Reserved  Heavy Duty Payload Upgrade
# 3               Enabled               122in         Mid Payload Upgrade
# 4              Disabled            Reserved         Mid Payload Upgrade
# 5              Disabled            Reserved                Base Payload
# 6               Enabled            Reserved              Unknown (0x04)
# 7               Enabled            Reserved              Unknown (0x04)
# 8              Disabled            Reserved         Mid Payload Upgrade
# 9               Enabled            Reserved  Heavy Duty Payload Upgrade
#
#                                                            \
#   Steering Gear Tire Size Cruise Control Mode Stop and Go
# 0     EPAS 21:1  Reserved              Normal     Without
# 1     EPAS 17:1  Reserved      Unknown (0x01)     Without
# 2     EPAS 17:1   17/18in      Unknown (0x01)     Without
# 3     EPAS 17:1      20in            Adaptive     Without
# 4     EPAS 17:1  Reserved      Unknown (0x01)     Without
# 5     EPAS 17:1  Reserved      Unknown (0x01)     Without
# 6      Reserved  Reserved      Unknown (0x01)     Without
# 7      Reserved  Reserved      Unknown (0x01)     Without
# 8     EPAS 17:1  Reserved      Unknown (0x01)     Without
# 9     EPAS 17:1  Reserved      Unknown (0x01)     Without
#
#                                            AccessoryProtocolInterfaceModule  \
#   Collision Mitigation by Braking (CMbB) Steering Wheel Angle Sensor (SWAS)
# 0                                Without                           Absolute
# 1                                Without                           Absolute
# 2                                Without                           Absolute
# 3                                   With                           Absolute
# 4                                Without                           Absolute
# 5                                Without                           Absolute
# 6                                Without                           Absolute
# 7                                Without                           Absolute
# 8                                Without                           Absolute
# 9                                Without                           Absolute
#
#                                                                  \
#   Brand Identification Hybrid (HEV) Transmission Type Fuel Type
# 0                 Ford           No            Manual  Gasoline
# 1              Lincoln           No         Automatic  Gasoline
# 2                 Ford          Yes         Automatic  Gasoline
# 3                 Ford           No         Automatic  Gasoline
# 4                 Ford           No         Automatic  Gasoline
# 5                 Ford           No         Automatic  Gasoline
# 6                 Ford          Yes         Automatic  Gasoline
# 7                 Ford          Yes         Automatic  Gasoline
# 8                 Ford           No         Automatic  Gasoline
# 9                 Ford           No         Automatic  Gasoline
#
#                                                                       \
#   Plug-in Hybrid (PHEV) Common Global Electrical Architecture (CGEA)
# 0                    No                                     CGEA 1.3
# 1                    No                                     CGEA 1.3
# 2                    No                                     CGEA 1.3
# 3                    No                                     CGEA 1.3
# 4                    No                                     CGEA 1.3
# 5                    No                                     CGEA 1.3
# 6                    No                                     CGEA 1.3
# 7                    No                                     CGEA 1.3
# 8                    No                                     CGEA 1.3
# 9                    No                                     CGEA 1.3
#
#                                                                               \
#   Heated Windshield Country Code (First Letter) Country Code (Second Letter)
# 0               Yes                           U                            K
# 1                No                           U                            S
# 2                No                           U                            S
# 3                No                           U                            S
# 4                No                           U                            S
# 5                No                           U                            S
# 6                No                           U                            S
# 7                No                           C                            A
# 8                No                           U                            S
# 9                No                           U                            S
#
#                                                                               \
#           Vehicle Style GPS Antenna Location/Mount Type     Electric Vehicle
# 0                 Focus         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 1  Large Commercial Van         Roof Mount (UK Default)       U611 (Aviator)
# 2               SUV/CUV         Roof Mount (UK Default)  CX482 (Escape/Kuga)
# 3               SUV/CUV         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 4               SUV/CUV         Roof Mount (UK Default)      U625 (Explorer)
# 5               SUV/CUV         Roof Mount (UK Default)  CX482 (Escape/Kuga)
# 6               SUV/CUV         Roof Mount (UK Default)      U625 (Explorer)
# 7               SUV/CUV         Roof Mount (UK Default)      U625 (Explorer)
# 8               SUV/CUV         Roof Mount (UK Default)      U625 (Explorer)
# 9               SUV/CUV         Roof Mount (UK Default)      U625 (Explorer)
#
#                                                                          \
#   Drivetrain Type Bluetooth Vehicle Nameplate ID Front Track Rear Track
# 0             FWD                     Ford Focus    64.05 in   64.05 in
# 1             AWD                Lincoln Aviator    68.45 in   68.20 in
# 2             FWD                    Ford Escape    61.50 in   61.60 in
# 3             AWD                      Ford Edge    70.75 in   70.67 in
# 4             AWD                  Ford Explorer    68.45 in   68.20 in
# 5             FWD                    Ford Escape    61.50 in   61.60 in
# 6             AWD                  Ford Explorer    68.45 in   68.20 in
# 7             AWD                  Ford Explorer    68.45 in   68.20 in
# 8             RWD                  Ford Explorer    68.45 in   68.20 in
# 9             AWD                  Ford Explorer    68.45 in   68.20 in
#
#                                                                               \
#   Wheel Base Wheel Base (cont.) Vehicle Weight Distance from IP to Rear Axle
# 0   97.28 in          + 0.83 in        1100 kg                Unknown (0x00)
# 1  117.76 in          + 1.33 in        2900 kg                Unknown (0x00)
# 2  104.96 in          + 0.95 in        2000 kg                Unknown (0x00)
# 3  110.08 in          + 1.97 in         800 kg                Unknown (0x00)
# 4  117.76 in          + 1.33 in        2600 kg                Unknown (0x00)
# 5  104.96 in          + 0.95 in        1900 kg                Unknown (0x00)
# 6  117.76 in          + 1.33 in        2900 kg                Unknown (0x00)
# 7  117.76 in          + 1.33 in        2900 kg                Unknown (0x00)
# 8  117.76 in          + 1.33 in        2600 kg                Unknown (0x00)
# 9  117.76 in          + 1.33 in        2700 kg                Unknown (0x00)
#
#                                                                              \
#   Distance from IP to Rear Axle (cont.)  ACC Menu Forward Collision Warning
# 0                        Unknown (0x61)   Enabled                      None
# 1                        Unknown (0x76)   Enabled                       FCW
# 2                        Unknown (0x88)   Enabled                       FCW
# 3                        Unknown (0x70)  Disabled                      None
# 4                        Unknown (0x76)  Disabled                       FCW
# 5                        Unknown (0x88)  Disabled                      None
# 6                        Unknown (0x76)   Enabled                       FCW
# 7                        Unknown (0x76)   Enabled                       FCW
# 8                        Unknown (0x76)  Disabled                       FCW
# 9                        Unknown (0x76)   Enabled                       FCW
#
#                                                        \
#    FCW Menu FCW Braking Evasive Steering Assist (ESA)
# 0   Enabled     Enabled                       Enabled
# 1  Disabled     Enabled                       Enabled
# 2  Disabled     Enabled                       Enabled
# 3  Disabled    Disabled                      Disabled
# 4  Disabled     Enabled                      Disabled
# 5  Disabled     Enabled                      Disabled
# 6  Disabled     Enabled                       Enabled
# 7  Disabled     Enabled                       Enabled
# 8  Disabled     Enabled                      Disabled
# 9  Disabled     Enabled                       Enabled
#
#                                                                \
#   Lane Change Assist (LCA) Lane Keeping Sensitivity  ACC Mode
# 0                  Enabled                  Enabled   Enabled
# 1                  Enabled                 Disabled   Enabled
# 2                  Enabled                 Disabled   Enabled
# 3                 Disabled                 Disabled  Disabled
# 4                  Enabled                 Disabled  Disabled
# 5                  Enabled                 Disabled  Disabled
# 6                  Enabled                 Disabled   Enabled
# 7                  Enabled                 Disabled   Enabled
# 8                  Enabled                 Disabled  Disabled
# 9                  Enabled                 Disabled   Enabled
#
#
#      Lane Assist NCAP Aid Lane Assist NCAP Alert
# 0  Off, Reduced, Enhanced      High, Normal, Low
# 1                Disabled               Disabled
# 2                Disabled               Disabled
# 3                Disabled               Disabled
# 4                Disabled               Disabled
# 5                Disabled               Disabled
# 6                Disabled               Disabled
# 7                Disabled               Disabled
# 8                Disabled               Disabled
# 9                Disabled               Disabled

# %%
from settings import VehicleSettings

important_settings = [
  VehicleSettings.ipma_vehicle,
  # VehicleSettings.ipma_driving_side,
  VehicleSettings.ipma_enable_adaptive_cruise,
  VehicleSettings.ipma_enable_traffic_jam_assist,
  VehicleSettings.ipma_shift_by_wire,
  VehicleSettings.ipma_speed_limit_sign_unit,

  VehicleSettings.pscm_traffic_jam_assist,
  VehicleSettings.pscm_lane_centering_assist,

  VehicleSettings.abs_cruise_control_mode,
  VehicleSettings.abs_steering_gear,

  VehicleSettings.apim_country_code_first_letter,
  VehicleSettings.apim_country_code_second_letter,
  VehicleSettings.apim_lane_change_assist,
  VehicleSettings.apim_adaptive_cruise_mode,
  VehicleSettings.apim_transmission_type,
  VehicleSettings.apim_fuel_type,
  VehicleSettings.apim_wheel_base,
  VehicleSettings.apim_wheel_base_cont,
  VehicleSettings.apim_vehicle_weight,
]

rows = []
for vin in ('WF0NXXGCHNJR69712', 'WF0NXXGCHNKD75963', 'RHAETAGEXN2000154', *random.sample(vins, 19)):
  abd = AsBuiltData.from_vin(vin)
  rows.append([vin, *map(lambda s: abd.get_setting_value(s), important_settings)])

columns = [('', 'VIN'), *map(lambda s: (s.ecu.name, s.comment), important_settings)]

df = pd.DataFrame(rows, columns=pd.MultiIndex.from_tuples(columns))
df
# Out:
#                             ImageProcessingModuleA                             \
#                   VIN                      Vehicle      Enable ACC Enable TJA
# 0   WF0NXXGCHNJR69712                 C519 (Focus)             Off        Off
# 1   WF0NXXGCHNKD75963                 C519 (Focus)             Off        Off
# 2   RHAETAGEXN2000154          CX482 (Escape/Kuga)     RadarFusion         On
# 3   2FMPK4G9XNBA97732                 CD539 (Edge)             Off        Off
# 4   1FADP3H23HL214937                      Missing         Missing    Missing
# 5   3FMCR9B69NRD56961  CX430 (Bronco Sport OnRoad)             Off        Off
# 6   1FMCU9H60NUA95251          CX482 (Escape/Kuga)             Off        Off
# 7   1FMSK8DH3NGA52377              U625 (Explorer)             Off        Off
# 8   2FMPK4J97NBA93842                 CD539 (Edge)             Off        Off
# 9   1FADP3H29JL265364                      Missing         Missing    Missing
# 10  1FM5K7FWXMNA21754              U625 (Explorer)     RadarFusion         On
# 11  2FMPK4K98RBA51359                 CD539 (Edge)             Off        Off
# 12  1FMSK8DH1LGC57192              U625 (Explorer)             Off        Off
# 13  1FADP3M2XHL223494                      Missing         Missing    Missing
# 14  3FMCR9C63RRE24157  CX430 (Bronco Sport OnRoad)             Off        Off
# 15  1FMSK8DH6NGB82394              U625 (Explorer)     RadarFusion         On
# 16  1FMCU0F73JUC28280                      Missing         Missing    Missing
# 17  1FMCU9DZ3MUA04312          CX482 (Escape/Kuga)     RadarFusion         On
# 18  1FTFW1E87PFC20899       P702 (F-150 Lightning)  Unknown (0x03)  Undefined
# 19  1FMCU9MN0RUA09195       P702 (F-150 Lightning)     RadarFusion  Undefined
# 20  1FMSK7BH9LGD13005              U625 (Explorer)             Off        Off
# 21  2FMPK3G95MBA64808                 CD539 (Edge)             Off        Off
#
#                                        PowerSteeringControlModule  \
#    Shift by Wire Speed Limit Sign Unit         Traffic Jam Assist
# 0            Off                   MPH                   Disabled
# 1            Off                   KPH                   Disabled
# 2             On                   KPH                    Enabled
# 3             On                   MPH                   Disabled
# 4        Missing               Missing                    Missing
# 5             On                   MPH                   Disabled
# 6             On                   MPH                   Disabled
# 7             On                   MPH                   Disabled
# 8             On                   MPH                   Disabled
# 9        Missing               Missing                    Missing
# 10            On                   MPH                    Enabled
# 11            On                   MPH                   Disabled
# 12            On                   MPH                   Disabled
# 13       Missing               Missing                    Missing
# 14            On                   MPH                   Disabled
# 15            On                   MPH                    Enabled
# 16       Missing               Missing                    Missing
# 17            On                   MPH                    Enabled
# 18     Undefined             Undefined                    Enabled
# 19     Undefined             Undefined                    Enabled
# 20            On                   MPH                   Disabled
# 21            On                   MPH                   Disabled
#
#                          AntiLockBrakeSystem                \
#    Lane Centering Assist Cruise Control Mode Steering Gear
# 0               Disabled              Normal     EPAS 21:1
# 1               Disabled              Normal     EPAS 21:1
# 2                Enabled      Unknown (0x01)      Reserved
# 3               Disabled            Adaptive     EPAS 17:1
# 4                Missing             Missing       Missing
# 5               Disabled              Normal     EPAS 17:1
# 6               Disabled              Normal     EPAS 17:1
# 7               Disabled      Unknown (0x01)     EPAS 17:1
# 8               Disabled            Adaptive     EPAS 17:1
# 9                Missing             Missing       Missing
# 10               Enabled      Unknown (0x01)      Reserved
# 11              Disabled            Adaptive     EPAS 17:1
# 12              Disabled      Unknown (0x01)     EPAS 17:1
# 13               Missing             Missing       Missing
# 14              Disabled              Normal     EPAS 17:1
# 15               Enabled      Unknown (0x01)     EPAS 17:1
# 16               Missing             Missing       Missing
# 17               Enabled              Normal     EPAS 17:1
# 18               Enabled              Normal     EPAS 17:1
# 19               Enabled              Normal     EPAS 17:1
# 20              Disabled      Unknown (0x01)     EPAS 17:1
# 21              Disabled            Adaptive     EPAS 17:1
#
#    AccessoryProtocolInterfaceModule                               \
#         Country Code (First Letter) Country Code (Second Letter)
# 0                                 U                            K
# 1                                 F                            R
# 2                                 T                            W
# 3                    Unknown (0x04)               Unknown (0x02)
# 4                                 U                            S
# 5                                 U                            S
# 6                                 U                            S
# 7                                 U                            S
# 8                    Unknown (0x04)               Unknown (0x02)
# 9                                 U                            S
# 10                                U                            S
# 11                   Unknown (0x04)               Unknown (0x02)
# 12                                U                            S
# 13                                U                            S
# 14                                U                            S
# 15                                U                            S
# 16                   Unknown (0x04)                            U
# 17                                U                            S
# 18                   Unknown (0x86)               Unknown (0x16)
# 19                   Unknown (0x04)               Unknown (0x12)
# 20                                U                            S
# 21                   Unknown (0x04)               Unknown (0x02)
#
#                                                                          \
#    Lane Change Assist (LCA)  ACC Mode Transmission Type       Fuel Type
# 0                   Enabled   Enabled            Manual        Gasoline
# 1                  Disabled  Disabled            Manual          Diesel
# 2                   Enabled   Enabled         Automatic        Gasoline
# 3                  Disabled  Disabled         Automatic  Electric (BEV)
# 4                   Missing   Missing         Automatic        Gasoline
# 5                   Enabled  Disabled         Automatic        Gasoline
# 6                   Enabled  Disabled         Automatic        Gasoline
# 7                   Enabled  Disabled         Automatic        Gasoline
# 8                  Disabled  Disabled         Automatic  Electric (BEV)
# 9                   Missing   Missing         Automatic        Gasoline
# 10                  Enabled   Enabled         Automatic        Gasoline
# 11                 Disabled  Disabled         Automatic  Electric (BEV)
# 12                  Enabled  Disabled         Automatic        Gasoline
# 13                  Missing   Missing         Automatic        Gasoline
# 14                  Enabled  Disabled         Automatic        Gasoline
# 15                  Enabled   Enabled         Automatic        Gasoline
# 16                  Missing   Missing         Automatic        Gasoline
# 17                  Enabled   Enabled         Automatic        Gasoline
# 18                  Enabled   Enabled         Automatic  Electric (BEV)
# 19                  Enabled   Enabled         Automatic  Electric (BEV)
# 20                  Enabled  Disabled         Automatic        Gasoline
# 21                 Disabled  Disabled         Automatic  Electric (BEV)
#
#
#    Wheel Base Wheel Base (cont.) Vehicle Weight
# 0    97.28 in          + 0.83 in        1100 kg
# 1    97.28 in          + 0.83 in        1100 kg
# 2   104.96 in          + 0.95 in        2000 kg
# 3     0.00 in          + 0.00 in        2500 kg
# 4   102.40 in          + 1.90 in        1600 kg
# 5   104.96 in          + 0.14 in        2100 kg
# 6   104.96 in          + 0.95 in        2000 kg
# 7   117.76 in          + 1.33 in        2600 kg
# 8     0.00 in          + 0.00 in        2500 kg
# 9   102.40 in          + 1.90 in        1600 kg
# 10  117.76 in          + 1.33 in        2900 kg
# 11    0.00 in          + 0.00 in        2500 kg
# 12  117.76 in          + 1.33 in        2600 kg
# 13  102.40 in          + 1.90 in        1600 kg
# 14  104.96 in          + 0.14 in        2100 kg
# 15  117.76 in          + 1.33 in        2600 kg
# 16    Missing            Missing        Missing
# 17  104.96 in          + 0.95 in        2100 kg
# 18    0.00 in          + 0.00 in        3200 kg
# 19    0.00 in          + 0.00 in        2000 kg
# 20  117.76 in          + 1.33 in        2600 kg
# 21    0.00 in          + 0.00 in        2400 kg
