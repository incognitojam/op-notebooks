# %%
# %load_ext autoreload
# %autoreload 2

# %%
from vins import load_vins

vins = load_vins()
# Out:
# Loaded 1263 VINs (filter_comment=None, include_openpilot=False, skipped=80)
# Loaded AsBuilt data for 1263 VINs

# %%
import random

import pandas as pd

from asbuilt import AsBuiltData
from settings import VEHICLE_SETTINGS

pd.set_option('display.max_columns', None)

rows = []
for vin in ('WF0NXXGCHNJR69712', *random.sample(vins, 9)):
  abd = AsBuiltData.from_vin(vin)
  rows.append([vin, *map(lambda s: abd.get_setting_value(s), VEHICLE_SETTINGS)])

columns = [('', 'VIN'), *map(lambda s: (s.ecu.name, s.comment), VEHICLE_SETTINGS)]

df = pd.DataFrame(rows, columns=pd.MultiIndex.from_tuples(columns))
df
# Out:
#                       ImageProcessingModuleA                 \
#                  VIN                 Vehicle Distance Alert
# 0  WF0NXXGCHNJR69712            C519 (Focus)            Off
# 1  MAJ6S3GL0LC331448                 Missing        Missing
# 2  1FMCU0H60LUB10243     CX482 (Escape/Kuga)            Off
# 3  3FMTK3SU9MMA03647  CX733 (Mustang Mach-E)      Undefined
# 4  1FMSK7DH4MGA12138         U625 (Explorer)             On
# 5  2FMPK4J98NBA17479            CD539 (Edge)             On
# 6  1FMJU1MT4MEA23661   U553 (Expedition SBW)             On
# 7  1FM5K8FW9MNA10878         U625 (Explorer)             On
# 8  1FMCU9GN4RUA09129                    None      Undefined
# 9  1FMCU9H62MUA77204     CX482 (Escape/Kuga)            Off
#
#                                                                    \
#   Forward Collision Warning HUD  High Beam Lane Departure Warning
# 0                           Off        Off                     On
# 1                       Missing    Missing                Missing
# 2                           Off       AHBC                     On
# 3                            On  Undefined                    Off
# 4                           Off       AHBC                     On
# 5                           Off       AHBC                     On
# 6                           Off       AHBC                     On
# 7                           Off       AHBC                     On
# 8                     Undefined  Undefined                    Off
# 9                           Off       AHBC                     On
#
#                                                                  \
#   Lane Keeping Aid Driver Alert System Traffic Sign Recognition
# 0               On                 Off                       On
# 1          Missing             Missing                  Missing
# 2               On                  On                      Off
# 3              Off           Undefined                       On
# 4               On                  On                       On
# 5               On                  On                      Off
# 6               On                  On                      Off
# 7               On                  On                       On
# 8              Off           Undefined                       On
# 9               On                  On                      Off
#
#                                                                              \
#   Traffic Sign Recognition Mode Traffic Sign Recognition Feature LKS Switch
# 0                   Camera Only                             SLIF    Network
# 1                       Missing                          Missing    Missing
# 2                        Fusion                              Off    Network
# 3                   Camera Only                              Off    Network
# 4                        Fusion                             SLIF    Network
# 5                        Fusion                              Off    Network
# 6                        Fusion                              Off     Direct
# 7                        Fusion                             SLIF    Network
# 8                   Camera Only                             SLIF  Undefined
# 9                        Fusion                              Off    Network
#
#                                                                           \
#   Pre-Collision Assist Type   Enable ACC Driving Side Region and Country
# 0              Radar Fusion          Off         Left               0x25
# 1                   Missing      Missing      Missing            Missing
# 2               Camera Only          Off        Right               0x75
# 3              Radar Fusion  RadarFusion         Left               0x00
# 4              Radar Fusion  RadarFusion        Right               0x7A
# 5              Radar Fusion  RadarFusion        Right               0x76
# 6              Radar Fusion  RadarFusion        Right               0x75
# 7              Radar Fusion  RadarFusion        Right               0x7A
# 8                 Undefined  RadarFusion    Undefined               0x00
# 9               Camera Only          Off        Right               0x75
#
#                                                                                \
#   Enable TJA Windshield Type LKS Actuator Shift by Wire Speed Limit Sign Unit
# 0        Off        Acoustic         EPAS           Off                   MPH
# 1    Missing         Missing      Missing       Missing               Missing
# 2        Off        Acoustic         EPAS            On                   MPH
# 3  Undefined       Undefined    Undefined     Undefined             Undefined
# 4         On       IR Coated         EPAS            On                   MPH
# 5         On        Acoustic         EPAS            On                   MPH
# 6        Off        Acoustic         EPAS            On                   MPH
# 7         On       IR Coated         EPAS            On                   MPH
# 8  Undefined       Undefined    Undefined     Undefined             Undefined
# 9        Off        Acoustic         EPAS            On                   MPH
#
#   AntiLockBrakeSystem                                    \
#     Wheel base preset Steering Gear Cruise Control Mode
# 0            Reserved     EPAS 21:1              Normal
# 1            Reserved     EPAS 21:1      Unknown (0x07)
# 2            Reserved     EPAS 17:1      Unknown (0x01)
# 3            Reserved     EPAS 17:1      Unknown (0x01)
# 4            Reserved     EPAS 17:1      Unknown (0x01)
# 5               122in     EPAS 17:1            Adaptive
# 6               122in      Reserved      Unknown (0x00)
# 7            Reserved      Reserved      Unknown (0x01)
# 8            Reserved     EPAS 17:1              Normal
# 9            Reserved     EPAS 17:1              Normal
#
#                                            AccessoryProtocolInterfaceModule  \
#   Collision Mitigation by Braking (CMbB) Steering Wheel Angle Sensor (SWAS)
# 0                                Without                           Absolute
# 1                                Missing                           Absolute
# 2                                Without                           Absolute
# 3                                Without                           Absolute
# 4                                Without                           Absolute
# 5                                   With                           Absolute
# 6                                   With                           Absolute
# 7                                Without                           Absolute
# 8                                Without                           Relative
# 9                                Without                           Absolute
#
#                                                                  \
#   Brand Identification Hybrid (HEV) Transmission Type Fuel Type
# 0                 Ford           No            Manual    Diesel
# 1                 Ford           No         Automatic  Gasoline
# 2                 Ford           No         Automatic  Gasoline
# 3                 Ford          Yes         Automatic  Gasoline
# 4                 Ford           No         Automatic  Gasoline
# 5                 Ford           No         Automatic  Gasoline
# 6                 Ford           No         Automatic  Gasoline
# 7                 Ford          Yes         Automatic  Gasoline
# 8                 Ford           No         Automatic  Gasoline
# 9                 Ford           No         Automatic  Gasoline
#
#                                                                       \
#   Plug-in Hybrid (PHEV) Common Global Electrical Architecture (CGEA)
# 0                    No                                     CGEA 1.3
# 1                    No                                     CGEA 1.3
# 2                    No                                     CGEA 1.3
# 3                    No                                     CGEA 1.3
# 4                    No                                     CGEA 1.3
# 5                    No                            CGEA 1.2 or C1MCA
# 6                    No                                     CGEA 1.3
# 7                    No                                     CGEA 1.3
# 8                    No                            CGEA 1.2 or C1MCA
# 9                    No                                     CGEA 1.3
#
#                                                                               \
#   Heated Windshield Country Code (First Letter) Country Code (Second Letter)
# 0               Yes                           U                            K
# 1                No                           U                            S
# 2                No                           U                            S
# 3                No              Unknown (0x04)               Unknown (0x02)
# 4                No                           U                            S
# 5                No              Unknown (0x04)               Unknown (0x02)
# 6                No                           U                            S
# 7                No                           U                            S
# 8                No              Unknown (0x04)               Unknown (0x12)
# 9                No                           U                            S
#
#                                                                         \
#     Vehicle Style GPS Antenna Location/Mount Type     Electric Vehicle
# 0           Focus         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 1        EcoSport         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 2         SUV/CUV         Roof Mount (UK Default)  CX482 (Escape/Kuga)
# 3  Unknown (0x8B)                  Unknown (0x05)       Unknown (0x53)
# 4         SUV/CUV         Roof Mount (UK Default)      U625 (Explorer)
# 5  Unknown (0x8A)                  Unknown (0x05)       Unknown (0x53)
# 6         SUV/CUV         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 7         SUV/CUV         Roof Mount (UK Default)      U625 (Explorer)
# 8          Fiesta                  Unknown (0x05)       Unknown (0x53)
# 9         SUV/CUV         Roof Mount (UK Default)  CX482 (Escape/Kuga)
#
#                                                                          \
#   Drivetrain Type Bluetooth Vehicle Nameplate ID Front Track Rear Track
# 0             FWD                     Ford Focus    64.05 in   64.05 in
# 1             AWD                  Ford EcoSport    64.00 in   64.00 in
# 2             FWD                    Ford Escape    61.50 in   61.60 in
# 3             AWD                           SYNC   116.50 in  143.36 in
# 4             RWD                  Ford Explorer    68.45 in   68.20 in
# 5      Dually 2WD                           SYNC     2.62 in  122.88 in
# 6             4WD                Ford Expedition    67.00 in   67.20 in
# 7             AWD                  Ford Explorer    68.45 in   68.20 in
# 8      Dually 2WD                           SYNC     0.01 in   10.24 in
# 9             AWD                    Ford Escape    61.50 in   61.60 in
#
#                                                                               \
#   Wheel Base Wheel Base (cont.) Vehicle Weight Distance from IP to Rear Axle
# 0   97.28 in          + 0.83 in        1100 kg                Unknown (0x00)
# 1   97.28 in          + 1.72 in        1400 kg                Unknown (0x00)
# 2  104.96 in          + 0.95 in        1900 kg                Unknown (0x00)
# 3    0.00 in          + 0.00 in        2600 kg                Unknown (0x00)
# 4  117.76 in          + 1.33 in        2600 kg                Unknown (0x00)
# 5    0.00 in          + 0.00 in        2500 kg                Unknown (0x00)
# 6  120.32 in          + 2.18 in        3400 kg                Unknown (0x00)
# 7  117.76 in          + 1.33 in        2900 kg                Unknown (0x00)
# 8    0.00 in          + 0.00 in        2000 kg                Unknown (0x00)
# 9  104.96 in          + 0.95 in        2000 kg                Unknown (0x00)
#
#                                                                              \
#   Distance from IP to Rear Axle (cont.)  ACC Menu Forward Collision Warning
# 0                        Unknown (0x61)   Enabled                      None
# 1                        Unknown (0x6B)  Disabled                      None
# 2                        Unknown (0x88)  Disabled                       FCW
# 3                        Unknown (0x72)   Enabled                       FCW
# 4                        Unknown (0x76)   Enabled                       FCW
# 5                        Unknown (0x80)  Disabled                      None
# 6                        Unknown (0x76)  Disabled                      None
# 7                        Unknown (0x76)   Enabled                       FCW
# 8                        Unknown (0x88)  Disabled                       FCW
# 9                        Unknown (0x88)  Disabled                       FCW
#
#                                                        \
#    FCW Menu FCW Braking Evasive Steering Assist (ESA)
# 0   Enabled     Enabled                       Enabled
# 1  Disabled    Disabled                      Disabled
# 2  Disabled     Enabled                      Disabled
# 3  Disabled     Enabled                       Enabled
# 4  Disabled     Enabled                       Enabled
# 5  Disabled    Disabled                      Disabled
# 6  Disabled    Disabled                      Disabled
# 7  Disabled     Enabled                       Enabled
# 8  Disabled     Enabled                      Disabled
# 9  Disabled     Enabled                      Disabled
#
#                                                                \
#   Lane Change Assist (LCA) Lane Keeping Sensitivity  ACC Mode
# 0                  Enabled                  Enabled   Enabled
# 1                 Disabled                 Disabled  Disabled
# 2                  Enabled                 Disabled  Disabled
# 3                  Enabled                 Disabled   Enabled
# 4                  Enabled                 Disabled   Enabled
# 5                 Disabled                 Disabled  Disabled
# 6                 Disabled                 Disabled  Disabled
# 7                  Enabled                 Disabled   Enabled
# 8                  Enabled                 Disabled  Disabled
# 9                  Enabled                 Disabled  Disabled
#
#
#      Lane Assist NCAP Aid Lane Assist NCAP Alert
# 0  Off, Reduced, Enhanced      High, Normal, Low
# 1                Disabled               Disabled
# 2                Disabled               Disabled
# 3                Disabled               Disabled
# 4                Disabled               Disabled
# 5                Disabled               Disabled
# 6                Disabled               Disabled
# 7                Disabled               Disabled
# 8                Disabled               Disabled
# 9                Disabled               Disabled

# %%
from settings import VehicleSettings

important_settings = [
  VehicleSettings.ipma_vehicle,
  # VehicleSettings.ipma_driving_side,
  VehicleSettings.ipma_enable_adaptive_cruise,
  VehicleSettings.ipma_enable_traffic_jam_assist,
  VehicleSettings.ipma_shift_by_wire,
  VehicleSettings.ipma_speed_limit_sign_unit,

  VehicleSettings.abs_cruise_control_mode,
  VehicleSettings.abs_steering_gear,

  VehicleSettings.apim_country_code_first_letter,
  VehicleSettings.apim_country_code_second_letter,
  VehicleSettings.apim_lane_change_assist,
  VehicleSettings.apim_adaptive_cruise_mode,
  VehicleSettings.apim_transmission_type,
  VehicleSettings.apim_fuel_type,
  VehicleSettings.apim_wheel_base,
  VehicleSettings.apim_wheel_base_cont,
  VehicleSettings.apim_vehicle_weight,
]

rows = []
for vin in ('WF0NXXGCHNJR69712', *random.sample(vins, 19)):
  abd = AsBuiltData.from_vin(vin)
  rows.append([vin, *map(lambda s: abd.get_setting_value(s), important_settings)])

columns = [('', 'VIN'), *map(lambda s: (s.ecu.name, s.comment), important_settings)]

df = pd.DataFrame(rows, columns=pd.MultiIndex.from_tuples(columns))
df
# Out:
#                             ImageProcessingModuleA                          \
#                   VIN                      Vehicle   Enable ACC Enable TJA
# 0   WF0NXXGCHNJR69712                 C519 (Focus)          Off        Off
# 1   1FMSK8BH8LGB76905              U625 (Explorer)          Off        Off
# 2   1FM5K7FWXMNA21754              U625 (Explorer)  RadarFusion         On
# 3   1FMSK7FH9MGC17970              U625 (Explorer)  RadarFusion         On
# 4   3FA6P0HD9JR224016                      Missing      Missing    Missing
# 5   1FMCU9J93LUA40908          CX482 (Escape/Kuga)  RadarFusion         On
# 6   2FMPK4K96MBA39185                 CD539 (Edge)  RadarFusion         On
# 7   2FMPK3G90JBB51530                      Missing      Missing    Missing
# 8   1FATP8UH7M5102563           S550 (Mustang LHD)          Off        Off
# 9   3FMCR9B63RRE16920  CX430 (Bronco Sport OnRoad)          Off        Off
# 10  1FMCU9BZ0MUA67743          CX482 (Escape/Kuga)          Off        Off
# 11  5LMYJ8XY5LGL31249       U611 (Lincoln Aviator)  RadarFusion         On
# 12  2FMPK3G93JBB36097                      Missing      Missing    Missing
# 13  1FMCU0DZ0LUA12197          CX482 (Escape/Kuga)  RadarFusion         On
# 14  3FTTW8F97NRA00360              P758 (Maverick)          Off        Off
# 15  3FMCR9B69RRE56130  CX430 (Bronco Sport OnRoad)          Off        Off
# 16  1FMCU9J97LUB24956          CX482 (Escape/Kuga)  RadarFusion         On
# 17  1FMSK8DH9LGB63898              U625 (Explorer)  RadarFusion         On
# 18  1FTFW1E85PKF54629                         None  RadarFusion  Undefined
# 19  1FMCU9DZ5MUB04928          CX482 (Escape/Kuga)  RadarFusion         On
#
#                                        AntiLockBrakeSystem                  \
#    Shift by Wire Speed Limit Sign Unit Cruise Control Mode   Steering Gear
# 0            Off                   MPH              Normal       EPAS 21:1
# 1             On                   MPH      Unknown (0x01)       EPAS 17:1
# 2             On                   MPH      Unknown (0x01)        Reserved
# 3             On                   MPH      Unknown (0x01)       EPAS 17:1
# 4        Missing               Missing            Adaptive  Unknown (0x03)
# 5             On                   MPH              Normal       EPAS 17:1
# 6             On                   MPH            Adaptive       EPAS 17:1
# 7        Missing               Missing            Adaptive  Unknown (0x03)
# 8            Off                   KPH              Normal       EPAS 17:1
# 9             On                   MPH              Normal       EPAS 17:1
# 10            On                   MPH              Normal       EPAS 17:1
# 11            On                   MPH      Unknown (0x01)        Reserved
# 12       Missing               Missing            Adaptive  Unknown (0x03)
# 13            On                   MPH      Unknown (0x01)       EPAS 17:1
# 14            On                   MPH              Normal        Reserved
# 15            On                   MPH              Normal       EPAS 17:1
# 16            On                   MPH              Normal       EPAS 17:1
# 17            On                   MPH      Unknown (0x01)       EPAS 17:1
# 18     Undefined             Undefined              Normal       EPAS 17:1
# 19            On                   MPH              Normal       EPAS 17:1
#
#    AccessoryProtocolInterfaceModule                               \
#         Country Code (First Letter) Country Code (Second Letter)
# 0                                 U                            K
# 1                                 U                            S
# 2                                 U                            S
# 3                                 U                            S
# 4                                 U                            S
# 5                                 U                            S
# 6                    Unknown (0x04)               Unknown (0x02)
# 7                    Unknown (0x04)                            U
# 8                                 U                            S
# 9                                 U                            S
# 10                                U                            S
# 11                                U                            S
# 12                   Unknown (0x04)                            U
# 13                                U                            S
# 14                          Missing                      Missing
# 15                                U                            S
# 16                                U                            S
# 17                                U                            S
# 18                   Unknown (0x06)               Unknown (0x16)
# 19                                U                            S
#
#                                                                          \
#    Lane Change Assist (LCA)  ACC Mode Transmission Type       Fuel Type
# 0                   Enabled   Enabled            Manual          Diesel
# 1                   Enabled  Disabled         Automatic        Gasoline
# 2                   Enabled   Enabled         Automatic        Gasoline
# 3                   Enabled   Enabled         Automatic        Gasoline
# 4                   Missing   Missing         Automatic        Gasoline
# 5                   Enabled   Enabled         Automatic        Gasoline
# 6                  Disabled  Disabled         Automatic        Gasoline
# 7                   Missing   Missing         Automatic  Electric (BEV)
# 8                  Disabled  Disabled         Automatic        Gasoline
# 9                   Enabled  Disabled         Automatic        Gasoline
# 10                  Enabled  Disabled         Automatic        Gasoline
# 11                  Enabled   Enabled         Automatic             CNG
# 12                  Missing   Missing         Automatic  Electric (BEV)
# 13                  Enabled   Enabled         Automatic        Gasoline
# 14                  Missing   Missing           Missing         Missing
# 15                  Enabled  Disabled         Automatic        Gasoline
# 16                  Enabled   Enabled         Automatic        Gasoline
# 17                  Enabled   Enabled         Automatic        Gasoline
# 18                  Enabled  Disabled         Automatic        Gasoline
# 19                  Enabled   Enabled         Automatic        Gasoline
#
#
#    Wheel Base Wheel Base (cont.) Vehicle Weight
# 0    97.28 in          + 0.83 in        1100 kg
# 1   117.76 in          + 1.33 in        2600 kg
# 2   117.76 in          + 1.33 in        2900 kg
# 3   117.76 in          + 1.33 in        2600 kg
# 4   110.08 in          + 2.08 in         700 kg
# 5   104.96 in          + 0.95 in        2000 kg
# 6     0.00 in          + 0.00 in        2500 kg
# 7     Missing            Missing        Missing
# 8   104.96 in          + 2.14 in        1600 kg
# 9   104.96 in          + 0.14 in        2100 kg
# 10  104.96 in          + 0.95 in        2100 kg
# 11  117.76 in          + 1.33 in        3200 kg
# 12    Missing            Missing        Missing
# 13  104.96 in          + 0.95 in        2000 kg
# 14    Missing            Missing        Missing
# 15  104.96 in          + 0.14 in        2100 kg
# 16  104.96 in          + 0.95 in        2000 kg
# 17  117.76 in          + 1.33 in        2600 kg
# 18    0.00 in          + 0.00 in        3200 kg
# 19  104.96 in          + 0.95 in        2100 kg
