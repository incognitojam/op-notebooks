# %%
# %load_ext autoreload
# %autoreload 2

# %%
from vins import load_vins

vins = load_vins()
# Out:
# Loaded 1263 VINs (filter_comment=None, include_openpilot=False, skipped=80)
# Loaded AsBuilt data for 1263 VINs

# %%
import random

import pandas as pd

from asbuilt import AsBuiltData
from settings import VEHICLE_SETTINGS

pd.set_option('display.max_columns', None)

rows = []
for vin in ('WF0NXXGCHNJR69712', *random.sample(vins, 9)):
  abd = AsBuiltData.from_vin(vin)
  rows.append([vin, *map(lambda s: abd.get_setting_value(s), VEHICLE_SETTINGS)])

columns = [('', 'VIN'), *map(lambda s: (s.ecu.name, s.comment), VEHICLE_SETTINGS)]

df = pd.DataFrame(rows, columns=pd.MultiIndex.from_tuples(columns))
df
# Out:
#                             ImageProcessingModuleA                 \
#                  VIN                       Vehicle Distance Alert
# 0  WF0NXXGCHNJR69712                  C519 (Focus)            Off
# 1  1FMCU9HD4KUB83004                       Missing        Missing
# 2  1FMCU0F67MUA27879           CX482 (Escape/Kuga)            Off
# 3  2FMPK3G95KBB68227                  CD539 (Edge)            Off
# 4  3FADP4EJ1JM127379                       Missing        Missing
# 5  3FMCR9D93PRE02648  CX430 (Bronco Sport OffRoad)             On
# 6  1FMJK1KT1LEA99684         U553 (Expedition LWB)            Off
# 7  1FMCU0MN4PUA27630                          None      Undefined
# 8  1FMSK7DHXPGA09281               U625 (Explorer)             On
# 9  2FMPK4AP4NBA06672                  CD539 (Edge)            Off
#
#                                                                    \
#   Forward Collision Warning HUD  High Beam Lane Departure Warning
# 0                           Off        Off                     On
# 1                       Missing    Missing                Missing
# 2                           Off       AHBC                     On
# 3                           Off       AHBC                     On
# 4                       Missing    Missing                Missing
# 5                           Off       AHBC                     On
# 6                           Off       AHBC                     On
# 7                     Undefined  Undefined                    Off
# 8                           Off       AHBC                     On
# 9                           Off       AHBC                     On
#
#                                                                  \
#   Lane Keeping Aid Driver Alert System Traffic Sign Recognition
# 0               On                 Off                       On
# 1          Missing             Missing                  Missing
# 2               On                  On                      Off
# 3               On                  On                      Off
# 4          Missing             Missing                  Missing
# 5               On                  On                       On
# 6               On                  On                      Off
# 7              Off           Undefined                       On
# 8               On                  On                       On
# 9               On                  On                      Off
#
#                                                                              \
#   Traffic Sign Recognition Mode Traffic Sign Recognition Feature LKS Switch
# 0                   Camera Only                             SLIF    Network
# 1                       Missing                          Missing    Missing
# 2                        Fusion                              Off    Network
# 3                        Fusion                              Off    Network
# 4                       Missing                          Missing    Missing
# 5                        Fusion                             SLIF    Network
# 6                        Fusion                              Off     Direct
# 7                   Camera Only                             SLIF  Undefined
# 8                        Fusion                             SLIF    Network
# 9                        Fusion                              Off    Network
#
#                                                                           \
#   Pre-Collision Assist Type   Enable ACC Driving Side Region and Country
# 0              Radar Fusion          Off         Left               0x25
# 1                   Missing      Missing      Missing            Missing
# 2               Camera Only          Off        Right               0x75
# 3               Camera Only          Off        Right               0x75
# 4                   Missing      Missing      Missing            Missing
# 5              Radar Fusion  RadarFusion        Right               0x7A
# 6               Camera Only          Off        Right               0x75
# 7                 Undefined  RadarFusion    Undefined               0x00
# 8              Radar Fusion  RadarFusion        Right               0x7A
# 9               Camera Only          Off        Right               0x75
#
#                                                                                \
#   Enable TJA Windshield Type LKS Actuator Shift by Wire Speed Limit Sign Unit
# 0        Off        Acoustic         EPAS           Off                   MPH
# 1    Missing         Missing      Missing       Missing               Missing
# 2        Off        Acoustic         EPAS            On                   MPH
# 3        Off        Acoustic         EPAS            On                   MPH
# 4    Missing         Missing      Missing       Missing               Missing
# 5         On        Acoustic         EPAS            On                   MPH
# 6        Off        Acoustic         EPAS            On                   MPH
# 7  Undefined       Undefined    Undefined     Undefined             Undefined
# 8         On       IR Coated         EPAS            On                   MPH
# 9        Off        Acoustic         EPAS            On                   MPH
#
#   AntiLockBrakeSystem                                      \
#     Wheel base preset   Steering Gear Cruise Control Mode
# 0            Reserved       EPAS 21:1              Normal
# 1             Missing         Missing             Missing
# 2            Reserved       EPAS 17:1      Unknown (0x01)
# 3               141in       EPAS 17:1            Adaptive
# 4               141in  Unknown (0x03)      Unknown (0x00)
# 5            Reserved       EPAS 17:1              Normal
# 6               141in        Reserved      Unknown (0x00)
# 7            Reserved       EPAS 17:1      Unknown (0x01)
# 8            Reserved       EPAS 17:1      Unknown (0x01)
# 9               122in       EPAS 21:1            Adaptive
#
#                                            AccessoryProtocolInterfaceModule  \
#   Collision Mitigation by Braking (CMbB) Steering Wheel Angle Sensor (SWAS)
# 0                                Without                           Absolute
# 1                                Missing                           Absolute
# 2                                Without                           Absolute
# 3                                   With                           Absolute
# 4                                Missing                           Relative
# 5                                Without                           Absolute
# 6                                   With                           Absolute
# 7                                Without                           Relative
# 8                                Without                           Absolute
# 9                                   With                           Absolute
#
#                                                                        \
#   Brand Identification Hybrid (HEV) Transmission Type       Fuel Type
# 0                 Ford           No            Manual        Gasoline
# 1                 Ford           No         Automatic        Gasoline
# 2                 Ford           No         Automatic        Gasoline
# 3                 Ford           No         Automatic        Gasoline
# 4             Reserved           No         Automatic        Gasoline
# 5                 Ford           No         Automatic        Gasoline
# 6                 Ford           No         Automatic        Gasoline
# 7                 Ford           No         Automatic  Electric (BEV)
# 8                 Ford           No         Automatic        Gasoline
# 9                 Ford           No         Automatic  Electric (BEV)
#
#                                                                       \
#   Plug-in Hybrid (PHEV) Common Global Electrical Architecture (CGEA)
# 0                    No                                     CGEA 1.3
# 1                    No                            CGEA 1.2 or C1MCA
# 2                    No                                     CGEA 1.3
# 3                    No                                     CGEA 1.3
# 4                    No                                      Missing
# 5                    No                                     CGEA 1.3
# 6                    No                                     CGEA 1.3
# 7                    No                            CGEA 1.2 or C1MCA
# 8                    No                                     CGEA 1.3
# 9                    No                            CGEA 1.2 or C1MCA
#
#                                                                               \
#   Heated Windshield Country Code (First Letter) Country Code (Second Letter)
# 0               Yes                           U                            K
# 1                No                           U                            S
# 2                No                           U                            S
# 3                No                           U                            S
# 4           Missing              Unknown (0x04)                            U
# 5                No                           U                            S
# 6                No                           U                            S
# 7                No              Unknown (0x04)               Unknown (0x12)
# 8                No                           U                            S
# 9                No              Unknown (0x04)               Unknown (0x02)
#
#                                                                         \
#     Vehicle Style GPS Antenna Location/Mount Type     Electric Vehicle
# 0           Focus         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 1         SUV/CUV         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 2         SUV/CUV         Roof Mount (UK Default)  CX482 (Escape/Kuga)
# 3         SUV/CUV         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 4            None         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 5         SUV/CUV         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 6         SUV/CUV         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 7          Fiesta                  Unknown (0x05)       Unknown (0x53)
# 8         SUV/CUV         Roof Mount (UK Default)      U625 (Explorer)
# 9  Unknown (0x8A)                  Unknown (0x05)       Unknown (0x53)
#
#                                                                          \
#   Drivetrain Type Bluetooth Vehicle Nameplate ID Front Track Rear Track
# 0             FWD                     Ford Focus    64.05 in   64.05 in
# 1             AWD                    Ford Escape    61.50 in   61.60 in
# 2             FWD                    Ford Escape    61.50 in   61.60 in
# 3             FWD                      Ford Edge    70.75 in   70.67 in
# 4             FWD                        Missing     Missing    Missing
# 5             AWD                           SYNC    61.50 in   61.60 in
# 6             RWD                Ford Expedition    67.00 in   67.20 in
# 7      Dually 2WD                           SYNC     0.01 in   10.24 in
# 8             RWD                  Ford Explorer    68.45 in   68.20 in
# 9      Dually 2WD                           SYNC     0.06 in  122.88 in
#
#                                                                               \
#   Wheel Base Wheel Base (cont.) Vehicle Weight Distance from IP to Rear Axle
# 0   97.28 in          + 0.83 in        1100 kg                Unknown (0x00)
# 1  104.96 in          + 0.95 in        2200 kg                Unknown (0x00)
# 2  104.96 in          + 0.95 in        1900 kg                Unknown (0x00)
# 3  110.08 in          + 1.97 in         800 kg                Unknown (0x00)
# 4    Missing            Missing        Missing                       Missing
# 5  104.96 in          + 0.14 in        2100 kg                Unknown (0x00)
# 6  130.56 in          + 1.04 in        3300 kg                Unknown (0x00)
# 7    0.00 in          + 0.00 in        1900 kg                Unknown (0x00)
# 8  117.76 in          + 1.33 in        2600 kg                Unknown (0x00)
# 9    0.00 in          + 0.00 in        2600 kg                Unknown (0x00)
#
#                                                                              \
#   Distance from IP to Rear Axle (cont.)  ACC Menu Forward Collision Warning
# 0                        Unknown (0x61)   Enabled                      None
# 1                        Unknown (0x57)   Missing                   Missing
# 2                        Unknown (0x88)  Disabled                      None
# 3                        Unknown (0x70)  Disabled                      None
# 4                               Missing   Missing                   Missing
# 5                        Unknown (0x88)   Enabled                       FCW
# 6                        Unknown (0x76)  Disabled                      None
# 7                        Unknown (0x88)  Disabled                       FCW
# 8                        Unknown (0x76)   Enabled                       FCW
# 9                        Unknown (0x80)  Disabled                      None
#
#                                                        \
#    FCW Menu FCW Braking Evasive Steering Assist (ESA)
# 0   Enabled     Enabled                       Enabled
# 1   Missing     Missing                       Missing
# 2  Disabled     Enabled                      Disabled
# 3  Disabled    Disabled                      Disabled
# 4   Missing     Missing                       Missing
# 5  Disabled     Enabled                       Enabled
# 6  Disabled    Disabled                      Disabled
# 7  Disabled     Enabled                      Disabled
# 8  Disabled     Enabled                       Enabled
# 9  Disabled    Disabled                      Disabled
#
#                                                                \
#   Lane Change Assist (LCA) Lane Keeping Sensitivity  ACC Mode
# 0                  Enabled                  Enabled   Enabled
# 1                  Missing                  Missing   Missing
# 2                  Enabled                 Disabled  Disabled
# 3                 Disabled                 Disabled  Disabled
# 4                  Missing                  Missing   Missing
# 5                  Enabled                 Disabled   Enabled
# 6                 Disabled                 Disabled  Disabled
# 7                  Enabled                 Disabled  Disabled
# 8                  Enabled                 Disabled   Enabled
# 9                 Disabled                 Disabled  Disabled
#
#
#      Lane Assist NCAP Aid Lane Assist NCAP Alert
# 0  Off, Reduced, Enhanced      High, Normal, Low
# 1                 Missing                Missing
# 2                Disabled               Disabled
# 3                Disabled               Disabled
# 4                 Missing                Missing
# 5                Disabled               Disabled
# 6                Disabled               Disabled
# 7                Disabled               Disabled
# 8                Disabled               Disabled
# 9                Disabled               Disabled

# %%
from settings import VehicleSettings

important_settings = [
  VehicleSettings.ipma_vehicle,
  # VehicleSettings.ipma_driving_side,
  VehicleSettings.ipma_enable_adaptive_cruise,
  VehicleSettings.ipma_enable_traffic_jam_assist,
  VehicleSettings.ipma_shift_by_wire,
  VehicleSettings.ipma_speed_limit_sign_unit,

  VehicleSettings.abs_cruise_control_mode,
  VehicleSettings.abs_steering_gear,

  VehicleSettings.apim_country_code_first_letter,
  VehicleSettings.apim_country_code_second_letter,
  VehicleSettings.apim_lane_change_assist,
  VehicleSettings.apim_adaptive_cruise_mode,
  VehicleSettings.apim_transmission_type,
  VehicleSettings.apim_fuel_type,
  VehicleSettings.apim_wheel_base,
  VehicleSettings.apim_wheel_base_cont,
  VehicleSettings.apim_vehicle_weight,
]

rows = []
for vin in ('WF0NXXGCHNJR69712', *random.sample(vins, 19)):
  abd = AsBuiltData.from_vin(vin)
  rows.append([vin, *map(lambda s: abd.get_setting_value(s), important_settings)])

columns = [('', 'VIN'), *map(lambda s: (s.ecu.name, s.comment), important_settings)]

df = pd.DataFrame(rows, columns=pd.MultiIndex.from_tuples(columns))
df
# Out:
# Unknown ECU address: 2002 (0x7d2)
# 0x7d2 {61712: 'DSNL38-10D678-AG', 61713: 'NL38-10D686-AD', 61715: 'NL38-10D678-YD', 61732: 'NL38-10D682-AL', 61832: 'NL38-10D681-AL', 61836: 'DVMUA23184J00719'}
#                             ImageProcessingModuleA                             \
#                   VIN                      Vehicle      Enable ACC Enable TJA
# 0   WF0NXXGCHNJR69712                 C519 (Focus)             Off        Off
# 1   2FMPK4G93KBB89695                 CD539 (Edge)             Off        Off
# 2   1FTVW1EV1PWG61316       CX733 (Mustang Mach-E)  Unknown (0x03)  Undefined
# 3   1FMCU9H93NUA05276          CX482 (Escape/Kuga)             Off        Off
# 4   5LMCJ1D9XLUL24376      CX483 (Lincoln Corsair)             Off        Off
# 5   1FM5K8FW5MNA11476              U625 (Explorer)     RadarFusion         On
# 6   1FMJK1KTXKEA17773                      Missing         Missing    Missing
# 7   1FADP3J28JL251773                      Missing         Missing    Missing
# 8   1FMEE5DP9PLC13156                U725 (Bronco)     RadarFusion        Off
# 9   1FM5K8FW9MNA02103              U625 (Explorer)     RadarFusion         On
# 10  5LM5J6WC1NGL16313       U611 (Lincoln Aviator)             Off        Off
# 11  1FMSK8FH0MGA85106              U625 (Explorer)     RadarFusion         On
# 12  2FMPK4AP3KBB20366                 CD539 (Edge)     RadarFusion         On
# 13  1FM5K8FW4MNA17236              U625 (Explorer)     RadarFusion         On
# 14  5LM5J7XC8MGL10205       U611 (Lincoln Aviator)     RadarFusion         On
# 15  3FTTW8E31NRA95110              P758 (Maverick)     RadarFusion         On
# 16  3FMCR9C64RRE08260  CX430 (Bronco Sport OnRoad)             Off        Off
# 17  3FMTK1SS5PMA13941       CX733 (Mustang Mach-E)     RadarFusion  Undefined
# 18  1FMCU9G60LUC08520          CX482 (Escape/Kuga)             Off        Off
# 19  1FMSK7FH4LGB65629              U625 (Explorer)     RadarFusion         On
#
#                                        AntiLockBrakeSystem                \
#    Shift by Wire Speed Limit Sign Unit Cruise Control Mode Steering Gear
# 0            Off                   MPH              Normal     EPAS 21:1
# 1             On                   MPH            Adaptive     EPAS 17:1
# 2      Undefined             Undefined      Unknown (0x01)     EPAS 17:1
# 3             On                   MPH              Normal     EPAS 17:1
# 4             On                   MPH              Normal     EPAS 17:1
# 5             On                   MPH      Unknown (0x01)      Reserved
# 6        Missing               Missing      Unknown (0x00)      Reserved
# 7        Missing               Missing             Missing       Missing
# 8            Off                   MPH      Unknown (0x01)     EPAS 17:1
# 9             On                   MPH      Unknown (0x01)      Reserved
# 10            On                   MPH      Unknown (0x01)     EPAS 17:1
# 11            On                   MPH      Unknown (0x01)     EPAS 17:1
# 12            On                   MPH            Adaptive     EPAS 21:1
# 13            On                   MPH      Unknown (0x01)      Reserved
# 14            On                   MPH      Unknown (0x01)     EPAS 17:1
# 15            On                   MPH      Unknown (0x01)      Reserved
# 16            On                   MPH              Normal     EPAS 17:1
# 17     Undefined             Undefined      Unknown (0x01)     EPAS 17:1
# 18            On                   MPH              Normal     EPAS 17:1
# 19            On                   MPH      Unknown (0x01)     EPAS 17:1
#
#    AccessoryProtocolInterfaceModule                               \
#         Country Code (First Letter) Country Code (Second Letter)
# 0                                 U                            K
# 1                                 U                            S
# 2                    Unknown (0x86)               Unknown (0x16)
# 3                                 U                            S
# 4                                 U                            S
# 5                                 U                            S
# 6                                 U                            S
# 7                                 U                            S
# 8                    Unknown (0x04)               Unknown (0x12)
# 9                                 U                            S
# 10                                U                            S
# 11                                U                            S
# 12                                U                            S
# 13                                U                            S
# 14                                U                            S
# 15                                U                            S
# 16                                U                            S
# 17                   Unknown (0x04)               Unknown (0x02)
# 18                                U                            S
# 19                                U                            S
#
#                                                                          \
#    Lane Change Assist (LCA)  ACC Mode Transmission Type       Fuel Type
# 0                   Enabled   Enabled            Manual        Gasoline
# 1                  Disabled  Disabled         Automatic        Gasoline
# 2                   Enabled   Enabled         Automatic  Electric (BEV)
# 3                   Enabled  Disabled         Automatic        Gasoline
# 4                   Enabled  Disabled         Automatic        Gasoline
# 5                   Enabled   Enabled         Automatic        Gasoline
# 6                   Missing   Missing         Automatic        Gasoline
# 7                   Missing   Missing         Automatic        Gasoline
# 8                   Enabled   Enabled         Automatic  Electric (BEV)
# 9                   Enabled   Enabled         Automatic        Gasoline
# 10                  Enabled  Disabled         Automatic        Gasoline
# 11                  Enabled   Enabled         Automatic        Gasoline
# 12                 Disabled  Disabled         Automatic        Gasoline
# 13                  Enabled   Enabled         Automatic        Gasoline
# 14                  Enabled   Enabled         Automatic        Gasoline
# 15                  Enabled   Enabled         Automatic        Gasoline
# 16                  Enabled  Disabled         Automatic        Gasoline
# 17                  Enabled   Enabled         Automatic  Electric (BEV)
# 18                  Enabled  Disabled         Automatic        Gasoline
# 19                  Enabled   Enabled         Automatic        Gasoline
#
#
#    Wheel Base Wheel Base (cont.) Vehicle Weight
# 0    97.28 in          + 0.83 in        1100 kg
# 1   110.08 in          + 1.97 in         800 kg
# 2     0.00 in          + 0.00 in        3800 kg
# 3   104.96 in          + 0.95 in        2100 kg
# 4   104.96 in          + 0.95 in        2200 kg
# 5   117.76 in          + 1.33 in        2900 kg
# 6   130.56 in          + 1.04 in        3300 kg
# 7   102.40 in          + 1.90 in        1600 kg
# 8     0.00 in          + 0.00 in        2800 kg
# 9   117.76 in          + 1.33 in        2900 kg
# 10  117.76 in          + 1.33 in        2800 kg
# 11  117.76 in          + 1.33 in        2600 kg
# 12  110.08 in          + 1.97 in         800 kg
# 13  117.76 in          + 1.33 in        2900 kg
# 14  117.76 in          + 1.33 in        2900 kg
# 15  120.32 in          + 0.68 in        2400 kg
# 16  104.96 in          + 0.14 in        2100 kg
# 17    0.00 in          + 0.00 in        2500 kg
# 18  104.96 in          + 0.95 in        2000 kg
# 19  117.76 in          + 1.33 in        2600 kg
