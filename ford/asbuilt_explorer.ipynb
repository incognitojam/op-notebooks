# %%
# %load_ext autoreload
# %autoreload 2

# %%
from vins import load_vins

vins = load_vins()
# vins = ['WF0NXXGCHNJR69712']
# Out:
# Loaded 1263 VINs (filter_comment=None, include_openpilot=False, skipped=80)
# Loaded AsBuilt data for 1263 VINs

# %%
import random

import pandas as pd

from asbuilt import AsBuiltData
from settings import VEHICLE_SETTINGS

pd.set_option('display.max_columns', None)

rows = []
for vin in ('WF0NXXGCHNJR69712', *random.sample(vins, 20)):
  abd = AsBuiltData.from_vin(vin)
  rows.append([vin, *map(lambda s: abd.get_setting_value(s), VEHICLE_SETTINGS)])

columns = [('', 'VIN'), *map(lambda s: (s.ecu.name, s.comment), VEHICLE_SETTINGS)]

df = pd.DataFrame(rows, columns=pd.MultiIndex.from_tuples(columns))
df
# Out:
#                       ImageProcessingModuleA                             \
#                   VIN                Vehicle      Enable ACC Enable TJA
# 0   WF0NXXGCHNJR69712           C519 (Focus)             Off        Off
# 1   1FMEE5DP0PLB51789         Unknown (0x4B)             Off        Off
# 2   1FMCU0MN5PUA09329         Unknown (0x00)     RadarFusion  Undefined
# 3   1FMCU9FN1PUA54818         Unknown (0x00)     RadarFusion  Undefined
# 4   1FTEW1EPXNKD77883         Unknown (0x58)  Unknown (0x03)  Undefined
# 5   3FTTW8F92PRA08417         Unknown (0x4D)             Off        Off
# 6   1FMSK8DH0NGA71727        U625 (Explorer)             Off        Off
# 7   1FADP3J21JL232191                Missing         Missing    Missing
# 8   1FMSK8DHXLGA77872        U625 (Explorer)     RadarFusion         On
# 9   1FMSK7DH8NGA11513        U625 (Explorer)             Off        Off
# 10  1FMCU9G64NUB66775    CX482 (Escape/Kuga)             Off        Off
# 11  3FA6P0HD4LR264457         Unknown (0xA8)       Undefined  Undefined
# 12  3FMCR9G61PRD98116   CX430 (Bronco Sport)             Off        Off
# 13  1FMJK2A80PEA04329         Unknown (0x58)     RadarFusion  Undefined
# 14  1FMCU9PA9PUA55615         Unknown (0x58)     RadarFusion  Undefined
# 15  1FMCU9F69LUA52995    CX482 (Escape/Kuga)             Off        Off
# 16  2FMPK4K97RBA27053           CD539 (Edge)             Off        Off
# 17  2FMPK4J9XRBA24293           CD539 (Edge)             Off        Off
# 18  1FMJU1MT9KEA64302             Expedition     RadarFusion        Off
# 19  1FM5K8GC0PGA70822        U625 (Explorer)     RadarFusion         On
# 20  1FM5K8FW0MNA16536        U625 (Explorer)     RadarFusion         On
#
#    AntiLockBrakeSystem                                      \
#      Wheel base preset   Steering Gear Cruise Control Mode
# 0             Reserved       EPAS 21:1              Normal
# 1                141in       EPAS 17:1      Unknown (0x01)
# 2             Reserved       EPAS 17:1      Unknown (0x01)
# 3             Reserved       EPAS 17:1              Normal
# 4                145in       EPAS 17:1      Unknown (0x01)
# 5             Reserved        Reserved              Normal
# 6             Reserved       EPAS 17:1      Unknown (0x01)
# 7              Missing         Missing             Missing
# 8             Reserved       EPAS 17:1      Unknown (0x01)
# 9             Reserved       EPAS 17:1      Unknown (0x01)
# 10            Reserved       EPAS 17:1              Normal
# 11               141in  Unknown (0x03)            Adaptive
# 12            Reserved       EPAS 17:1              Normal
# 13               141in       EPAS 17:1      Unknown (0x00)
# 14            Reserved       EPAS 17:1              Normal
# 15            Reserved       EPAS 17:1              Normal
# 16               122in       EPAS 17:1            Adaptive
# 17               122in       EPAS 17:1            Adaptive
# 18               122in        Reserved      Unknown (0x00)
# 19            Reserved       EPAS 17:1      Unknown (0x01)
# 20            Reserved        Reserved      Unknown (0x01)
#
#                                             AccessoryProtocolInterfaceModule  \
#    Collision Mitigation by Braking (CMbB) Steering Wheel Angle Sensor (SWAS)
# 0                                 Without                           Absolute
# 1                                    With                           Absolute
# 2                                 Without                           Relative
# 3                                 Without                           Relative
# 4                                    With                           Absolute
# 5                                 Without                            Missing
# 6                                 Without                           Absolute
# 7                                 Missing                           Absolute
# 8                                 Without                           Absolute
# 9                                 Without                           Absolute
# 10                                Without                           Absolute
# 11                                Missing                           Absolute
# 12                                Without                           Absolute
# 13                                   With                           Absolute
# 14                                Without                           Relative
# 15                                Without                           Absolute
# 16                                   With                           Absolute
# 17                                   With                           Absolute
# 18                                   With                           Absolute
# 19                                Without                           Absolute
# 20                                Without                           Absolute
#
#                                                                   \
#    Brand Identification Hybrid (HEV) Transmission Type Fuel Type
# 0                  Ford           No            Manual    Diesel
# 1                  Ford           No         Automatic  Gasoline
# 2                  Ford           No         Automatic  Gasoline
# 3                  Ford           No         Automatic  Gasoline
# 4               Lincoln          Yes         Automatic  Gasoline
# 5               Missing      Missing           Missing   Missing
# 6                  Ford           No         Automatic  Gasoline
# 7                  Ford           No         Automatic  Gasoline
# 8                  Ford           No         Automatic  Gasoline
# 9                  Ford           No         Automatic  Gasoline
# 10                 Ford           No         Automatic  Gasoline
# 11                 Ford           No         Automatic  Gasoline
# 12                 Ford           No         Automatic  Gasoline
# 13                 Ford          Yes         Automatic  Gasoline
# 14                 Ford          Yes         Automatic  Gasoline
# 15                 Ford           No         Automatic  Gasoline
# 16                 Ford           No         Automatic  Gasoline
# 17                 Ford           No         Automatic  Gasoline
# 18                 Ford           No         Automatic  Gasoline
# 19                 Ford           No         Automatic  Gasoline
# 20                 Ford          Yes         Automatic  Gasoline
#
#                                                                        \
#    Plug-in Hybrid (PHEV) Common Global Electrical Architecture (CGEA)
# 0                     No                                     CGEA 1.3
# 1                     No                            CGEA 1.2 or C1MCA
# 2                     No                            CGEA 1.2 or C1MCA
# 3                     No                            CGEA 1.2 or C1MCA
# 4                     No                            CGEA 1.2 or C1MCA
# 5                Missing                                      Missing
# 6                     No                                     CGEA 1.3
# 7                     No                            CGEA 1.2 or C1MCA
# 8                     No                                     CGEA 1.3
# 9                     No                                     CGEA 1.3
# 10                    No                                     CGEA 1.3
# 11                    No                                     CGEA 1.3
# 12                    No                                     CGEA 1.3
# 13                    No                            CGEA 1.2 or C1MCA
# 14                    No                            CGEA 1.2 or C1MCA
# 15                    No                                     CGEA 1.3
# 16                    No                            CGEA 1.2 or C1MCA
# 17                    No                            CGEA 1.2 or C1MCA
# 18                    No                                     CGEA 1.3
# 19                    No                                     CGEA 1.3
# 20                    No                                     CGEA 1.3
#
#                                                                                \
#    Heated Windshield Country Code (First Letter) Country Code (Second Letter)
# 0                Yes                           U                            K
# 1                 No              Unknown (0x04)               Unknown (0x12)
# 2                 No              Unknown (0x04)               Unknown (0x12)
# 3                 No              Unknown (0x04)               Unknown (0x12)
# 4                 No              Unknown (0x86)               Unknown (0x16)
# 5            Missing                     Missing                      Missing
# 6                 No                           U                            S
# 7                 No                           U                            S
# 8                 No                           U                            S
# 9                 No                           U                            S
# 10                No                           U                            S
# 11                No                           U                            S
# 12                No                           U                            S
# 13                No              Unknown (0x86)               Unknown (0x02)
# 14                No              Unknown (0x04)               Unknown (0x12)
# 15                No                           U                            S
# 16                No              Unknown (0x04)               Unknown (0x02)
# 17                No              Unknown (0x04)               Unknown (0x02)
# 18                No                           U                            S
# 19                No                           U                            S
# 20                No                           U                            S
#
#                                                     \
#      Vehicle Style GPS Antenna Location/Mount Type
# 0            Focus         Roof Mount (UK Default)
# 1           Fiesta                  Unknown (0x05)
# 2           Fiesta                  Unknown (0x05)
# 3            Focus                  Unknown (0x05)
# 4           Fiesta                  Unknown (0x05)
# 5          Missing                         Missing
# 6          SUV/CUV         Roof Mount (UK Default)
# 7            Sedan         Roof Mount (UK Default)
# 8          SUV/CUV         Roof Mount (UK Default)
# 9          SUV/CUV         Roof Mount (UK Default)
# 10         SUV/CUV         Roof Mount (UK Default)
# 11           Sedan         Roof Mount (UK Default)
# 12         SUV/CUV         Roof Mount (UK Default)
# 13  Unknown (0x2A)                  Unknown (0x05)
# 14           Focus                  Unknown (0x05)
# 15         SUV/CUV         Roof Mount (UK Default)
# 16  Unknown (0x8A)                  Unknown (0x05)
# 17  Unknown (0x8A)                  Unknown (0x05)
# 18         SUV/CUV         Roof Mount (UK Default)
# 19         SUV/CUV         Roof Mount (UK Default)
# 20         SUV/CUV         Roof Mount (UK Default)
#
#                                                                                \
#               Electric Vehicle Drivetrain Type Bluetooth Vehicle Nameplate ID
# 0           Non-HEV, BEV, PHEV             FWD                     Ford Focus
# 1               Unknown (0x53)  Unknown (0x0C)                           SYNC
# 2               Unknown (0x53)      Dually 2WD                           SYNC
# 3               Unknown (0x53)      Dually 2WD                           SYNC
# 4               Unknown (0x53)             4WD                           SYNC
# 5                      Missing         Missing                        Missing
# 6              U625 (Explorer)             AWD                  Ford Explorer
# 7   C346/C519 (Focus Electric)             FWD                     Ford Focus
# 8              U625 (Explorer)             AWD                  Ford Explorer
# 9              U625 (Explorer)             RWD                  Ford Explorer
# 10         CX482 (Escape/Kuga)             AWD                    Ford Escape
# 11          Non-HEV, BEV, PHEV             FWD                    Ford Fusion
# 12          Non-HEV, BEV, PHEV             AWD                           SYNC
# 13              Unknown (0x53)      Dually 2WD                           SYNC
# 14              Unknown (0x53)      Dually 2WD                           SYNC
# 15         CX482 (Escape/Kuga)             AWD                    Ford Escape
# 16              Unknown (0x53)      Dually 2WD                           SYNC
# 17              Unknown (0x53)      Dually 2WD                           SYNC
# 18          Non-HEV, BEV, PHEV             4WD                Ford Expedition
# 19             U625 (Explorer)             AWD                  Ford Explorer
# 20             U625 (Explorer)             AWD                  Ford Explorer
#
#                                                                         \
#                                                               \
#     ACC Menu Forward Collision Warning  FCW Menu FCW Braking
# 0    Enabled                      None   Enabled     Enabled
# 1   Disabled                       FCW   Enabled     Enabled
# 2   Disabled                       FCW  Disabled     Enabled
# 3   Disabled                       FCW  Disabled     Enabled
# 4    Enabled                       FCW   Enabled     Enabled
# 5    Missing                   Missing   Missing     Missing
# 6   Disabled                       FCW  Disabled     Enabled
# 7    Missing                   Missing   Missing     Missing
# 8    Enabled                       FCW  Disabled     Enabled
# 9   Disabled                       FCW  Disabled     Enabled
# 10  Disabled                       FCW  Disabled     Enabled
# 11  Disabled                      None  Disabled    Disabled
# 12  Disabled                       FCW  Disabled     Enabled
# 13   Enabled                       FCW   Enabled     Enabled
# 14   Enabled                       FCW  Disabled     Enabled
# 15  Disabled                      None  Disabled     Enabled
# 16  Disabled                      None  Disabled    Disabled
# 17  Disabled                      None  Disabled    Disabled
# 18   Missing                   Missing   Missing     Missing
# 19   Enabled                       FCW  Disabled     Enabled
# 20   Enabled                       FCW  Disabled     Enabled
#
#                                                            \
#    Evasive Steering Assist (ESA) Lane Change Assist (LCA)
# 0                        Enabled                  Enabled
# 1                       Disabled                  Enabled
# 2                       Disabled                  Enabled
# 3                       Disabled                  Enabled
# 4                        Enabled                  Enabled
# 5                        Missing                  Missing
# 6                       Disabled                  Enabled
# 7                        Missing                  Missing
# 8                        Enabled                  Enabled
# 9                       Disabled                  Enabled
# 10                      Disabled                  Enabled
# 11                      Disabled                 Disabled
# 12                      Disabled                  Enabled
# 13                       Enabled                  Enabled
# 14                       Enabled                  Enabled
# 15                      Disabled                  Enabled
# 16                      Disabled                 Disabled
# 17                      Disabled                 Disabled
# 18                       Missing                  Missing
# 19                       Enabled                  Enabled
# 20                       Enabled                  Enabled
#
#                                                                \
#    Lane Keeping Sensitivity  ACC Mode    Lane Assist NCAP Aid
# 0                   Enabled   Enabled  Off, Reduced, Enhanced
# 1                  Disabled  Disabled                Disabled
# 2                  Disabled  Disabled                Disabled
# 3                  Disabled  Disabled                Disabled
# 4                  Disabled   Enabled                Disabled
# 5                   Missing   Missing                 Missing
# 6                  Disabled  Disabled                Disabled
# 7                   Missing   Missing                 Missing
# 8                  Disabled   Enabled                Disabled
# 9                  Disabled  Disabled                Disabled
# 10                 Disabled  Disabled                Disabled
# 11                 Disabled  Disabled                Disabled
# 12                 Disabled  Disabled                Disabled
# 13                 Disabled   Enabled                Disabled
# 14                 Disabled   Enabled                Disabled
# 15                 Disabled  Disabled                Disabled
# 16                 Disabled  Disabled                Disabled
# 17                 Disabled  Disabled                Disabled
# 18                  Missing   Missing                 Missing
# 19                 Disabled   Enabled                Disabled
# 20                 Disabled   Enabled                Disabled
#
#
#    Lane Assist NCAP Alert
# 0       High, Normal, Low
# 1                Disabled
# 2                Disabled
# 3                Disabled
# 4                Disabled
# 5                 Missing
# 6                Disabled
# 7                 Missing
# 8                Disabled
# 9                Disabled
# 10               Disabled
# 11               Disabled
# 12               Disabled
# 13               Disabled
# 14               Disabled
# 15               Disabled
# 16               Disabled
# 17               Disabled
# 18                Missing
# 19               Disabled
# 20               Disabled
