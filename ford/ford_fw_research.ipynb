# %%
# %pip install beautifulsoup4 lxml
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/cameron/openpilot/.venv/lib/python3.11/site-packages (4.12.3)
# Requirement already satisfied: lxml in /home/cameron/openpilot/.venv/lib/python3.11/site-packages (5.1.0)
# Requirement already satisfied: soupsieve>1.2 in /home/cameron/openpilot/.venv/lib/python3.11/site-packages (from beautifulsoup4) (2.5)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path

ASBUILT_DIR = Path() / 'asbuilt'

if not ASBUILT_DIR.is_dir():
  ASBUILT_DIR.mkdir()

def get_asbuilt_path(vin: str) -> Path:
  return ASBUILT_DIR / f'{vin}.ab'

def check_asbuilt_exists(vin: str) -> bool:
  return get_asbuilt_path(vin).is_file()

# %%
import pandas as pd

df_vins = pd.read_csv('ford_vins.csv', dtype={"pr":"str"})

duplicates = df_vins[df_vins.duplicated(subset=['vin'], keep=False)]
print(f'Found {len(duplicates)} duplicate VINs')
if len(duplicates):
  print(duplicates)

# remove rows with non-empty "pr" column
df_vins = df_vins[df_vins['pr'].isnull()]
df_vins.drop(columns=['pr'], inplace=True)

# reset index
df_vins.reset_index(drop=True, inplace=True)

print(f"Loaded {len(df_vins)} VINs")
vins = set(df_vins['vin'])
# Out:
# /tmp/ipykernel_37766/335545698.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 df_vins = pd.read_csv('ford_vins.csv', dtype={"pr":"str"})
#       5 duplicates = df_vins[df_vins.duplicated(subset=['vin'], keep=False)]
#       6 print(f'Found {len(duplicates)} duplicate VINs')
#
# File ~/openpilot/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~/openpilot/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File ~/openpilot/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File ~/openpilot/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File ~/openpilot/.venv/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ford_vins.csv'

# %%
print("Download from https://www.motorcraftservice.com/AsBuilt")
missing, found = 0, 0
for vin in df_vins['vin']:
  if not check_asbuilt_exists(vin):
    print(f'missing: {vin}')
    missing += 1
  else:
    found += 1
print(f'missing: {missing}')
print(f'found: {found}')
# Out:
# Download from https://www.motorcraftservice.com/AsBuilt
# missing: 0
# found: 44

# %%
from bs4 import BeautifulSoup

EcuData = dict[int, str]

def get_car_ecu_data(vin: str) -> dict[int, EcuData]:
  with open(get_asbuilt_path(vin), 'r') as f:
    soup = BeautifulSoup(f, 'lxml')

  car_data = {}
  for value in soup.find_all('nodeid'):
    children = value.children
    addr = int(str(next(children)).strip(), 16)
    ecu_data = {}
    for child in children:
      if child.name:
        data_identifier = int(child.name, 16)
        ecu_data[data_identifier] = child.text.strip()
    car_data[addr] = ecu_data
  return car_data

candidate = df_vins['vin'][0]
print(get_car_ecu_data(candidate))
# Out:
# {1776: {61712: 'DSN1MT-14D068-AA', 61713: 'N1MT-14G635-AA', 61715: 'N1MT-14D068-CA', 61732: 'N1MT-14G631-AA', 61832: 'N1MT-14G630-AA', 61836: '0120360937440391'}, 1795: {61713: 'MB5A-14G581-AA', 61715: 'N1MA-7P238-AA', 61832: 'N1MA-14G576-DA', 61836: '00IFH3Y74801'}, 1798: {61712: 'DSLB5T-19H406-AE', 61713: 'LB5T-14F403-CA', 61715: 'LB5T-19H406-CF', 61728: 'LB5T-14F397-BC', 61732: 'LB5T-14F398-AF', 61733: 'LB5T-14F398-BC', 61832: 'LB5T-14F397-AF', 61836: '220342335'}, 1814: {61706: 'LB5T-14F535-BB', 61712: 'DSJU5T-14F642-BA', 61713: 'LU5T-14F536-EB', 61715: 'LB5T-14F642-BB', 61832: 'LB5T-14F530-BB', 61836: '4710210938323003'}, 1824: {61712: 'DSMB5T-1A292-BA', 61713: 'MB5T-14F094-BA', 61715: 'MB5T-10849-FA', 61732: 'MB5T-14C088-BA', 61832: 'MB5T-14C026-BA', 61836: '03121849'}, 1828: {61712: 'DSLB5T-3F944-AA', 61713: 'LB5T-14F078-DC', 61715: 'LB5T-3F944-SG', 61832: 'LB5T-14C579-AB', 61836: '9291820170497000'}, 1830: {61706: 'NB5T-14C636-AA', 61710: 'LB5T-14G570-AAC', 61712: 'DSLU5T-14B476-AAK', 61713: 'LU5T-14F141-KAD', 61715: 'LU5T-14B476-KAT', 61803: 'LU5T-14F391-AAA', 61804: 'LB5T-14F390-AAF', 61805: 'LB5T-14F389-AH', 61806: 'LB5T-14G163-AAA', 61821: 'LU5T-14G162-KAM', 61832: 'LU5T-14C184-AAT', 61836: '22048193120'}, 1831: {61706: 'LB5T-14C653-FA', 61712: 'DSJX7T-18K810-AM', 61713: 'MB5T-14F168-AA', 61715: 'MB5T-18K810-AA', 61729: 'JX7T-14C302-GA', 61732: 'JX7T-14C303-AT', 61832: 'JX7T-14C302-BT', 61836: 'A6AH056004'}, 1840: {61706: 'MB5C-14D007-BB', 61712: 'DSL1MC-3F964-AJ', 61713: 'M1MC-14F079-AA', 61715: 'M1MC-3F964-AB', 61732: 'M1MC-14D004-AC', 61832: 'M1MC-14D003-AB', 61836: '21X280016078'}, 1842: {61712: 'DSL1MP-7P155-JB', 61713: 'L1MP-14G400-JA', 61715: 'L1MP-7P155-LA', 61732: 'L1MP-14G396-JB', 61832: 'L1MP-14G395-JB', 61836: '60212110280194'}, 1843: {61706: 'NB5T-14C651-AC', 61712: 'DSNB5T-18C612-AA', 61713: 'NB5T-14F165-DA', 61715: 'NB5T-18C612-DB', 61832: 'NB5T-18D619-AB', 61836: '07020072'}, 1846: {61706: 'LB5T-14C647-UB', 61712: 'DSLU5T-15K866-AB', 61713: 'LU5T-14F159-AA', 61715: 'LU5T-15K866-AB', 61832: 'LU5T-14C090-AB', 61836: 'FORD_V408_4CH_V6'}, 1847: {61706: 'LB5T-14C635-AB', 61712: 'DSGN15-14B321-BA', 61713: 'LB5T-14F136-PA', 61715: 'LB5T-14B321-PA', 61832: 'GN15-14C028-CA', 61836: '7000534234040000'}, 1856: {61706: 'LB5T-14C637-CA', 61712: 'DSJX7T-14B531-AJ', 61713: 'JX7T-14F142-AA', 61715: 'JX7T-14B531-AJ', 61832: 'JX7T-14C064-AH', 61836: '2275382203482365'}, 1857: {61706: 'LB5T-14C639-CA', 61712: 'DSJX7T-14B533-AJ', 61713: 'JX7T-14F144-AA', 61715: 'JX7T-14B533-AJ', 61832: 'JX7T-14C108-AH', 61836: '2275382203171066'}, 1873: {61712: 'DSML3T-15K619-AB', 61713: 'ML3T-14G096-CA', 61715: 'ML3T-15K619-JA', 61832: 'ML3T-14G090-CA', 61836: '1502220200581916'}, 1876: {61706: 'LB5T-14G144-SR', 61712: 'DSLB5T-14G087-AN', 61713: 'LB5T-14G145-SA', 61715: 'LB5T-14G087-SN', 61832: 'LB5T-14G139-SR', 61836: 'UD2103G3'}, 1888: {61706: 'L1MC-14C602-FBB', 61712: 'DSL1MC-2C219-AL', 61713: 'L1MC-14F065-DA', 61715: 'L1MC-2C219-KB', 61832: 'L1MC-2D053-KB', 61836: '000M152220600791'}, 1893: {61712: 'DSLJ6B-603B16-AA', 61713: 'FR3B-14F601-AC', 61715: 'LB5B-603B16-AC', 61732: 'LB5B-14F596-AC', 61832: 'LB5B-14F595-AB', 61836: 'SR18992203201602'}, 1909: {61706: 'LB5T-14C674-AP', 61712: 'DSJX7T-14B673-AL', 61713: 'JX7T-14F151-AD', 61715: 'JX7T-14B673-BB', 61832: 'JX7T-14C121-AP', 61836: '2575436203543612'}, 1925: {61712: 'DSLB5T-19980-AD', 61713: 'JL1T-14F213-AB', 61715: 'LB5T-19980-EG', 61832: 'LB5T-14C178-AE', 61836: '0742-0312000'}, 1938: {61712: 'DSLB5T-14G066-AB', 61713: 'LB5T-14F147-CA', 61715: 'LB5T-14G066-CB', 61832: 'LB5T-14D024-AB', 61836: '882B2202040035'}, 1988: {61712: 'DSLB5T-14C689-AB', 61713: 'KB3T-14F152-AA', 61715: 'LC3T-14C689-AC', 61832: 'LB5T-14D368-AC', 61836: '02C22130002B1'}, 1990: {61712: 'DSLB5T-14C689-AB', 61713: 'KB3T-14F152-AA', 61715: 'LC3T-14C689-BC', 61832: 'LB5T-14D368-BC', 61836: '02C22128000C8'}, 2000: {61706: 'GB5T-14G379-AA', 61712: 'DS1U5T-14G371-EL', 61713: '1U5T-14G380-CE', 61715: 'MU5T-14G371-BA ...

# %%
from dataclasses import dataclass
from enum import IntEnum
from typing import NamedTuple

class FordEcu(IntEnum):
  PowerSteeringControlModule = 0x730
  AntiLockBrakeSystem = 0x760
  CruiseControlModule = 0x764
  ImageProcessingModuleA = 0x706
  PowertrainControlModule = 0x7E0
  InstrumentPanelCluster = 0x720
  BodyControlModule = 0x726
  AccessoryProtocolInterfaceModule = 0x7D0
  SteeringColumnControlModule = 0x724

def get_ford_ecu(addr: int) -> FordEcu | None:
  return FordEcu(addr) if addr in FordEcu.__members__.values() else None

@dataclass
class FordFeature:
  masks: list[dict[FordEcu, dict[str, list[int]]]]


class VehicleSetting(NamedTuple):
  address: str
  bit_positions: int
  value_map: dict[int, str]


class VehicleConfiguration:
  configuration_data: dict[str, list[str]]

  def __init__(self, configuration_data: dict[str, list[str]]):
    self.configuration_data = configuration_data

  def get_setting(self, setting: VehicleSetting) -> str:
    codes = self.configuration_data.get(setting.address)
    if not codes:
      return "Not Found"


class FordFeatures:
  # https://www.fordescape.org/threads/how-to-enable-lane-centering-assist.117546/post-1158933
  LaneCenteringAssist = FordFeature(
    masks={
      FordEcu.PowerSteeringControlModule: {
        '02-02': [0x0000, 0xFFFF, 0x00],
      },
      FordEcu.ImageProcessingModuleA: {
        '01-02': [0x0006, 0x0000, 0x00],  # Traffic Jam Assist
        '02-07': [0x0000, 0x0F80, 0x00],
      },
      FordEcu.InstrumentPanelCluster: {
        '10-01': [0x0D00, 0x0000, 0x00],
      },
      FordEcu.SteeringColumnControlModule: {
        # Basic Cruise = 0x0358
        # Adaptive Cruise = 0x0360
        # Adaptive Cruise + Lane Centering = 0x0390
        # TODO: not clear what correct bitmask is
        '02-01': [0x0300, 0x0000, 0x00],
      },
    },
  )
  # https://www.fordescape.org/threads/how-to-adding-adaptive-cruise-non-stop-go-and-copilot-assist.117530/
  AdaptiveCruiseControl = FordFeature(
    masks={
      # FordEcu.PowerSteeringControlModule: {
      #   '02-03': [0xFF00, 0x0000, 0x00],  # enable ESA
      # },
      FordEcu.AntiLockBrakeSystem: {
        # '02-03': [0x0300, 0x00FE, 0x00],  # not needed?
        '03-02': [0x0300, 0x0000, 0x00],  # 0x0400 may also work
        # '03-03': [0x0000, 0x0000, 0x01],  # not needed?
        # '03-04': [0x0000, 0x0000, 0x02],  # not needed?
      },
      FordEcu.CruiseControlModule: {
        # V = VIN as hex
        # 01-01 26VV-VVVV-VV
        # 01-02 VVVV-VVVV-VV
        # 01-03 VVVV-VVVV-VV
        # 01-04 VVVV-Vvxx-xx
        # 01-05 0000-00
        '01-01': [0x2600, 0x0000, 0x00],
      },
      FordEcu.ImageProcessingModuleA: {
        '01-01': [0x0000, 0x9000, 0xA9],
        # 3F = gap setting #1 (closest), 5F = #2, 7F = #3, 9F = #4, BF = #5 (furthest)
        '02-01': [0x0000, 0x0000, 0x1F],
      },
      FordEcu.InstumentPanelCluster: {
        '01-01': [0x0F00, 0x0000, 0x00],  # enable ACC
        # '01-02': [0x0000, 0x80],  # FCW + FDA
        # '09-01': [0x3000, 0x0000, 0x00],  # enable ESA
      },
      FordEcu.BodyControlModule: {
        '04-06': [0x8C00, 0x0000, 0x00],  # 0x8C00 non-stop and go
      },
      FordEcu.AccessoryProtocolInterfaceModule: {
        '09-01': [0x6000, 0x0000, 0x00],  # ACC Menu
        # '09-01': [0x0000, 0x4000, 0x00],  # FCW + FDA
        '09-02': [0x0000, 0x0E00, 0x00],  # enable ACC (0x0F00 with iACC and TSR)
        # '09-02': [0x000C, 0x0000, 0x00],  # enable ESA
      },
      FordEcu.SteeringColumnControlModule: {
        # Basic Cruise = 0x0358
        # Adaptive Cruise = 0x0360
        # Adaptive Cruise + Lane Centering = 0x0390
        # TODO: not clear what correct bitmask is
        '02-01': [0x0390, 0x0000, 0x00],
      },
    },
  )

INTERESTING_ECUS = [ecu for feature in FordFeatures.__dict__.values() if isinstance(feature, FordFeature) for ecu in feature.masks.keys()]

# %%
from collections import defaultdict

def get_module_configuration(vin: str, filter_ecu: FordEcu | None = None) -> dict[FordEcu, dict[str, str]] | dict[str, str]:
  with open(get_asbuilt_path(vin), 'r') as f:
    soup = BeautifulSoup(f, 'lxml')

  # <AS_BUILT_DATA>
  #   <VEHICLE>
  #     <VIN>1FM5K8D8XHGC96884</VIN>
  #     <VEHICLE_DATA>
  #       <DATA LABEL=""><CODE>52E4</CODE><CODE>FFFF</CODE><CODE>FF33</CODE></DATA>
  #     </VEHICLE_DATA>
  #     <PCM_MODULE>
  #       <DATA LABEL="PCM 1"><CODE>FFFF</CODE><CODE>FFFF</CODE><CODE>FF0C</CODE></DATA>
  #       <DATA LABEL="PCM 2"><CODE>FFFF</CODE><CODE>FFFF</CODE><CODE>FF0D</CODE></DATA>
  #       ...
  #     </PCM_MODULE>
  #     <BCE_MODULE>
  #       <DATA LABEL="7D0-01-01"><CODE>2A2A</CODE><CODE>0502</CODE><CODE>083C</CODE></DATA>
  #       <DATA LABEL="7D0-01-02"><CODE>0289</CODE><CODE>0004</CODE><CODE>9A03</CODE></DATA>
  #       ...
  #     </BCE_MODULE>
  #     ...

  module_configuration = defaultdict(dict)
  for module in soup.find_all('bce_module'):
    for data in module.find_all('data'):
      addr, _, label = data['label'].partition('-')

      addr = int(addr, 16)
      ecu = get_ford_ecu(addr)
      if ecu not in INTERESTING_ECUS:
        continue

      if filter_ecu and ecu != filter_ecu:
        continue

      module_configuration[ecu][label] = [code.text for code in data.find_all('code')]

  if filter_ecu:
    return dict(module_configuration[filter_ecu])

  return dict(module_configuration)

for module, conf in get_module_configuration(df_vins['vin'][0]).items():
  print(module.name, conf)

# %%
def get_feature(vin: str, feature: FordFeature) -> bool:
  if ecu not in FORD_FEATURE_MASKS:
    raise ValueError(f'Unknown ECU: {ecu}')
  if feature not in FORD_FEATURE_MASKS[ecu]:
    raise ValueError(f'Unknown feature: {feature}')
  addr, mask = FORD_FEATURE_MASKS[ecu][feature]

  conf = get_module_configuration(vin, ecu)
  if addr not in conf:
    print(f'Unknown address: {addr}')
    return False
  data = conf[addr]
  masked_data = [int(d, 16) & m for d, m in zip(data, mask, strict=True)]
  return all(d == m for d, m in zip(masked_data, mask, strict=True))

for vin in df_vins['vin']:
  print(vin)
  try:
    print(get_feature(vin, FordEcu.ImageProcessingModuleA, 'TrafficJamAssist'))
    print(get_feature(vin, FordEcu.ImageProcessingModuleA, 'LaneCenteringAssist'))
    print(get_feature(vin, FordEcu.PowerSteeringControlModule, 'LaneCenteringAssist'))
  except:
    pass

# %%
import json

NHTSA_DIR = Path() / 'nhtsa'

if not NHTSA_DIR.is_dir():
  NHTSA_DIR.mkdir()

def get_nhtsa_path(vin: str) -> Path:
  return NHTSA_DIR / f'{vin}.json'

def decode_nhtsa_vin_values(vin: str) -> dict[str, str] | None:
  if get_nhtsa_path(vin).is_file():
    with open(get_nhtsa_path(vin), 'r') as f:
      return json.load(f)
  import requests
  url = f'https://vpic.nhtsa.dot.gov/api/vehicles/DecodeVinValuesExtended/{vin}?format=json'
  resp = requests.get(url)
  data = resp.json()['Results'][0]
  if 'ErrorCode' in data and data['ErrorCode'] != '0':
    return None
  with open(get_nhtsa_path(vin), 'w') as f:
    json.dump(data, f)
  return data

# %%
from collections import defaultdict

# {("details", "vin"): [...],
#  ("details", "comment"): [...],
#  ("values", "Make"): [...],
#  ("values", "Model"): [...],
#  ...}
vins_data = defaultdict(list)
known_values = set()

# skip not interesting values
skip_values = {"VIN", "ErrorCode", "ErrorText", "AirBagLocFront", "AirBagLocKnee", "AirBagLocSide",
  "AutoReverseSystem", "AutomaticPedestrianAlertingSound", "Axles", "BasePrice", "CAN_AACN", "CIB",
  "DaytimeRunningLight", "DisplacementCC", "DisplacementCI", "Doors", "ForwardCollisionWarning",
  "MakeID", "ManufacturerId", "ModelID", "NCSAMake", "TPMS", "TractionControl",
  "RearVisibilitySystem", "SeatRows", "Seats", "SemiautomaticHeadlampBeamSwitching", "Wheels"}

for vin, comment in zip(df_vins['vin'], df_vins['comment'], strict=True):
  vin_values = decode_nhtsa_vin_values(vin)
  if vin_values is None:
    print(f'Failed to get NHTSA data for {vin}')
    continue

  vins_data[('details', 'vin')].append(vin)
  vins_data[('details', 'comment')].append(comment)

  found_values = set(vin_values.keys())
  for key in known_values:
    if key not in found_values:
      print('! missing value:', key)
      print('data may be innacurate due to row misalignment')

  for key, value in vin_values.items():
    if key in skip_values:
      continue
    known_values.add(key)
    vins_data[('vin values', key)].append(value)


df_vin_values = pd.DataFrame(vins_data)
print(df_vin_values.shape)

# replace "Not Applicable" with empty string
df_vin_values = df_vin_values.replace("Not Applicable", "")

# remove empty columns
df_vin_values = df_vin_values.loc[:, (df_vin_values != '').any(axis=0)]
print(df_vin_values.shape)

# remove columns with only one value
df_vin_values = df_vin_values.loc[:, df_vin_values.nunique() > 1]
print(df_vin_values.shape)

print(df_vin_values.to_string())
# Out:
# (44, 124)
# (44, 52)
# (44, 36)
#               details                                            vin values
#                   vin                         comment AdaptiveCruiseControl AdaptiveDrivingBeam BlindSpotMon DisplacementL              DriveType DynamicBrakeSupport       EDR EngineConfiguration EngineCylinders EngineHP  EngineModel                                FuelInjectionType                                           GVWR LaneCenteringAssistance LaneDepartureWarning LaneKeepSystem LowerBeamHeadlampLightSource ModelYear                                                                       NCSABodyType                                                                                                                  NCSAModel OtherEngineInfo ParkAssist PedestrianAutomaticEmergencyBraking RearCrossTrafficAlert   Series       SteeringLocation TransmissionSpeeds TransmissionStyle Trim Turbo VehicleDescriptor WheelBaseShort WheelSizeFront WheelSizeRear
# 0   1FMSK8DH1NGA52944          2022 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG
# 1   1FMSK8DH7MGC46036          2021 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*MG          119.1             18            18
# 2   1FMSK8DH9MGB42406          2021 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*MG          119.1             18            18
# 3   1FMSK8DH4NGA87686          2022 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG
# 4   1FMSK8DH8MGA39221          2021 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*MG          119.1             18            18
# 5   1FMSK8DH3NGA52377          2022 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG
# 6   1FMSK8DH1LGB19569          2020 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4            Standard                       In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TIVCT                                       Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*LG         119.10             18            18
# 7   1FMSK8DH8NGA60359          2022 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG
# 8   1FMSK8DH7NGB18820          2022 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG
# 9   1FMSK8DH9LGB14815          2020 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4            Standard                       In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TIVCT                                       Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*LG         119.10             18            18
# 10  1FMSK8DH6NGB18355          2022 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG
# 11  1FMSK8FH7NGA39693      2022 Ford Explorer Limited              Standard                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                Standard             Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard  Limited                                        10         Automatic                  1FMSK8FH*NG
# 12  1FMSK7FHXPGA86567  2023 Ford Explorer Limited RWD              Standard                         Standard           2.3   RWD/Rear-Wheel Drive            Standard  Standard             In-Line               4                Ti-VCT                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2023  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)                   Standard                            Standard              Standard  Limited                                        10         Automatic                  1FMSK7FH*PG
# 13  1FMSK8DH0NGA71727          2022 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG
# 14  1FMSK8DH9LGC24909          2020 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4            Standard                       In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TIVCT                                       Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*LG         119.10             18            18
# 15  1FMSK8DH9LGB63898      2020 Ford Explorer XLT 4WD              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4            Standard                       In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TIVCT                                       Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*LG         119.10             18            18
# 16  1FMSK8DH6NGB07064          2022 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG
# 17  1FMSK8DH9NGB20164          2022 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG
# 18  1FMSK8DH0NGA52109          2022 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG
# 19  1FM5K8D83KGA27066          2019 Ford Explorer XLT              Optional            Optional     Optional           3.5  4WD/4-Wheel Drive/4x4            Standard                      V-Shaped               6      290  3.5L Ti-VCT                                                   Class 2E: 6,001 - 7,000 lb (2,722 - 3,175 kg)                                     Optional       Optional                                   2019  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)                                                                                                Left-Hand Drive (LHD)                                       XLT             1FM5K8D8*KG         112.80             18            18
# 20  1FMSK8FH9MGA85086  2021 Ford Explorer Limited 4WD              Standard                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard  Limited  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8FH*MG          119.1             20            20
# 21  1FMSK8DH1LGB40518          2020 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4            Standard                       In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TIVCT                                       Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*LG         119.10             18            18
# 22  1FMSK8DH1LGD04611          2020 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4            Standard                       In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TIVCT                                       Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*LG         119.10             18            18
# 23  1FMSK8DHXLGB61691          2020 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4            Standard                       In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TIVCT                                       Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*LG         119.10             18            18
# 24  1FMSK8DHXLGA77872          2020 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4            Standard                       In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TIVCT                                       Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*LG         119.10             18            18
# 25  1FM5K8GC0LGA77814           2020 Ford Explorer ST              Standard                         Standard           3.0  4WD/4-Wheel Drive/4x4            Standard                      V-Shaped               6                  GTDI  Stoichiometric Gasoline Direct Injection (SGDI)  Class 2E: 6,001 - 7,000 lb (2,722 - 3,175 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)                   Standard                            Standard              Standard       ST  Left-Hand Drive (LHD)                 10         Automatic        Yes       1FM5K8GC*LG         119.10             20            20
# 26  1FMSK8FH2MGB36895      2021 Ford Explorer Limited              Standard                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard  Limited  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8FH*MG          119.1             20            20
# 27  1FMSK8FHXMGB54965      2021 Ford Explorer Limited              Standard                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard  Limited  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8FH*MG          119.1             20            20
# 28  1FMSK8FH2MGB07817      2021 Ford Explorer Limited              Standard                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard  Limited  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8FH*MG          119.1             20            20
# 29  1FMSK8FH8MGB37288      2021 Ford Explorer Limited              Standard                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard  Limited  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8FH*MG          119.1             20            20
# 30  1FMSK8DH1LGC57192          2020 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4            Standard                       In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TIVCT                                       Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*LG         119.10             18            18
# 31  1FMSK8FH5MGA88485      2021 Ford Explorer Limited              Standard                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard  Limited  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8FH*MG          119.1             20            20
# 32  1FMSK8FH4MGB36719      2021 Ford Explorer Limited              Standard                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard  Limited  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8FH*MG          119.1             20            20
# 33  1FMSK8FH5MGA96778      2021 Ford Explorer Limited              Standard                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard  Limited  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8FH*MG          119.1             20            20
# 34  1FMSK7DH5LGA58222          2020 Ford Explorer XLT              Optional                         Standard           2.3   RWD/Rear-Wheel Drive            Standard                       In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TIVCT                                       Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK7DH*LG         119.10             18            18
# 35  1FM5K8D8XHGC96884      2017 Ford Explorer XLT 4WD                                                                  3.5  4WD/4-Wheel Drive/4x4            Standard                      V-Shaped               6      290  3.5L Ti-VCT                                                   Class 2E: 6,001 - 7,000 lb (2,722 - 3,175 kg)                                                                                               2017                 Compact Utility (Utility Vehicle Categories "Small" and "Midsize")  Bronco (thru 1977)/Bronco II/Explorer/Explorer Sport (Explorer for 1990-2018 only.  For model years 2019 on, see 12-425.)                                                                                           XLT  Left-Hand Drive (LHD)                                                       1FM5K8D8*HG         112.80             18            18
# 36  1FMSK8DH0LGB93145          2020 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4            Standard                       In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TIVCT                                       Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*LG         119.10             18            18
# 37  1FMSK8DH4MGA00576              2021 Ford Explorer              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*MG          119.1             18            18
# 38  1FMSK8DH5MGA98632          2021 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      270                                                                Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2021  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)           TiVCT   Standard                            Standard              Standard      XLT  Left-Hand Drive (LHD)                 10         Automatic                  1FMSK8DH*MG          119.1             18            18
# 39  1FM5K8GC3LGA05280           2020 Ford Explorer ST              Standard                         Standard           3.0  4WD/4-Wheel Drive/4x4            Standard                      V-Shaped               6                  GTDI  Stoichiometric Gasoline Direct Injection (SGDI)  Class 2E: 6,001 - 7,000 lb (2,722 - 3,175 kg)                                     Standard       Standard                          LED      2020  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)                   Standard                            Standard              Standard       ST  Left-Hand Drive (LHD)                 10         Automatic        Yes       1FM5K8GC*LG         119.10             20            20
# 40  1FM5K8GT6HGD50410        2017 Ford Explorer Sport              Optional                         Optional           3.5  4WD/4-Wheel Drive/4x4            Standard                      V-Shaped               6      365    3.5L GTDI  Stoichiometric Gasoline Direct Injection (SGDI)  Class 2E: 6,001 - 7,000 lb (2,722 - 3,175 kg)                                                                                               2017                 Compact Utility (Utility Vehicle Categories "Small" and "Midsize")  Bronco (thru 1977)/Bronco II/Explorer/Explorer Sport (Explorer for 1990-2018 only.  For model years 2019 on, see 12-425.)                                                                                         Sport  Left-Hand Drive (LHD)                                             Yes       1FM5K8GT*HG         112.80             20            20
# 41  1FMSK8DH0NGB42229      2022 Ford Explorer XLT 4WD              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG
# 42  1FMSK8DH1NGA11262          2022 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG
# 43  1FMSK8DH5NGA17467          2022 Ford Explorer XLT              Optional                         Standard           2.3  4WD/4-Wheel Drive/4x4                                           In-Line               4      300     EcoBoost                                                   Class 1D: 5,001 - 6,000 lb (2,268 - 2,722 kg)                                     Standard       Standard                          LED      2022  Large utility (ANSI D16.1 Utility Vehicle Categories and "Full Size" and "Large")                                                             Explorer (For 2019 on.  For model years 1990-2018 see 12-401.)    Premium Fuel                                                             Standard      XLT                                        10         Automatic                  1FMSK8DH*NG

# %%
# statistics
print(df_vin_values['vin values', 'Model'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/openpilot/.venv/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3053, in MultiIndex.get_loc(self, key)
#    3052 try:
# -> 3053     return self._engine.get_loc(key)
#    3054 except KeyError as err:
#
# File index.pyx:771, in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2152, in pandas._libs.hashtable.UInt64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2176, in pandas._libs.hashtable.UInt64HashTable.get_item()
#
# KeyError: 455
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 # statistics
# ----> 2 print(df_vin_values['vin values', 'Model'].value_counts())
#
# File ~/openpilot/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4089, in DataFrame.__getitem__(self, key)
#    4087 if is_single_key:
#    4088     if self.columns.nlevels > 1:
# -> 4089         return self._getitem_multilevel(key)
#    4090     indexer = self.columns.get_loc(key)
#    4091     if is_integer(indexer):
#
# File ~/openpilot/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4147, in DataFrame._getitem_multilevel(self, key)
#    4145 def _getitem_multilevel(self, key):
#    4146     # self.columns is a MultiIndex
# -> 4147     loc = self.columns.get_loc(key)
#    4148     if isinstance(loc, (slice, np.ndarray)):
#    4149         new_columns = self.columns[loc]
#
# File ~/openpilot/.venv/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3055, in MultiIndex.get_loc(self, key)
#    3053     return self._engine.get_loc(key)
#    3054 except KeyError as err:
# -> 3055     raise KeyError(key) from err
#    3056 except TypeError:
#    3057     # e.g. test_partial_slicing_with_multiindex partial string slicing
#    3058     loc, _ = self.get_loc_level(key, list(range(self.nlevels)))
#
# KeyError: ('vin values', 'Model')

# %% [markdown]
# # Compare original openpilot FW matching vs custom fuzzy matcher

# %%
from cereal import car
from panda.python.uds import DATA_IDENTIFIER_TYPE
from openpilot.selfdrive.car.fw_query_definitions import EcuAddrSubAddr
from openpilot.selfdrive.car.ford.tests.test_ford import ECU_ADDRESSES as FW_ECUS

Ecu = car.CarParams.Ecu

FW_ECUS = FW_ECUS.copy()
FW_ECUS.pop(Ecu.shiftByWire)

# ECU_ADDRESS_TO_NAME = {v: k for k, v in ECU_ADDRESSES.items()}

def get_fw_dict(vin: str) -> dict[EcuAddrSubAddr, list[bytes]]:
  car_fw = {}
  for addr, ecu_data in get_car_ecu_data(vin).items():
    if addr not in FW_ECUS.values():
      continue
    # ecu = ECU_ADDRESS_TO_NAME[addr]

    fw = ecu_data[DATA_IDENTIFIER_TYPE.VEHICLE_MANUFACTURER_ECU_SOFTWARE_NUMBER]
    fw_length = 24
    fw = fw.encode()
    fw = (fw + b'\x00' * fw_length)[:fw_length]

    car_fw[(addr, None)] = [fw]
  return car_fw

print(candidate, get_fw_dict(candidate))
# Out:
# 1FMSK8DH1NGA52944 {(1798, None): [b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'], (1840, None): [b'M1MC-14D003-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'], (1888, None): [b'L1MC-2D053-KB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'], (2016, None): [b'NB5A-14C204-ARC\x00\x00\x00\x00\x00\x00\x00\x00\x00']}

# %%
from cereal import car
from openpilot.selfdrive.car.fw_query_definitions import LiveFwVersions
from openpilot.selfdrive.car.fw_versions import match_fw_to_car_fuzzy as match_op_fuzzy
from openpilot.selfdrive.car.ford.fingerprints import FW_VERSIONS as FORD_FW_VERSIONS
from openpilot.selfdrive.car.ford.values import match_fw_to_car_fuzzy as match_custom_fuzzy

Ecu = car.CarParams.Ecu
ESSENTIAL_ECUS = [Ecu.engine, Ecu.eps, Ecu.abs, Ecu.fwdRadar, Ecu.fwdCamera, Ecu.vsa]

def match_fw_to_car_exact(live_fw_versions: LiveFwVersions) -> set[str]:
  """Do an exact FW match. Returns all cars that match the given
  FW versions for a list of "essential" ECUs. If an ECU is not considered
  essential the FW version can be missing to get a fingerprint, but if it's present it
  needs to match the database."""
  invalid = set()
  candidates = FORD_FW_VERSIONS

  for candidate, fws in candidates.items():
    for ecu, expected_versions in fws.items():
      ecu_type = ecu[0]
      addr = ecu[1:]

      found_versions = live_fw_versions.get(addr, set())
      if not len(found_versions):
        # Some models can sometimes miss an ecu, or show on two different addresses
        # FIXME: this logic can be improved to be more specific, should require one of the two addresses
        # if candidate in config.non_essential_ecus.get(ecu_type, []):
        #   continue

        # Ignore non essential ecus
        if ecu_type not in ESSENTIAL_ECUS:
          continue

      # Virtual debug ecu doesn't need to match the database
      if ecu_type == Ecu.debug:
        continue

      if not any(found_version in expected_versions for found_version in found_versions):
        invalid.add(candidate)
        break

  return set(candidates.keys()) - invalid

def match_fw_to_car(fw_versions_dict: LiveFwVersions, allow_fuzzy: bool, allow_custom_fuzzy: bool) -> tuple[bool, set[str]]:
  # Attempt to fingerprint using all FW returned from its queries
  matches = match_fw_to_car_exact(fw_versions_dict)
  if len(matches):
    return True, matches

  matches = match_op_fuzzy(fw_versions_dict, log=False)

  # If specified and no matches so far, fall back to brand's fuzzy fingerprinting function
  if allow_custom_fuzzy and not len(matches):
    matches |= match_custom_fuzzy(fw_versions_dict, FORD_FW_VERSIONS)

  if len(matches):
    return False, matches

  return True, set()


def get_fingerprint(fw_versions_dict: LiveFwVersions, allow_fuzzy=True, allow_custom_fuzzy=False) -> tuple[bool, str]:
  exact_match, matches = match_fw_to_car(fw_versions_dict, allow_fuzzy, allow_custom_fuzzy)
  if len(matches) == 0:
    return False, "mock"
  elif len(matches) == 1:
    return not exact_match, matches.pop()
  else:
    return not exact_match, "multiple"


def run_fw_test(vins):
  df_matches_rows = []
  columns = ['VIN', 'Model', 'ModelYear', 'ExistingFingerprint', 'ExistingFuzzy', 'NewFingerprint', 'NewFuzzy']
  for vin in vins:
    fw_versions_dict = get_fw_dict(vin)

    # uses exact/fuzzy matching
    fuzzy, fingerprint = get_fingerprint(fw_versions_dict)

    # uses exact/fuzzy matching + custom match_fw_to_car_fuzzy from fw config
    new_fuzzy, new_fingerprint = get_fingerprint(fw_versions_dict, allow_custom_fuzzy=True)

    values = df_vin_values[df_vin_values['details', 'vin'] == vin].iloc[0]
    df_matches_rows.append((vin, 'Explorer', values['vin values', 'ModelYear'],
                            fingerprint, fuzzy, new_fingerprint, new_fuzzy))
  df_matches = pd.DataFrame(df_matches_rows, columns=columns)
  df_matches.sort_values(by=['Model', 'ModelYear'], inplace=True, ascending=[True, True])
  return df_matches

# %%
vins = set(df_vin_values['details', 'vin'])
df_fw_test = run_fw_test(vins)

def get_result(row):
  if row['ExistingFingerprint'] == 'mock' and row['NewFingerprint'] == 'mock':
    return 'mock -> mock'
  elif row['ExistingFingerprint'] == 'mock':
    return 'mock -> fp'
  elif row['NewFingerprint'] == 'mock':
    return 'fp -> mock'
  else:
    return 'fp -> fp'

def trim_vin(row):
  return row['VIN'][0:12] + 'X' * 6

df_fw_test['Result'] = df_fw_test.apply(get_result, axis=1)
df_fw_test['VIN'] = df_fw_test.apply(trim_vin, axis=1)
print(df_fw_test.shape)
df_fw_test
# Out:
# (44, 8)
#                    VIN     Model ModelYear    ExistingFingerprint  \
# 14  1FM5K8GT6HGDXXXXXX  Explorer      2017                   mock
# 23  1FM5K8D8XHGCXXXXXX  Explorer      2017                   mock
# 29  1FM5K8D83KGAXXXXXX  Explorer      2019                   mock
# 0   1FMSK8DH1LGCXXXXXX  Explorer      2020                   mock
# 4   1FM5K8GC3LGAXXXXXX  Explorer      2020  FORD EXPLORER 6TH GEN
# 5   1FMSK8DH0LGBXXXXXX  Explorer      2020                   mock
# 17  1FMSK8DH1LGBXXXXXX  Explorer      2020  FORD EXPLORER 6TH GEN
# 20  1FMSK8DH9LGCXXXXXX  Explorer      2020                   mock
# 21  1FMSK8DH1LGDXXXXXX  Explorer      2020                   mock
# 25  1FMSK8DHXLGAXXXXXX  Explorer      2020                   mock
# 32  1FMSK8DHXLGBXXXXXX  Explorer      2020  FORD EXPLORER 6TH GEN
# 33  1FMSK8DH1LGBXXXXXX  Explorer      2020                   mock
# 35  1FM5K8GC0LGAXXXXXX  Explorer      2020  FORD EXPLORER 6TH GEN
# 37  1FMSK8DH9LGBXXXXXX  Explorer      2020                   mock
# 38  1FMSK7DH5LGAXXXXXX  Explorer      2020                   mock
# 41  1FMSK8DH9LGBXXXXXX  Explorer      2020                   mock
# 1   1FMSK8DH7MGCXXXXXX  Explorer      2021                   mock
# 2   1FMSK8FH9MGAXXXXXX  Explorer      2021                   mock
# 7   1FMSK8FH2MGBXXXXXX  Explorer      2021                   mock
# 11  1FMSK8FH5MGAXXXXXX  Explorer      2021                   mock
# 12  1FMSK8FH5MGAXXXXXX  Explorer      2021                   mock
# 15  1FMSK8FH2MGBXXXXXX  Explorer      2021                   mock
# 16  1FMSK8DH9MGBXXXXXX  Explorer      2021                   mock
# 22  1FMSK8FH8MGBXXXXXX  Explorer      2021                   mock
# 27  1FMSK8FHXMGBXXXXXX  Explorer      2021                   mock
# 30  1FMSK8DH5MGAXXXXXX  Explorer      2021                   mock
# 39  1FMSK8FH4MGBXXXXXX  Explorer      2021                   mock
# 42  1FMSK8DH4MGAXXXXXX  Explorer      2021                   mock
# 43  1FMSK8DH8MGAXXXXXX  Explorer      2021                   mock
# 3   1FMSK8DH7NGBXXXXXX  Explorer      2022  FORD EXPLORER 6TH GEN
# 6   1FMSK8DH5NGAXXXXXX  Explorer      2022                   mock
# 8   1FMSK8DH0NGAXXXXXX  Explorer      2022                   mock
# 9   1FMSK8DH6NGBXXXXXX  Explorer      2022  FORD EXPLORER 6TH GEN
# 10  1FMSK8DH6NGBXXXXXX  Explorer      2022                   mock
# 13  1FMSK8DH9NGBXXXXXX  Explorer      2022  FORD EXPLORER 6TH GEN
# 18  1FMSK8FH7NGAXXXXXX  Explorer      2022                   mock
# 24  1FMSK8DH0NGBXXXXXX  Explorer      2022  FORD EXPLORER 6TH GEN
# 26  1FMSK8DH1NGAXXXXXX  Explorer      2022                   mock
# 28  1FMSK8DH0NGAXXXXXX  Explorer      2022                   mock
# 31  1FMSK8DH3NGAXXXXXX  Explorer      2022                   mock
# 34  1FMSK8DH8NGAXXXXXX  Explorer      2022                   mock
# 36  1FMSK8DH4NGAXXXXXX  Explorer      2022                   mock
# 40  1FMSK8DH1NGAXXXXXX  Explorer      2022                   mock
# 19  1FMSK7FHXPGAXXXXXX  Explorer      2023                   mock
#
#     ExistingFuzzy         NewFingerprint  NewFuzzy        Result
# 14          False                   mock     False  mock -> mock
# 23          False                   mock     False  mock -> mock
# 29          False                   mock     False  mock -> mock
# 0           False                   mock     False  mock -> mock
# 4           False  FORD EXPLORER 6TH GEN     False      fp -> fp
# 5           False                   mock     False  mock -> mock
# 17           True  FORD EXPLORER 6TH GEN      True      fp -> fp
# 20          False                   mock     False  mock -> mock
# 21          False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 25          False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 32          False  FORD EXPLORER 6TH GEN     False      fp -> fp
# 33          False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 35          False  FORD EXPLORER 6TH GEN     False      fp -> fp
# 37          False                   mock     False  mock -> mock
# 38          False                   mock     False  mock -> mock
# 41          False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 1           False                   mock     False  mock -> mock
# 2           False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 7           False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 11          False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 12          False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 15          False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 16          False                   mock     False  mock -> mock
# 22          False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 27          False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 30          False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 39          False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 42          False                   mock     False  mock -> mock
# 43          False                   mock     False  mock -> mock
# 3            True  FORD EXPLORER 6TH GEN      True      fp -> fp
# 6           False                   mock     False  mock -> mock
# 8           False                   mock     False  mock -> mock
# 9            True  FORD EXPLORER 6TH GEN      True      fp -> fp
# 10          False                   mock     False  mock -> mock
# 13           True  FORD EXPLORER 6TH GEN      True      fp -> fp
# 18          False  FORD EXPLORER 6TH GEN      True    mock -> fp
# 24          False  FORD EXPLORER 6TH GEN     False      fp -> fp
# 26          False                   mock     False  mock -> mock
# 28          False                   mock     False  mock -> mock
# 31          False                   mock     False  mock -> mock
# 34          False                   mock     False  mock -> mock
# 36          False                   mock     False  mock -> mock
# 40          False                   mock     False  mock -> mock
# 19          False  FORD EXPLORER 6TH GEN      True    mock -> fp

# %%
# statistics
df_fw_test_results = df_fw_test[['Result']].copy()
df_fw_test_results['Count'] = 1
df_fw_test_results = df_fw_test_results.groupby(['Result']).count()
df_fw_test_results.reset_index(inplace=True)
df_fw_test_results.columns = ['Result', 'Count']
df_fw_test_results['%'] = (df_fw_test_results['Count'] / df_fw_test_results['Count'].sum() * 100).round(1)
df_fw_test_results
# Out:
#          Result  Count     %
# 0      fp -> fp      8  18.2
# 1    mock -> fp     15  34.1
# 2  mock -> mock     21  47.7

# %%
from openpilot.selfdrive.car.ford.values import CAR

ALL_ECUS = {k: v for k, v in Ecu.__dict__.items() if isinstance(v, int)}
ECU_LOOKUP = {addr: ecu for ecu, addr in ALL_ECUS.items()}
FW_ECUS_BY_ADDR = {addr: ecu for ecu, addr in FW_ECUS.items()}

def check_fw_database(df):
  for _, row in df.iterrows():
    vin = row['VIN']
    print(row[['VIN', 'Model', 'ModelYear']].to_string())
    print('FW:')

    fw_rows = []
    for addr, fws in get_fw_dict(vin).items():
      ecu = FW_ECUS_BY_ADDR[addr[0]]
      fw = fws[0]

      known_fw = fw in FORD_FW_VERSIONS[CAR.EXPLORER_MK6][(ecu, *addr)]

      fw_rows.append((ECU_LOOKUP[ecu], fw, known_fw))
    df_fw = pd.DataFrame(fw_rows, columns=['ECU', 'FW', 'In Database'])
    print(df_fw.to_string())
    print()

# %%
def is_changed_from_mock(row):
  return row['ExistingFingerprint'] == 'mock' and row['Changed']

df_new_fps = df_fw_test[df_fw_test.apply(is_changed_from_mock, axis=1)].copy()
check_fw_database(df_new_fps)
# Out:
# VIN          1FMSK8DH1LGD04611
# Model                 Explorer
# ModelYear                 2020
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BD\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'LB5A-14C204-EAE\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DHXLGA77872
# Model                 Explorer
# ModelYear                 2020
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AJ\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BA\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'LB5A-14C204-BVJ\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH1LGB40518
# Model                 Explorer
# ModelYear                 2020
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AK\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BA\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'LB5A-14C204-EAE\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH9LGB63898
# Model                 Explorer
# ModelYear                 2020
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AK\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'LB5A-14C204-EAE\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8FH9MGA85086
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'MB5A-14C204-ASA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8FH2MGB36895
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'MB5A-14C204-ASA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8FH5MGA88485
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'MB5A-14C204-ASA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8FH5MGA96778
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'MB5A-14C204-ASA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8FH2MGB07817
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'MB5A-14C204-ASA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8FH8MGB37288
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'MB5A-14C204-ASA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8FHXMGB54965
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'MB5A-14C204-ASA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH5MGA98632
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'MB5A-14C204-ASA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8FH4MGB36719
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'MB5A-14C204-ASA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8FH7NGA39693
# Model                 Explorer
# ModelYear                 2022
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'M1MC-14D003-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-KB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'NB5A-14C204-ARD\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK7FHXPGA86567
# Model                 Explorer
# ModelYear                 2023
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'P1MC-14D003-AA\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-KB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3   fwdRadar     b'LB5T-14D049-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 4     engine        b'PB5A-14C204-ABA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False

# %%
def is_not_changed_from_mock(row):
  return row['ExistingFingerprint'] == 'mock' and not row['Changed']

df_mock_unchanged = df_fw_test[df_fw_test.apply(is_not_changed_from_mock, axis=1)].copy()
check_fw_database(df_mock_unchanged)
# Out:
# VIN          1FM5K8GT6HGD50410
# Model                 Explorer
# ModelYear                 2017
# FW:
#       ECU                                                            FW  In Database
# 0  engine     b'GB5A-14C204-PJ\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 1     eps     b'HB53-14D003-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 2     abs  b'HB53-2D053-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FM5K8D8XHGC96884
# Model                 Explorer
# ModelYear                 2017
# FW:
#       ECU                                                            FW  In Database
# 0  engine     b'HB5A-14C204-BC\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 1     eps     b'HB53-14D003-AE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 2     abs  b'HB53-2D053-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FM5K8D83KGA27066
# Model                 Explorer
# ModelYear                 2019
# FW:
#       ECU                                                            FW  In Database
# 0  engine     b'KB5A-14C204-RC\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 1     eps     b'HB53-14D003-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 2     abs  b'HB53-2D053-BA\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH1LGC57192
# Model                 Explorer
# ModelYear                 2020
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AK\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BC\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 3     engine        b'LB5A-14C204-EAC\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
#
# VIN          1FMSK8DH0LGB93145
# Model                 Explorer
# ModelYear                 2020
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AK\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3     engine        b'LB5A-14C204-EBC\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH9LGC24909
# Model                 Explorer
# ModelYear                 2020
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AK\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BC\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 3     engine        b'LB5A-14C204-EAC\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
#
# VIN          1FMSK8DH9LGB14815
# Model                 Explorer
# ModelYear                 2020
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AK\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BA\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3     engine        b'LB5A-14C204-BUM\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK7DH5LGA58222
# Model                 Explorer
# ModelYear                 2020
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AJ\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BA\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3     engine        b'LB5A-14C204-BUL\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH7MGC46036
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'M1MC-14D003-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BJ\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 3     engine        b'MB5A-14C204-BUC\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH9MGB42406
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3     engine        b'MB5A-14C204-ARA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH4MGA00576
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 3     engine     b'MB5A-14C204-BC\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH8MGA39221
# Model                 Explorer
# ModelYear                 2021
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'L1MC-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 3     engine     b'MB5A-14C204-BC\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH5NGA17467
# Model                 Explorer
# ModelYear                 2022
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'M1MC-14D003-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BJ\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 3     engine        b'NB5A-14C204-BCA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH0NGA52109
# Model                 Explorer
# ModelYear                 2022
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'M1MC-14D003-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-KB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3     engine        b'NB5A-14C204-ARC\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH6NGB07064
# Model                 Explorer
# ModelYear                 2022
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'M1MC-14D003-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-KB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3     engine        b'NB5A-14C204-AZC\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH1NGA11262
# Model                 Explorer
# ModelYear                 2022
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'M1MC-14D003-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-BJ\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
# 3     engine        b'NB5A-14C204-BCA\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH0NGA71727
# Model                 Explorer
# ModelYear                 2022
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'M1MC-14D003-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-KB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3     engine        b'NB5A-14C204-AZF\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH3NGA52377
# Model                 Explorer
# ModelYear                 2022
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'M1MC-14D003-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-KB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3     engine        b'NB5A-14C204-ARC\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH8NGA60359
# Model                 Explorer
# ModelYear                 2022
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'M1MC-14D003-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-KB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3     engine        b'NB5A-14C204-ARD\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH4NGA87686
# Model                 Explorer
# ModelYear                 2022
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'M1MC-14D003-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-KB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3     engine        b'NB5A-14C204-ARC\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
#
# VIN          1FMSK8DH1NGA52944
# Model                 Explorer
# ModelYear                 2022
# FW:
#          ECU                                                            FW  In Database
# 0  fwdCamera     b'LB5T-14F397-AF\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 1        eps     b'M1MC-14D003-AB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 2        abs  b'L1MC-2D053-KB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'         True
# 3     engine        b'NB5A-14C204-ARC\x00\x00\x00\x00\x00\x00\x00\x00\x00'        False
