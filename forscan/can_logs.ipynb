# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ['FILEREADER_CACHE'] = '1'

from openpilot.tools.lib.logreader import LogReader


class Routes:
  ZERO = 'e886087f430e7fe7/2024-02-06--18-40-35'
  ONE = 'e886087f430e7fe7/2024-02-06--18-46-09'
  TWO = 'e886087f430e7fe7/2024-02-06--18-51-31'
  THREE = 'e886087f430e7fe7/2024-02-06--18-58-28'
  # FOUR = 'e886087f430e7fe7/2024-02-06--19-00-24'
  # FIVE = 'e886087f430e7fe7/2024-02-06--19-01-21'
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /mnt/c/Users/camer/AppData/Local/Programs/Microsoft VS Code

# %%
def process(route):
  rows = []

  initTime = None
  for event in LogReader(route):
    if not initTime:
      initTime = event.logMonoTime
    if event.which() != 'can':
      continue

    # time = (event.logMonoTime - initTime) / 1e9
    for can in event.can:
      # if can.dat.startswith(TESTER_PRESENT_REQUEST) or can.dat.startswith(SINGLE_FRAME_TESTER_PRESENT_REQUEST):
      #   print(f'{can.address:x} {can.dat.hex()} TESTER PRESENT')
      # if can.dat.startswith(TESTER_PRESENT_RESPONSE) or can.dat.startswith(SINGLE_FRAME_TESTER_PRESENT_RESPONSE):
      #   print(f'{can.address:x} {can.dat.hex()} TESTER PRESENT RESPONSE')
      if can.src >= 4:
        continue
      if can.address < 0x550:
        continue
      # if can.address in (ADDR, RX_ADDR):
      # print(f'{can.address:x} {can.dat.hex()}')
      rows.append(((can.src, can.address), can.dat))

  return rows

# %%
from collections import defaultdict

from notebooks.forscan.isotp import parse_iso_tp


msgs = {}
for route in (Routes.ZERO, Routes.ONE, Routes.TWO, Routes.THREE):
  msgs[route] = process(route)
  count = defaultdict(int)
  for (src, address), dat in msgs[route]:
    frame = parse_iso_tp(dat)
    if frame is not None:
      count[address] += 1
  print(route, count)
# Out:
# e886087f430e7fe7/2024-02-06--18-40-35 defaultdict(<class 'int'>, {2019: 6, 1892: 90, 1900: 112, 1888: 148, 1896: 131, 1847: 214, 1855: 124, 1840: 100, 1848: 106, 1798: 53, 1806: 104, 1783: 3, 1782: 3})
# e886087f430e7fe7/2024-02-06--18-46-09 defaultdict(<class 'int'>, {1892: 52, 1900: 68, 1888: 270, 1896: 336, 1847: 18, 1855: 14, 1840: 430, 1848: 438, 1798: 187, 1806: 313})
# e886087f430e7fe7/2024-02-06--18-51-31 defaultdict(<class 'int'>, {1798: 192, 1806: 220, 1840: 244, 1848: 143})
# e886087f430e7fe7/2024-02-06--18-58-28 defaultdict(<class 'int'>, {1840: 1356, 1848: 678})

# %%
from notebooks.forscan.isotp import parse_iso_tp


iso_tp_frames = []
for addr, data in msgs[Routes.ZERO] + msgs[Routes.ONE] + msgs[Routes.TWO]:
  # if addr[1] not in (1840, 1848):
  #   continue
  # if addr[1] in (1430, 1438, 1459, 1461):
  #   continue
  # if addr not in (ADDR, RX_ADDR):
  #   continue

  frame = parse_iso_tp(data)
  if frame is not None:
    # print(f'{addr=}', frame)
    # if addr[0] in (0, 1):
    iso_tp_frames.append((addr[1], frame))
  # else:
  #   print(f'Failed to parse {addr=}', data.hex())

len(iso_tp_frames)
# Out:
# 4119

# %%
from collections import defaultdict

def reconstruct_iso_tp_messages(frames):
  """
  Reconstructs complete ISO-TP payloads from a sequence of CAN messages.

  Args:
      msgs: A list of tuples (address, data), where address is the CAN address and
            data is the CAN message payload as bytes.

  Returns:
      A list of dictionaries representing the reconstructed messages, each containing:
          'addr': The CAN address where the message was received.
          'payload': The complete reassembled message payload as bytes.
  """

  reconstructed_msgs = []
  in_progress = defaultdict(list)  # To store partial frames of a message

  for addr, frame in frames:
    if frame.frame_type == 'single':
      reconstructed_msgs.append({'addr': addr, 'payload': frame.payload})

    elif frame.frame_type == 'first':
      # Start a new reconstruction - clear buffer in case any was in progress
      if len(in_progress[addr]):
        print(f'Warning: Discarding incomplete message from {addr:x}')
      in_progress[addr].clear() 
      in_progress[addr].append(frame)

    elif frame.frame_type == 'consecutive':
      if len(in_progress[addr]) == 0:
        print(f'Warning: Discarding orphaned consecutive frame from {addr:x}')
        continue

      in_progress[addr].append(frame)

      # Check if all segments are received based on expected size from First frame
      if sum(len(f.payload) for f in in_progress[addr]) >= in_progress[addr][0].size:
        payload = b''.join(f.payload for f in in_progress[addr])
        # Trim payload to expected size
        payload = payload[:in_progress[addr][0].size]
        assert len(payload) == in_progress[addr][0].size
        reconstructed_msgs.append({'addr': addr, 'payload': payload})
        in_progress[addr].clear()  # Message assembled - clear the buffer

    # Optionally handle potential FlowControlFrame if applicable, else it is discarded silently

  return reconstructed_msgs

reconstructed = reconstruct_iso_tp_messages(iso_tp_frames)
# for msg in reconstructed:
#   print(msg)
# Out:
# Warning: Discarding incomplete message from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding incomplete message from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding incomplete message from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding incomplete message from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding incomplete message from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding incomplete message from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 760
# Warning: Discarding orphaned consecutive frame from 760
# Warning: Discarding orphaned consecutive frame from 760
# Warning: Discarding incomplete message from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding incomplete message from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding incomplete message from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding incomplete message from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding orphaned consecutive frame from 76c
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding incomplete message from 730
# Warning: Discarding orphaned consecutive frame from 730
# Warning: Discarding orphaned consecutive frame from 730

# %%
from notebooks.ford.ecu import FordEcu
from notebooks.forscan.uds import parse_uds

ADDRS = [
  FordEcu.AccessoryProtocolInterfaceModule,
  FordEcu.ImageProcessingModuleA,
  FordEcu.PowerSteeringControlModule,
]
ADDRS = ADDRS + [addr + 0x8 for addr in ADDRS]

for msg in reconstructed:
  if msg['addr'] not in ADDRS:
    continue
  uds = parse_uds(msg['payload'])
  if uds is None:
    print(f'Failed to parse {msg=}')
    continue
  print({ 'addr': msg['addr'], **uds })
# Out:
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': '0200'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data':
}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de00'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de00'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de00ff000a8c02000250003d4d0dcd0000000000000000000000'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de01'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de01'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de01ffffffffffffffffff00ff00000000000000000000000000'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de02'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de02'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de02ffff00000200ff0000000000000000000000000000000000'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de03'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de03'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de03000000000000000000000000000000000000000000000000'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de04'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de04'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'de04000000000000000000000000000000000000000000000000'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd111'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd111'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd11195'}
# {'addr': 1840, 'type': 'request', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de01ffffffffffffff00ff00ffffffff00ff00ff000000000000'}
# {'addr': 1848, 'type': 'negative_response', 'data': '2e7f'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03003201f4'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03'}
# {'addr': 1840, 'type': 'request', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de01ffffffffffffff00ff00ffffffff00ff00ff000000000000'}
# {'addr': 1848, 'type': 'negative_response', 'data': '2e33'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd10003'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'f162'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'f162'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'f16206'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd10003'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '03'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '03'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'SECURITY_ACCESS', 'data': '03b117fb87220eebd1abd82bba8094d42a'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '045305dc9f0c61117137ccbec88e336e7d'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '045305dc9f0c61117137ccbec88e336e7d'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'SECURITY_ACCESS', 'data': '04'}
# {'addr': 1840, 'type': 'request', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de01ffffffffffffff00ff00ffffffff00ff00ff000000000000'}
# {'addr': 1848, 'type': 'negative_response', 'data': '2e78'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de01'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd10003'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01003201f4'}
# {'addr': 1840, 'type': 'request', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03003201f4'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd10003'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '03'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '03'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'SECURITY_ACCESS', 'data': '03b73c28fad055600ec1fef221ded8c2da'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '0457b2e21baa953f5611e174d5351dd0a5'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'SECURITY_ACCESS', 'data': '04'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '0457b2e21baa953f5611e174d5351dd0a5'}
# {'addr': 1840, 'type': 'request', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de01ffffffff000000000000ffffffffffff00ff000000000000'}
# {'addr': 1848, 'type': 'negative_response', 'data': '2e78'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de01'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd10003'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01003201f4'}
# {'addr': 1840, 'type': 'request', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03003201f4'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd10003'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '03'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '03'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'SECURITY_ACCESS', 'data': '035b56404f64411b9dc5525eec922c7ef6'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '04b9dc234045252ac81344deb0be2b2df0'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '04b9dc234045252ac81344deb0be2b2df0'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'SECURITY_ACCESS', 'data': '04'}
# {'addr': 1840, 'type': 'request', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de01ffffffffffffffff0000ff00000000000000000000000000'}
# {'addr': 1848, 'type': 'negative_response', 'data': '2e78'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de01'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd10003'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01003201f4'}
# {'addr': 1840, 'type': 'request', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03003201f4'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd10003'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '03'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '03'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'SECURITY_ACCESS', 'data': '035767484af0c9c60961e0bc7afe99518b'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '0416ef6b9dc9f90ae0b367e8882e74fc2d'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '0416ef6b9dc9f90ae0b367e8882e74fc2d'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'SECURITY_ACCESS', 'data': '04'}
# {'addr': 1840, 'type': 'request', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de01ffffffffffffffffff00ffffffffffff00ff000000000000'}
# {'addr': 1848, 'type': 'negative_response', 'data': '2e78'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de01'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd10003'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01003201f4'}
# {'addr': 1840, 'type': 'request', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03003201f4'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd10003'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '03'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '03'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '03'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'SECURITY_ACCESS', 'data': '034de46706ce77aae0e73049f40c784de5'}
# {'addr': 1840, 'type': 'request', 'service': 'SECURITY_ACCESS', 'data': '0461eac70292ae2d8ffa17b492ae2d8ffa'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'SECURITY_ACCESS', 'data': '04'}
# {'addr': 1840, 'type': 'request', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de02ffffff000200ff0000000000000000000000000000000000'}
# {'addr': 1840, 'type': 'request', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de02ffffff000200ff0000000000000000000000000000000000'}
# {'addr': 1848, 'type': 'negative_response', 'data': '2e78'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'WRITE_DATA_BY_IDENTIFIER', 'data': 'de02'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1840, 'type': 'request', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd100'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'READ_DATA_BY_IDENTIFIER', 'data': 'd10003'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01003201f4'}
# {'addr': 1840, 'type': 'request', 'service': 'DIAGNOSTIC_SESSION_CONTROL', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1840, 'type': 'request', 'service': 'ECU_RESET', 'data': '01'}
# {'addr': 1848, 'type': 'positive_response', 'service': 'ECU_RESET', 'data': '01'}
