# %%
# %load_ext autoreload
# %autoreload 2

# %%
from vins import load_vins

vins = load_vins()
# Out:
# Loaded 1263 VINs (filter_comment=None, include_openpilot=False, skipped=81)
# Loaded AsBuilt data for 1263 VINs

# %%
import random

import pandas as pd

from asbuilt import AsBuiltData
from settings import VEHICLE_SETTINGS

pd.set_option('display.max_columns', None)

rows = []
for vin in ('WF0NXXGCHNJR69712', *random.sample(vins, 9)):
  abd = AsBuiltData.from_vin(vin)
  rows.append([vin, *map(lambda s: abd.get_setting_value(s), VEHICLE_SETTINGS)])

columns = [('', 'VIN'), *map(lambda s: (s.ecu.name, s.comment), VEHICLE_SETTINGS)]

df = pd.DataFrame(rows, columns=pd.MultiIndex.from_tuples(columns))
df
# Out:
#                            ImageProcessingModuleA                 \
#                  VIN                      Vehicle Distance Alert
# 0  WF0NXXGCHNJR69712                 C519 (Focus)            Off
# 1  1FMSK8DH6LGA25297              U625 (Explorer)             On
# 2  3FMCR9C63MRA00972  CX430 (Bronco Sport OnRoad)             On
# 3  3FTTW8F95PRA38382              P758 (Maverick)            Off
# 4  1FMCU9H68NUB24320          CX482 (Escape/Kuga)            Off
# 5  1FM5K8FW1MNA02130              U625 (Explorer)             On
# 6  1FM5K8GC3PGB93174              U625 (Explorer)             On
# 7  3FADP4BJ1KM157309                      Missing        Missing
# 8  3FADP4BJ2KM128160                      Missing        Missing
# 9  1FMCU0G62MUA06596          CX482 (Escape/Kuga)             On
#
#                                                                   \
#   Forward Collision Warning HUD High Beam Lane Departure Warning
# 0                           Off       Off                     On
# 1                           Off      AHBC                     On
# 2                           Off      AHBC                     On
# 3                           Off      AHBC                    Off
# 4                           Off      AHBC                     On
# 5                           Off      AHBC                     On
# 6                           Off      AHBC                     On
# 7                       Missing   Missing                Missing
# 8                       Missing   Missing                Missing
# 9                           Off      AHBC                     On
#
#                                                                  \
#   Lane Keeping Aid Driver Alert System Traffic Sign Recognition
# 0               On                 Off                       On
# 1               On                  On                       On
# 2               On                  On                       On
# 3               On                 Off                      Off
# 4               On                  On                      Off
# 5               On                  On                       On
# 6               On                  On                       On
# 7          Missing             Missing                  Missing
# 8          Missing             Missing                  Missing
# 9               On                  On                       On
#
#                                                                              \
#   Traffic Sign Recognition Mode Traffic Sign Recognition Feature LKS Switch
# 0                   Camera Only                             SLIF    Network
# 1                        Fusion                             SLIF    Network
# 2                        Fusion                             SLIF    Network
# 3                        Fusion                              Off  No Switch
# 4                        Fusion                              Off    Network
# 5                        Fusion                             SLIF    Network
# 6                        Fusion                             SLIF    Network
# 7                       Missing                          Missing    Missing
# 8                       Missing                          Missing    Missing
# 9                        Fusion                             SLIF    Network
#
#                                                                           \
#   Pre-Collision Assist Type   Enable ACC Driving Side Region and Country
# 0              Radar Fusion          Off         Left               0x25
# 1              Radar Fusion  RadarFusion        Right               0x7A
# 2              Radar Fusion  RadarFusion        Right               0x7A
# 3               Camera Only          Off        Right               0x75
# 4               Camera Only          Off        Right               0x75
# 5              Radar Fusion  RadarFusion        Right               0x7A
# 6              Radar Fusion  RadarFusion        Right               0x7A
# 7                   Missing      Missing      Missing            Missing
# 8                   Missing      Missing      Missing            Missing
# 9              Radar Fusion  RadarFusion        Right               0x7A
#
#                                                           \
#   Enable TJA Windshield Type  LKS Actuator Shift by Wire
# 0        Off        Acoustic          EPAS           Off
# 1         On       IR Coated          EPAS            On
# 2         On        Acoustic          EPAS            On
# 3        Off            Base  Haptic Motor            On
# 4        Off        Acoustic          EPAS            On
# 5         On       IR Coated          EPAS            On
# 6         On       IR Coated          EPAS            On
# 7    Missing         Missing       Missing       Missing
# 8    Missing         Missing       Missing       Missing
# 9         On        Acoustic          EPAS            On
#
#                         PowerSteeringControlModule                   \
#   Speed Limit Sign Unit     Lane Departure Warning Lane Keeping Aid
# 0                   MPH                    Enabled          Enabled
# 1                   MPH                    Enabled          Enabled
# 2                   MPH                    Enabled          Enabled
# 3                   MPH                   Disabled         Disabled
# 4                   MPH                    Enabled          Enabled
# 5                   MPH                    Enabled          Enabled
# 6                   MPH                    Enabled          Enabled
# 7               Missing                    Missing          Missing
# 8               Missing                    Missing          Missing
# 9                   MPH                    Enabled          Enabled
#
#                                            AntiLockBrakeSystem  \
#   Traffic Jam Assist Lane Centering Assist   Wheel base preset
# 0           Disabled              Disabled            Reserved
# 1            Enabled               Enabled            Reserved
# 2            Enabled               Enabled            Reserved
# 3           Disabled              Disabled            Reserved
# 4           Disabled              Disabled            Reserved
# 5            Enabled               Enabled            Reserved
# 6            Enabled               Enabled            Reserved
# 7            Missing               Missing               141in
# 8            Missing               Missing               141in
# 9            Enabled               Enabled            Reserved
#
#                                                    \
#     Steering Gear Cruise Control Mode Stop and Go
# 0       EPAS 21:1              Normal     Without
# 1       EPAS 17:1      Unknown (0x01)     Without
# 2       EPAS 17:1              Normal     Without
# 3        Reserved              Normal     Without
# 4       EPAS 17:1              Normal     Without
# 5        Reserved      Unknown (0x01)     Without
# 6       EPAS 17:1      Unknown (0x01)     Without
# 7  Unknown (0x03)      Unknown (0x00)     Missing
# 8  Unknown (0x03)      Unknown (0x00)     Missing
# 9       EPAS 17:1      Unknown (0x01)     Without
#
#                                            AccessoryProtocolInterfaceModule  \
#   Collision Mitigation by Braking (CMbB) Steering Wheel Angle Sensor (SWAS)
# 0                                Without                           Absolute
# 1                                Without                           Absolute
# 2                                Without                           Absolute
# 3                                Without                            Missing
# 4                                Without                           Absolute
# 5                                Without                           Absolute
# 6                                Without                           Absolute
# 7                                Missing                           Relative
# 8                                Missing                           Relative
# 9                                Without                           Absolute
#
#                                                                  \
#   Brand Identification Hybrid (HEV) Transmission Type Fuel Type
# 0                 Ford           No            Manual  Gasoline
# 1                 Ford           No         Automatic  Gasoline
# 2                 Ford           No         Automatic  Gasoline
# 3              Missing      Missing           Missing   Missing
# 4                 Ford           No         Automatic  Gasoline
# 5                 Ford          Yes         Automatic  Gasoline
# 6                 Ford           No         Automatic  Gasoline
# 7             Reserved           No         Automatic  Gasoline
# 8                 Ford           No         Automatic  Gasoline
# 9                 Ford           No         Automatic  Gasoline
#
#                                                                       \
#   Plug-in Hybrid (PHEV) Common Global Electrical Architecture (CGEA)
# 0                    No                                     CGEA 1.3
# 1                    No                                     CGEA 1.3
# 2                    No                                     CGEA 1.3
# 3               Missing                                      Missing
# 4                    No                                     CGEA 1.3
# 5                    No                                     CGEA 1.3
# 6                    No                                     CGEA 1.3
# 7                    No                                      Missing
# 8                    No                            CGEA 1.2 or C1MCA
# 9                    No                                     CGEA 1.3
#
#                                                                               \
#   Heated Windshield Country Code (First Letter) Country Code (Second Letter)
# 0               Yes                           U                            K
# 1                No                           U                            S
# 2                No                           U                            S
# 3           Missing                     Missing                      Missing
# 4                No                           U                            S
# 5                No                           U                            S
# 6                No                           U                            S
# 7           Missing              Unknown (0x04)                            U
# 8                No                           U                            S
# 9                No                           U                            S
#
#                                                                       \
#   Vehicle Style GPS Antenna Location/Mount Type     Electric Vehicle
# 0         Focus         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 1       SUV/CUV         Roof Mount (UK Default)      U625 (Explorer)
# 2       SUV/CUV         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 3       Missing                         Missing              Missing
# 4       SUV/CUV         Roof Mount (UK Default)  CX482 (Escape/Kuga)
# 5       SUV/CUV         Roof Mount (UK Default)      U625 (Explorer)
# 6       SUV/CUV         Roof Mount (UK Default)      U625 (Explorer)
# 7          None         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 8         Sedan         Roof Mount (UK Default)   Non-HEV, BEV, PHEV
# 9       SUV/CUV         Roof Mount (UK Default)  CX482 (Escape/Kuga)
#
#                                                                          \
#   Drivetrain Type Bluetooth Vehicle Nameplate ID Front Track Rear Track
# 0             FWD                     Ford Focus    64.05 in   64.05 in
# 1             AWD                  Ford Explorer    68.45 in   68.20 in
# 2             AWD                           SYNC    61.50 in   61.60 in
# 3         Missing                        Missing     Missing    Missing
# 4             AWD                    Ford Escape    61.50 in   61.60 in
# 5             AWD                  Ford Explorer    68.45 in   68.20 in
# 6             AWD                  Ford Explorer    68.45 in   68.20 in
# 7             FWD                        Missing     Missing    Missing
# 8             FWD                    Ford Fiesta    57.70 in   57.00 in
# 9             FWD                    Ford Escape    61.50 in   61.60 in
#
#                                                                               \
#   Wheel Base Wheel Base (cont.) Vehicle Weight Distance from IP to Rear Axle
# 0   97.28 in          + 0.83 in        1100 kg                Unknown (0x00)
# 1  117.76 in          + 1.33 in        2600 kg                Unknown (0x00)
# 2  104.96 in          + 0.14 in        2100 kg                Unknown (0x00)
# 3    Missing            Missing        Missing                       Missing
# 4  104.96 in          + 0.95 in        2000 kg                Unknown (0x00)
# 5  117.76 in          + 1.33 in        2900 kg                Unknown (0x00)
# 6  117.76 in          + 1.33 in        2700 kg                Unknown (0x00)
# 7    Missing            Missing        Missing                       Missing
# 8   97.28 in          + 0.64 in        1600 kg                Unknown (0x00)
# 9  104.96 in          + 0.95 in        1900 kg                Unknown (0x00)
#
#                                                                              \
#   Distance from IP to Rear Axle (cont.)  ACC Menu Forward Collision Warning
# 0                        Unknown (0x61)   Enabled                      None
# 1                        Unknown (0x76)   Enabled                       FCW
# 2                        Unknown (0x88)   Enabled                       FCW
# 3                               Missing   Missing                   Missing
# 4                        Unknown (0x88)  Disabled                       FCW
# 5                        Unknown (0x76)   Enabled                       FCW
# 6                        Unknown (0x76)   Enabled                       FCW
# 7                               Missing   Missing                   Missing
# 8                        Unknown (0x5A)   Missing                   Missing
# 9                        Unknown (0x88)   Enabled                       FCW
#
#                                                        \
#    FCW Menu FCW Braking Evasive Steering Assist (ESA)
# 0   Enabled     Enabled                       Enabled
# 1  Disabled     Enabled                       Enabled
# 2  Disabled     Enabled                       Enabled
# 3   Missing     Missing                       Missing
# 4  Disabled     Enabled                      Disabled
# 5  Disabled     Enabled                       Enabled
# 6  Disabled     Enabled                       Enabled
# 7   Missing     Missing                       Missing
# 8   Missing     Missing                       Missing
# 9  Disabled     Enabled                       Enabled
#
#                                                                \
#   Lane Change Assist (LCA) Lane Keeping Sensitivity  ACC Mode
# 0                  Enabled                  Enabled   Enabled
# 1                  Enabled                 Disabled   Enabled
# 2                  Enabled                 Disabled   Enabled
# 3                  Missing                  Missing   Missing
# 4                  Enabled                 Disabled  Disabled
# 5                  Enabled                 Disabled   Enabled
# 6                  Enabled                 Disabled   Enabled
# 7                  Missing                  Missing   Missing
# 8                  Missing                  Missing   Missing
# 9                  Enabled                 Disabled   Enabled
#
#
#      Lane Assist NCAP Aid Lane Assist NCAP Alert
# 0  Off, Reduced, Enhanced      High, Normal, Low
# 1                Disabled               Disabled
# 2                Disabled               Disabled
# 3                 Missing                Missing
# 4                Disabled               Disabled
# 5                Disabled               Disabled
# 6                Disabled               Disabled
# 7                 Missing                Missing
# 8                 Missing                Missing
# 9                Disabled               Disabled

# %%
from settings import VehicleSettings

important_settings = [
  VehicleSettings.ipma_vehicle,
  # VehicleSettings.ipma_driving_side,
  VehicleSettings.ipma_enable_adaptive_cruise,
  VehicleSettings.ipma_enable_traffic_jam_assist,
  VehicleSettings.ipma_shift_by_wire,
  VehicleSettings.ipma_speed_limit_sign_unit,

  VehicleSettings.pscm_traffic_jam_assist,
  VehicleSettings.pscm_lane_centering_assist,

  VehicleSettings.abs_cruise_control_mode,
  VehicleSettings.abs_steering_gear,

  VehicleSettings.apim_country_code_first_letter,
  VehicleSettings.apim_country_code_second_letter,
  VehicleSettings.apim_lane_change_assist,
  VehicleSettings.apim_adaptive_cruise_mode,
  VehicleSettings.apim_transmission_type,
  VehicleSettings.apim_fuel_type,
  VehicleSettings.apim_wheel_base,
  VehicleSettings.apim_wheel_base_cont,
  VehicleSettings.apim_vehicle_weight,
]

rows = []
for vin in ('WF0NXXGCHNJR69712', 'WF0NXXGCHNKD75963', 'RHAETAGEXN2000154', *random.sample(vins, 19)):
  abd = AsBuiltData.from_vin(vin)
  rows.append([vin, *map(lambda s: abd.get_setting_value(s), important_settings)])

columns = [('', 'VIN'), *map(lambda s: (s.ecu.name, s.comment), important_settings)]

df = pd.DataFrame(rows, columns=pd.MultiIndex.from_tuples(columns))
df
# Out:
#                             ImageProcessingModuleA                          \
#                   VIN                      Vehicle   Enable ACC Enable TJA
# 0   WF0NXXGCHNJR69712                 C519 (Focus)          Off        Off
# 1   WF0NXXGCHNKD75963                 C519 (Focus)          Off        Off
# 2   RHAETAGEXN2000154          CX482 (Escape/Kuga)  RadarFusion         On
# 3   1FM5K8FW5MNA11574              U625 (Explorer)  RadarFusion         On
# 4   1FMSK7BH8MGB27957              U625 (Explorer)          Off        Off
# 5   1FMCU9G60LUC08520          CX482 (Escape/Kuga)          Off        Off
# 6   3FA6P0D95LR138447               Unknown (0xA8)    Undefined  Undefined
# 7   3FMCR9B6XRRE56542  CX430 (Bronco Sport OnRoad)          Off        Off
# 8   1FMCU0H69MUB31111          CX482 (Escape/Kuga)  RadarFusion         On
# 9   1FMSK8FH9NGA16934              U625 (Explorer)  RadarFusion         On
# 10  1FMSK8BH2LGB76866              U625 (Explorer)          Off        Off
# 11  1FMSK8BH8LGB76905              U625 (Explorer)          Off        Off
# 12  3FMCR9B60RRE23873  CX430 (Bronco Sport OnRoad)          Off        Off
# 13  1FMDE5DH4PLC10301                U725 (Bronco)          Off        Off
# 14  1FTEW1E55LKD46620               Unknown (0x05)          Off        Off
# 15  3FMCR9C60RRE50795  CX430 (Bronco Sport OnRoad)          Off        Off
# 16  1FMJK2AT6MEA71940        U553 (Expedition LWB)  RadarFusion        Off
# 17  2FMPK4J91LBA64530                 CD539 (Edge)  RadarFusion         On
# 18  2FMPK3G91JBC58005                      Missing      Missing    Missing
# 19  1FTFW1E50NFA99684                         None          Off  Undefined
# 20  1FMJK1KT0KEA19791                      Missing      Missing    Missing
# 21  1FMCU9GD2KUC00139                      Missing      Missing    Missing
#
#                                        PowerSteeringControlModule  \
#    Shift by Wire Speed Limit Sign Unit         Traffic Jam Assist
# 0            Off                   MPH                   Disabled
# 1            Off                   KPH                   Disabled
# 2             On                   KPH                    Enabled
# 3             On                   MPH                    Enabled
# 4             On                   MPH                   Disabled
# 5             On                   MPH                   Disabled
# 6      Undefined               Missing                   Disabled
# 7             On                   MPH                   Disabled
# 8             On                   MPH                    Enabled
# 9             On                   MPH                    Enabled
# 10            On                   MPH                   Disabled
# 11            On                   MPH                   Disabled
# 12            On                   MPH                   Disabled
# 13           Off                   MPH                   Disabled
# 14           Off                   MPH                   Disabled
# 15            On                   MPH                   Disabled
# 16            On                   MPH                   Disabled
# 17            On                   KPH                    Enabled
# 18       Missing               Missing                   Disabled
# 19     Undefined             Undefined                   Disabled
# 20       Missing               Missing                   Disabled
# 21       Missing               Missing                    Missing
#
#                          AntiLockBrakeSystem                  \
#    Lane Centering Assist Cruise Control Mode   Steering Gear
# 0               Disabled              Normal       EPAS 21:1
# 1               Disabled              Normal       EPAS 21:1
# 2                Enabled      Unknown (0x01)        Reserved
# 3                Enabled      Unknown (0x01)        Reserved
# 4               Disabled      Unknown (0x01)       EPAS 17:1
# 5               Disabled              Normal       EPAS 17:1
# 6               Disabled            Adaptive  Unknown (0x03)
# 7               Disabled              Normal       EPAS 17:1
# 8                Enabled      Unknown (0x01)       EPAS 17:1
# 9                Enabled      Unknown (0x01)       EPAS 17:1
# 10              Disabled      Unknown (0x01)       EPAS 17:1
# 11              Disabled      Unknown (0x01)       EPAS 17:1
# 12              Disabled              Normal       EPAS 17:1
# 13              Disabled              Normal        Reserved
# 14              Disabled              Normal       EPAS 17:1
# 15              Disabled              Normal       EPAS 17:1
# 16              Disabled      Unknown (0x00)        Reserved
# 17               Enabled            Adaptive       EPAS 17:1
# 18              Disabled            Adaptive  Unknown (0x03)
# 19              Disabled              Normal       EPAS 17:1
# 20              Disabled      Unknown (0x00)        Reserved
# 21               Missing             Missing         Missing
#
#    AccessoryProtocolInterfaceModule                               \
#         Country Code (First Letter) Country Code (Second Letter)
# 0                                 U                            K
# 1                                 F                            R
# 2                                 T                            W
# 3                                 U                            S
# 4                                 U                            S
# 5                                 U                            S
# 6                                 U                            S
# 7                                 U                            S
# 8                                 U                            S
# 9                                 U                            S
# 10                                U                            S
# 11                                U                            S
# 12                                U                            S
# 13                   Unknown (0x04)               Unknown (0x12)
# 14                                U                            S
# 15                                U                            S
# 16                                U                            S
# 17                                C                            A
# 18                   Unknown (0x04)                            U
# 19                   Unknown (0x06)               Unknown (0x12)
# 20                                U                            S
# 21                                U                            S
#
#                                                                          \
#    Lane Change Assist (LCA)  ACC Mode Transmission Type       Fuel Type
# 0                   Enabled   Enabled            Manual        Gasoline
# 1                  Disabled  Disabled            Manual          Diesel
# 2                   Enabled   Enabled         Automatic        Gasoline
# 3                   Enabled   Enabled         Automatic        Gasoline
# 4                   Enabled  Disabled         Automatic        Gasoline
# 5                   Enabled  Disabled         Automatic        Gasoline
# 6                  Disabled  Disabled         Automatic        Gasoline
# 7                   Enabled  Disabled         Automatic        Gasoline
# 8                   Enabled   Enabled         Automatic        Gasoline
# 9                   Enabled   Enabled         Automatic        Gasoline
# 10                  Enabled  Disabled         Automatic        Gasoline
# 11                  Enabled  Disabled         Automatic        Gasoline
# 12                  Enabled  Disabled         Automatic        Gasoline
# 13                  Enabled  Disabled         Automatic  Electric (BEV)
# 14                 Disabled  Disabled         Automatic        Gasoline
# 15                  Enabled  Disabled         Automatic        Gasoline
# 16                 Disabled  Disabled         Automatic        Gasoline
# 17                 Disabled  Disabled         Automatic        Gasoline
# 18                  Missing   Missing         Automatic        Gasoline
# 19                  Enabled  Disabled         Automatic             CNG
# 20                  Missing   Missing         Automatic        Gasoline
# 21                  Missing   Missing         Automatic        Gasoline
#
#
#    Wheel Base Wheel Base (cont.) Vehicle Weight
# 0    97.28 in          + 0.83 in        1100 kg
# 1    97.28 in          + 0.83 in        1100 kg
# 2   104.96 in          + 0.95 in        2000 kg
# 3   117.76 in          + 1.33 in        2900 kg
# 4   117.76 in          + 1.33 in        2600 kg
# 5   104.96 in          + 0.95 in        2000 kg
# 6   110.08 in          + 2.08 in         700 kg
# 7   104.96 in          + 0.14 in        2100 kg
# 8   104.96 in          + 0.95 in        1900 kg
# 9   117.76 in          + 1.33 in        2600 kg
# 10  117.76 in          + 1.33 in        2600 kg
# 11  117.76 in          + 1.33 in        2600 kg
# 12  104.96 in          + 0.14 in        2100 kg
# 13    0.00 in          + 0.00 in        2700 kg
# 14  143.36 in          + 1.64 in        7000 kg
# 15  104.96 in          + 0.14 in        2100 kg
# 16  130.56 in          + 1.04 in        3500 kg
# 17  110.08 in          + 1.97 in         800 kg
# 18    Missing            Missing        Missing
# 19    0.00 in          + 0.00 in        3200 kg
# 20  130.56 in          + 1.04 in        3300 kg
# 21  104.96 in          + 0.95 in        2200 kg
