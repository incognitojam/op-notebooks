# %%
import pandas as pd

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### Load NHTSA and Ford AsBuilt Data for vehicles
#
# Filtered to only include the Escape for this example

# %%
from nhtsa import decode_vins
from vins import load_vins

vins = load_vins(filter_comment='aviator', include_openpilot=True) \
     + load_vins(filter_comment='explorer', include_openpilot=True)
df_nhtsa = decode_vins(vins)

# Count unique values in ModelYear
print(df_nhtsa['ModelYear'].value_counts())
print(df_nhtsa['Series'].value_counts())

# Filter ModelYear
df_nhtsa = df_nhtsa[df_nhtsa.ModelYear.astype(int) >= 2019]

# Filter out Police series
df_nhtsa = df_nhtsa[~df_nhtsa['Series'].str.contains('Police', na=False)]

len(df_nhtsa)
# Out:
# Loaded 37 VINs (filter_comment='aviator', include_openpilot=True, skipped=61)
# Downloading AsBuilt data: 100%|██████████| 1/1 [00:06<00:00,  6.56s/it]
# Loaded AsBuilt data for 37 VINs
# Loaded 326 VINs (filter_comment='explorer', include_openpilot=True, skipped=61)
# Loaded AsBuilt data for 326 VINs
# Decoding VINs: 100%|██████████| 363/363 [00:00<00:00, 966.59it/s]
# Decoded 363 VINs
# ModelYear
# 2021    151
# 2020     91
# 2022     73
# 2023     34
# 2024      7
# 2019      4
# 2017      2
# 2018      1
# Name: count, dtype: int64
# Series
# Limited          144
# XLT               91
# Base              47
# Platinum          23
# Reserve           17
# ST                14
# Standard           9
# Grand Touring      4
#                    4
# Police             4
# Timberline         3
# Livery             1
# Sport              1
# King Ranch         1
# Name: count, dtype: int64
# 356

# %%
# Apply fixes
df_nhtsa['DisplacementL'] = df_nhtsa['DisplacementL'].apply(lambda x: round(float(x), 1) if x else None)
df_nhtsa['DriveType'] = df_nhtsa['DriveType'].apply(lambda x: '4WD' if '4WD' in x else 'RWD')

df_nhtsa.head()
# Out:
#         ABS ActiveSafetySysNote AdaptiveCruiseControl AdaptiveDrivingBeam  \
# 0  Standard
# 1  Standard                                  Optional            Optional
# 2  Standard
# 3  Standard
# 4  Standard
#
#                    AirBagLocFront                   AirBagLocKnee  \
# 0  1st Row (Driver and Passenger)  1st Row (Driver and Passenger)
# 1  1st Row (Driver and Passenger)  1st Row (Driver and Passenger)
# 2  1st Row (Driver and Passenger)  1st Row (Driver and Passenger)
# 3  1st Row (Driver and Passenger)  1st Row (Driver and Passenger)
# 4  1st Row (Driver and Passenger)  1st Row (Driver and Passenger)
#
#               AirBagLocSide AutoReverseSystem Axles BlindSpotMon  \
# 0  1st and 2nd and 3rd Rows          Standard     2     Standard
# 1  1st and 2nd and 3rd Rows          Standard     2     Standard
# 2  1st and 2nd and 3rd Rows          Standard           Standard
# 3  1st and 2nd and 3rd Rows          Standard     2     Standard
# 4  1st and 2nd and 3rd Rows          Standard     2     Standard
#
#                                            BodyClass BrakeSystemType  \
# 0  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       Hydraulic
# 1  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       Hydraulic
# 2  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       Hydraulic
# 3  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       Hydraulic
# 4  Sport Utility Vehicle (SUV)/Multi-Purpose Vehi...       Hydraulic
#
#           BusType  CAN_AACN       CIB DaytimeRunningLight DisplacementCC  \
# 0  Not Applicable  Standard  Standard            Standard         3000.0
# 1  Not Applicable  Standard  Standard            Standard         3000.0
# 2  Not Applicable  Standard  Standard            Standard         3000.0
# 3  Not Applicable  Standard  Standard            Standard         3000.0
# 4  Not Applicable  Standard  Standard            Standard         3000.0
#
#     DisplacementCI  DisplacementL Doors DriveType DynamicBrakeSupport EDR  \
# 0  183.07123228419            3.0     4       RWD            Standard
# 1  183.07123228419            3.0     4       RWD            Standard
# 2  183.07123228419            3.0     4       RWD            Standard
# 3  183.07123228419            3.0     4       RWD            Standard
# 4  183.07123228419            3.0     4       RWD            Standard
#
#         ESC ElectrificationLevel EngineConfiguration EngineCylinders EngineHP  \
# 0  Standard                                 V-Shaped               6      400
# 1  Standard                                 V-Shaped               6      400
# 2  Standard                                 V-Shaped               6      400
# 3  Standard                                 V-Shaped               6      400
# 4  Standard                                 V-Shaped               6      400
#
#   EngineManufacturer EngineModel ForwardCollisionWarning  \
# 0               Ford                            Standard
# 1               Ford        GTDI                Standard
# 2               Ford        GTDI                Standard
# 3               Ford                            Standard
# 4               Ford                            Standard
#
#                                  FuelInjectionType FuelTypePrimary  \
# 0                                                         Gasoline
# 1  Stoichiometric Gasoline Direct Injection (SGDI)        Gasoline
# 2                                                         Gasoline
# 3                                                         Gasoline
# 4                                                         Gasoline
#
#   FuelTypeSecondary                                           GVWR  \
# 0                    Class 2E: 6,001 - 7,000 lb (2,722 - 3,175 kg)
# 1                    Class 2E: 6,001 - 7,000 lb (2,722 - 3,175 kg)
# 2                    Class 2E: 6,001 - 7,000 lb (2,722 - 3,175 kg)
# 3                    Class 2E: 6,001 - 7,000 lb (2,722 - 3,175 kg)
# 4                    Class 2E: 6,001 - 7,000 lb (2,722 - 3,175 kg)
#
#   KeylessIgnition LaneCenteringAssistance LaneDepartureWarning LaneKeepSystem  \
# 0        Standard                                     Standard       Standard
# 1        Standard                Optional             Standard       Standard
# 2        Standard                                     Standard       Standard
# 3        Standard                                     Standard       Standard
# 4        Standard                                     Standard       Standard
#
#   LowerBeamHeadlampLightSource     Make MakeID        Manufacturer  \
# 0                          LED  LINCOLN    464  FORD MOTOR COMPANY
# 1                          LED  LINCOLN    464  FORD MOTOR COMPANY
# 2                          LED  LINCOLN    464  FORD MOTOR COMPANY
# 3                          LED  LINCOLN    464  FORD MOTOR COMPANY
# 4                          LED  LINCOLN    464  FORD MOTOR COMPANY
#
#   ManufacturerId    Model ModelID ModelYear  \
# 0            976  Aviator    2653      2020
# 1            976  Aviator    2653      2021
# 2            976  Aviator    2653      2022
# 3            976  Aviator    2653      2020
# 4            976  Aviator    2653      2020
#
#                                         NCSABodyType NCSAMake NCSAModel  \
# 0  Large utility (ANSI D16.1 Utility Vehicle Cate...  Lincoln   Aviator
# 1  Large utility (ANSI D16.1 Utility Vehicle Cate...  Lincoln   Aviator
# 2  Large utility (ANSI D16.1 Utility Vehicle Cate...  Lincoln   Aviator
# 3  Large utility (ANSI D16.1 Utility Vehicle Cate...  Lincoln   Aviator
# 4  Large utility (ANSI D16.1 Utility Vehicle Cate...  Lincoln   Aviator
#
#               OtherEngineInfo ParkAssist PedestrianAutomaticEmergencyBraking  \
# 0  Net Brake H.P.: 400 w/prem                                       Standard
# 1                               Optional                            Standard
# 2                                                                   Standard
# 3  Net Brake H.P.: 400 w/prem                                       Standard
# 4  Net Brake H.P.: 400 w/prem                                       Standard
#
#   PlantCity  PlantCompanyName         PlantCountry PlantState  \
# 0   CHICAGO                    UNITED STATES (USA)   ILLINOIS
# 1   CHICAGO                    UNITED STATES (USA)   ILLINOIS
# 2   CHICAGO  Chicago Assembly  UNITED STATES (USA)   ILLINOIS
# 3   CHICAGO                    UNITED STATES (USA)   ILLINOIS
# 4   CHICAGO                    UNITED STATES (USA)   ILLINOIS
#
#   RearAutomaticEmergencyBraking RearCrossTrafficAlert RearVisibilitySystem  \
# 0                                                                 Standard
# 1                                            Standard             Standard
# 2                                            Standard             Standard
# 3                                                                 Standard
# 4                                                                 Standard
#
#   SeatBeltsAll SeatRows Seats SemiautomaticHeadlampBeamSwitching    Series  \
# 0       Manual        3     7                           Standard   Reserve
# 1       Manual        3     6                           Standard   Reserve
# 2       Manual        3     7                           Standard      Base
# 3       Manual        3     7                           Standard  Standard
# 4       Manual        3     7                           Standard  Standard
#
#         SteeringLocation    TPMS TopSpeedMPH TractionControl  \
# 0  Left-Hand Drive (LHD)  Direct                    Standard
# 1  Left-Hand Drive (LHD)  Direct                    Standard
# 2                         Direct                    Standard
# 3  Left-Hand Drive (LHD)  Direct                    Standard
# 4  Left-Hand Drive (LHD)  Direct                    Standard
#
#   TransmissionSpeeds TransmissionStyle Trim Turbo                VIN  \
# 0                                                  5LM5J7XC9LGL15606
# 1                 10         Automatic        Yes  5LM5J7XC8MGL09541
# 2                 10         Automatic        Yes  5LM5J6WC1NGL16313
# 3                                                  5LM5J6XC4LGL07567
# 4                                                  5LM5J6WC7LGL33162
#
#   VehicleDescriptor                           VehicleType WheelBaseShort  \
# 0       5LM5J7XC*LG  MULTIPURPOSE PASSENGER VEHICLE (MPV)         119.10
# 1       5LM5J7XC*MG  MULTIPURPOSE PASSENGER VEHICLE (MPV)         119.10
# 2       5LM5J6WC*NG  MULTIPURPOSE PASSENGER VEHICLE (MPV)
# 3       5LM5J6XC*LG  MULTIPURPOSE PASSENGER VEHICLE (MPV)         119.10
# 4       5LM5J6WC*LG  MULTIPURPOSE PASSENGER VEHICLE (MPV)         119.10
#
#   WheelSizeFront WheelSizeRear Wheels
# 0                                   4
# 1             20            20      4
# 2
# 3                                   4
# 4                                   4

# %% [markdown]
# ### Reduce to interesting columns
#
# The NHTSA data has lots of columns, so we can filter down to only include the ones which don't change or aren't interesting to us.

# %%
SKIP = [
  'AirBagLocKnee',
  'AirBagLocSide',
  'DisplacementCC',
  'DisplacementCI',
  'EngineCylinders',
  'GVWR',
  'LowerBeamHeadlampLightSource',
  'Make',
  'MakeID',
  'ModelID',
  'NCSABodyType',
  'NCSAMake',
  'NCSAModel',
  'PlantCity',
  'PlantCompanyName',
  'PlantState',
  'Seats',
  'WheelSizeFront',
  'WheelSizeRear',
  'VIN',
  'VehicleDescriptor',
]

KEEP = [
  'DisplacementL',
  'FuelTypeSecondary',
  'Series',
  'Trim',
]

properties = {}

for col in df_nhtsa.columns:
  if col in SKIP:
    continue

  property_values = set(df_nhtsa[col].unique())
  if '' in property_values and col not in KEEP:
    continue
  if len(property_values) == 1:
    continue

  properties[col] = property_values

properties
# Out:
# {'DisplacementL': {2.3, 3.0, 3.3, 3.5},
#  'DriveType': {'4WD', 'RWD'},
#  'FuelTypePrimary': {'Electric', 'Gasoline'},
#  'FuelTypeSecondary': {'', 'Electric', 'Gasoline'},
#  'Model': {'Aviator', 'Explorer'},
#  'ModelYear': {'2019', '2020', '2021', '2022', '2023', '2024'},
#  'Series': {'',
#   'Base',
#   'Grand Touring',
#   'King Ranch',
#   'Limited',
#   'Livery',
#   'Platinum',
#   'Reserve',
#   'ST',
#   'Standard',
#   'Timberline',
#   'XLT'},
#  'Trim': {'', 'Base', 'Limited', 'XLT'}}

# %% [markdown]
# ### Combine NHTSA and Ford AsBuilt Data
#
# We fetch the factory part numbers (software and hardware) from the Ford AsBuilt data and combine it with the NHTSA data.

# %%
from panda.python.uds import DATA_IDENTIFIER_TYPE

from asbuilt import AsBuiltData
from ecu import FordEcu
from settings import VehicleSetting, VehicleSettings


df_fw = df_nhtsa.copy()


def get_ecu_identifier(ecu: FordEcu, identifier: int):
  def apply(row):
    data = AsBuiltData.from_vin(row['VIN'])
    if ecu not in data.ecus:
      return ''
    return data.get_identifier(ecu, identifier)
  return apply


def get_setting(setting: VehicleSetting):
  def apply(row):
    data = AsBuiltData.from_vin(row['VIN'])
    if setting.ecu not in data.ecus:
      return ''
    return data.get_setting_value(setting)
  return apply


# Drop rows that we don't care about (not in the properties)
df_fw.drop(
  columns=[col for col in df_nhtsa.columns if col not in properties and col != 'VIN'],
  inplace=True,
)


# Merge 'Series' and 'Trim' properties (they should be mutually exclusive)
if 'Trim' in properties and 'Series' in properties:
  def get_series_or_trim(row):
    series, trim = row['Series'], row['Trim']
    if series and trim:
      raise ValueError(f'{row["VIN"]} Both Series and Trim are set: {series} and {trim}')
    return series or trim


  df_fw['Series'] = df_fw.apply(get_series_or_trim, axis=1)
  df_fw.drop(columns=['Trim'], inplace=True)
  properties.pop('Trim', None)


# Add the ECU identifiers
ecus = {
  'abs': FordEcu.AntiLockBrakeSystem,
  # 'engine': FordEcu.PowertrainControlModule,
  'eps': FordEcu.PowerSteeringControlModule,
  'fwdCamera': FordEcu.ImageProcessingModuleA,
  'fwdRadar': FordEcu.CruiseControlModule,
}
for name, ecu in ecus.items():
  df_fw[f'{name}_fw'] = df_fw.apply(
    get_ecu_identifier(
      ecu, DATA_IDENTIFIER_TYPE.VEHICLE_MANUFACTURER_ECU_SOFTWARE_NUMBER
    ),
    axis=1,
  )
  df_fw[f'{name}_part'] = df_fw.apply(get_ecu_identifier(ecu, 0xF111), axis=1)


# Apply filters
constants = {
  # 'ModelYear': '2020',
  # 'DisplacementL': '1.5',
  # 'DriveType': '4x2',
  # 'EngineCylinders': '3',
  # 'Series': 'Titanium',
}
for col, value in constants.items():
  df_fw = df_fw[df_fw[col] == value]
  df_fw.drop(columns=[col], inplace=True)


# Drop columns that are all empty
df_fw = df_fw.loc[:, (df_fw != '').any(axis=0)]


# Add settings
settings = {
  # TODO: read this from multiple modules to check that it's consistent
  'acc': VehicleSettings.ipma_enable_adaptive_cruise,
  'lca': VehicleSettings.ipma_enable_traffic_jam_assist,
}
for name, setting in settings.items():
  df_fw[f'code_{name}'] = df_fw.apply(get_setting(setting), axis=1)


# Drop the VIN
df_fw.drop(columns=['VIN'], inplace=True)


# Sort by columns
extra_columns = list(set(properties.keys()) - {'ModelYear', 'Series'})

df_fw.sort_values(
  by=['ModelYear', 'Series'] + [f'code_{name}' for name in settings.keys()] + extra_columns + [f'{name}_fw' for name in ecus.keys()],
  ascending=False,
  inplace=True,
  ignore_index=True,
)


# Drop columns that are all the same
# df_fw = df_fw.loc[:, df_fw.apply(pd.Series.nunique) != 1]


# Add asterisks to column name where the value is the same for all rows
# df_fw.rename(
#   columns={
#     col: f'*{col}' if len(set(df_fw[col].unique())) == 1 else col
#     for col in df_fw.columns
#   },
#   inplace=True,
# )

# Remove duplicate rows

count = len(df_fw)
df_fw.drop_duplicates(inplace=True)
print(f'Removed {count - len(df_fw)} duplicate rows')


df_fw
# Out:
# Removed 214 duplicate rows
#      DisplacementL DriveType FuelTypePrimary FuelTypeSecondary     Model  \
# 0              2.3       4WD        Gasoline                    Explorer
# 4              2.3       4WD        Gasoline                    Explorer
# 5              3.0       4WD        Gasoline                    Explorer
# 7              2.3       RWD        Gasoline                    Explorer
# 8              2.3       4WD        Gasoline                    Explorer
# 9              2.3       RWD        Gasoline                    Explorer
# 11             2.3       4WD        Gasoline                    Explorer
# 19             3.0       4WD        Gasoline                    Explorer
# 23             3.0       RWD        Gasoline                     Aviator
# 26             3.3       4WD        Gasoline          Electric  Explorer
# 29             3.0       4WD        Gasoline                    Explorer
# 32             3.3       4WD        Gasoline          Electric  Explorer
# 34             2.3       RWD        Gasoline                    Explorer
# 38             2.3       4WD        Gasoline                    Explorer
# 39             3.0       RWD        Electric          Gasoline   Aviator
# 40             3.0       RWD        Gasoline                     Aviator
# 41             2.3       4WD        Gasoline                    Explorer
# 45             2.3       RWD        Gasoline                    Explorer
# 46             2.3       RWD        Gasoline                    Explorer
# 47             2.3       RWD        Gasoline                    Explorer
# 51             2.3       RWD        Gasoline                    Explorer
# 52             2.3       4WD        Gasoline                    Explorer
# 55             2.3       4WD        Gasoline                    Explorer
# 67             2.3       4WD        Gasoline                    Explorer
# 69             2.3       4WD        Gasoline                    Explorer
# 71             3.0       RWD        Gasoline                    Explorer
# 72             3.0       4WD        Gasoline                    Explorer
# 73             3.0       RWD        Gasoline                     Aviator
# 74             3.0       RWD        Gasoline                     Aviator
# 75             3.3       RWD        Gasoline          Electric  Explorer
L1MC-14F079-AE  LB5T-14F397-AE  LB5T-14F403-CA  LB5T-14D049-AB
# 318  L1MC-14F079-AE  LB5T-14F397-AE  LB5T-14F403-CA  LB5T-14D049-AB
# 320  L1MC-14F079-AE  LB5T-14F397-AD  LB5T-14F403-CA  LB5T-14D049-AB
# 321  L1MC-14F079-AE  LB5T-14F397-AF  LB5T-14F403-CA  LB5T-14D049-AB
# 322  L1MC-14F079-AE  LB5T-14F397-AE  LB5T-14F403-CA
# 323  L1MC-14F079-AE  LB5T-14F397-AE  LB5T-14F403-CA
# 324  L1MC-14F079-AE  LB5T-14F397-AF  LB5T-14F403-CA
# 327  L1MC-14F079-AE  LB5T-14F397-AE  LB5T-14F403-CA
# 328  L1MC-14F079-AE  LB5T-14F397-AF  LB5T-14F403-CA
# 329  L1MC-14F079-AE  LB5T-14F397-AE  LB5T-14F403-CA
# 330  L1MC-14F079-AE  LB5T-14F397-AE  LB5T-14F403-CA
# 332  L1MC-14F079-AE  LB5T-14F397-AE  LB5T-14F403-CA
# 333  L1MC-14F079-AE  LB5T-14F397-AE  LB5T-14F403-CA
# 335  L1MC-14F079-AE  LB5T-14F397-AF  LB5T-14F403-CA
# 343  L1MC-14F079-AE  LB5T-14F397-AE  LB5T-14F403-CA
# 350  L1MC-14F079-AE  LB5T-14F397-AE  LB5T-14F403-CA
# 351  L1MC-14F079-AE  LB5T-14F397-AE  LB5T-14F403-CA
# 352  GG13-14F079-AD
# 355  GG13-14F079-AD
#
#       fwdRadar_part     code_acc code_lca
# 0                            Off      Off
# 4    LB5T-14F089-AA  RadarFusion       On
# 5    LB5T-14F089-AA  RadarFusion       On
# 7    LB5T-14F089-AA  RadarFusion       On
# 8    LB5T-14F089-AA  RadarFusion       On
# 9                            Off      Off
# 11                           Off      Off
# 19   LB5T-14F089-AA  RadarFusion       On
# 23   LB5T-14F089-AA  RadarFusion       On
# 26   LB5T-14F089-AA  RadarFusion       On
# 29   LB5T-14F089-AA  RadarFusion       On
# 32   LB5T-14F089-AA  RadarFusion       On
# 34   LB5T-14F089-AA  RadarFusion       On
# 38   LB5T-14F089-AA  RadarFusion       On
# 39   LB5T-14F089-AA  RadarFusion       On
# 40                           Off      Off
# 41   LB5T-14F089-AA  RadarFusion       On
# 45                           Off      Off
# 46                           Off      Off
# 47                           Off      Off
# 51                           Off      Off
# 52                           Off      Off
# 55                           Off      Off
# 67                           Off      Off
# 69   LB5T-14F089-AA  RadarFusion       On
# 71   LB5T-14F089-AA  RadarFusion       On
# 72   LB5T-14F089-AA  RadarFusion       On
# 73   LB5T-14F089-AA  RadarFusion       On
# 74   LB5T-14F089-AA  RadarFusion       On
# 75   LB5T-14F089-AA  RadarFusion       On
# 76   LB5T-14F089-AA  RadarFusion       On
# 79   LB5T-14F089-AA  RadarFusion       On
# 80   LB5T-14F089-AA  RadarFusion       On
# 82   LB5T-14F089-AA  RadarFusion       On
# 83                           Off      Off
# 84   LB5T-14F089-AA  RadarFusion       On
# 89   LB5T-14F089-AA  RadarFusion       On
# 91   LB5T-14F089-AA  RadarFusion       On
# 94   LB5T-14F089-AA  RadarFusion       On
# 95   LB5T-14F089-AA  RadarFusion       On
# 97   LB5T-14F089-AA  RadarFusion       On
# 98   LB5T-14F089-AA  RadarFusion       On
# 100  LB5T-14F089-AA  RadarFusion       On
# 104  LB5T-14F089-AA  RadarFusion       On
# 105  LB5T-14F089-AA  RadarFusion       On
# 106                          Off      Off
# 107                          Off      Off
# 108                          Off      Off
# 110                          Off      Off
# 111                          Off      Off
# 112  LB5T-14F089-AA  RadarFusion       On
# 113  LB5T-14F089-AA  RadarFusion       On
# 114  LB5T-14F089-AA  RadarFusion       On
# 115  LB5T-14F089-AA  RadarFusion       On
# 122                          Off      Off
# 125                          Off      Off
# 127                          Off      Off
# 129                          Off      Off
# 132  LB5T-14F089-AA  RadarFusion       On
# 134  LB5T-14F089-AA  RadarFusion       On
# 138  LB5T-14F089-AA  RadarFusion       On
# 139  LB5T-14F089-AA  RadarFusion       On
# 140  LB5T-14F089-AA  RadarFusion       On
# 144  LB5T-14F089-AA  RadarFusion       On
# 145  LB5T-14F089-AA  RadarFusion       On
# 146  LB5T-14F089-AA  RadarFusion       On
# 147  LB5T-14F089-AA  RadarFusion       On
# 149  LB5T-14F089-AA  RadarFusion       On
# 151  LB5T-14F089-AA  RadarFusion       On
# 152  LB5T-14F089-AA  RadarFusion       On
# 212  LB5T-14F089-AA  RadarFusion       On
# 214  LB5T-14F089-AA  RadarFusion       On
# 217  LB5T-14F089-AA  RadarFusion       On
# 218  LB5T-14F089-AA  RadarFusion       On
# 227  LB5T-14F089-AA  RadarFusion       On
# 228  LB5T-14F089-AA  RadarFusion       On
# 249  LB5T-14F089-AA  RadarFusion       On
# 250                          Off      Off
# 251                          Off      Off
# 252                          Off      Off
# 257                          Off      Off
# 259                          Off      Off
# 260                          Off      Off
# 261  LB5T-14F089-AA  RadarFusion       On
# 263  LB5T-14F089-AA  RadarFusion       On
# 264  LB5T-14F089-AA  RadarFusion       On
# 265  LB5T-14F089-AA  RadarFusion       On
# 266  LB5T-14F089-AA  RadarFusion       On
# 267  LB5T-14F089-AA  RadarFusion       On
# 271  LB5T-14F089-AA  RadarFusion       On
# 272  LB5T-14F089-AA  RadarFusion       On
# 273  LB5T-14F089-AA  RadarFusion       On
# 274                          Off      Off
# 275                          Off      Off
# 278                          Off      Off
# 280                          Off      Off
# 281                          Off      Off
# 282                          Off      Off
# 283                          Off      Off
# 285                          Off      Off
# 286                          Off      Off
# 287                          Off      Off
# 288                          Off      Off
# 289                          Off      Off
# 291                          Off      Off
# 292                          Off      Off
# 294                          Off      Off
# 295  LB5T-14F089-AA  RadarFusion       On
# 296  LB5T-14F089-AA  RadarFusion       On
# 298  LB5T-14F089-AA  RadarFusion       On
# 299  LB5T-14F089-AA  RadarFusion       On
# 300  LB5T-14F089-AA  RadarFusion       On
# 302  LB5T-14F089-AA  RadarFusion       On
# 304  LB5T-14F089-AA  RadarFusion       On
# 305                          Off      Off
# 306  LB5T-14F089-AA  RadarFusion       On
# 308  LB5T-14F089-AA  RadarFusion       On
# 309  LB5T-14F089-AA  RadarFusion       On
# 310  LB5T-14F089-AA  RadarFusion       On
# 311  LB5T-14F089-AA  RadarFusion       On
# 313  LB5T-14F089-AA  RadarFusion       On
# 314  LB5T-14F089-AA  RadarFusion       On
# 315  LB5T-14F089-AA  RadarFusion       On
# 316  LB5T-14F089-AA  RadarFusion       On
# 318  LB5T-14F089-AA  RadarFusion       On
# 320  LB5T-14F089-AA  RadarFusion       On
# 321  LB5T-14F089-AA  RadarFusion       On
# 322                          Off      Off
# 323                          Off      Off
# 324                          Off      Off
# 327                          Off      Off
# 328                          Off      Off
# 329                          Off      Off
# 330                          Off      Off
# 332                          Off      Off
# 333                          Off      Off
# 335                          Off      Off
# 343                          Off      Off
# 350                          Off      Off
# 351                          Off      Off
# 352
# 355

# %%
df_fw_analysis = df_fw.copy()

SORTED_TRIM_LEVELS = [
  'Base',
  'XL',
  'XLT',
  'Limited',
  'ST',
  'Platinum',
  'Timberline',
  'King Ranch',
  # Aviator
  'Standard',
  'Reserve',
  'Livery',
  'Grand Touring',
]

def sort_trim_level(trim):
  if trim in SORTED_TRIM_LEVELS:
    return SORTED_TRIM_LEVELS.index(trim)
  return 1000

for ecu in reversed(ecus.keys()):
  print()
  print(f'# Ecu.{ecu}')

  fw_groups = df_fw_analysis \
    .drop(
      columns=[f'{name}_fw' for name in ecus.keys() if name != ecu] + [f'{name}_part' for name in ecus.keys() if name != ecu],
    ) \
    .rename(
      columns={
        f'{ecu}_fw': 'fw',
        f'{ecu}_part': 'part',
      },
    ) \
    .groupby(
      by=['part', 'fw'],
      dropna=False,
    )
  # print(fw_groups.nunique().to_string())

  if len(fw_groups) > 1:
    for name, group in fw_groups:
      print(name)
      # print(group.groupby(
      #   by=['ModelYear', 'Model', 'Series'] + list(set(group.columns) - {'ModelYear', 'Model', 'Series', 'code_acc', 'code_lca', 'part', 'fw'}) + ['code_acc', 'code_lca'],
      #   dropna=False,
      # ).count().to_string())

      drive_type = group["DriveType"].unique()
      fuel_type_secondary = group["FuelTypeSecondary"].unique()
      code_acc = group["code_acc"].unique()

      print(f'  Model        : {group["Model"].unique()}')
      print(f'  ModelYear    : {sorted(group["ModelYear"].unique())}')
      print(f'  Series       : {", ".join(sorted(group["Series"].unique(), key=sort_trim_level))}')
      print(f'  DisplacementL: {", ".join(map(str, sorted(group["DisplacementL"].unique())))}')
      print(f'  4WD?         : {"Both" if "4WD" in drive_type and "RWD" in drive_type else "Yes" if "4WD" in drive_type else "No"}')
      print(f'  Hybrid?      : {"Both" if "Electric" in fuel_type_secondary and ("Gasoline" in fuel_type_secondary or "" in fuel_type_secondary) else "Yes" if "Electric" in fuel_type_secondary else "No"}')
      print(f'  ACC?         : {"Both" if "RadarFusion" in code_acc and ("Off" in code_acc or "" in code_acc) else "Yes" if "RadarFusion" in code_acc else "No"}')

      print()

  print()
# Out:
# # Ecu.fwdRadar
# ('', '')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2019', '2020', '2021', '2022', '2023', '2024']
#   Series       : Base, XLT, Standard, Reserve, Livery, Grand Touring,
#   DisplacementL: 2.3, 3.0, 3.3, 3.5
#   4WD?         : Both
#   Hybrid?      : No
#   ACC?         : No
#
# ('LB5T-14F089-AA', 'LB5T-14D049-AB')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2020', '2021', '2022', '2023', '2024']
#   Series       : XLT, Limited, ST, Platinum, Timberline, King Ranch, Reserve, Grand Touring
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Yes
#
#
#
# # Ecu.fwdCamera
# ('', '')
#   Model        : ['Explorer']
#   ModelYear    : ['2019']
#   Series       :
#   DisplacementL: 2.3, 3.5
#   4WD?         : Both
#   Hybrid?      : No
#   ACC?         : No
#
# ('LB5T-14F403-CA', 'LB5T-14F397-AD')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2020']
#   Series       : XLT, Limited, ST, Platinum, Standard
#   DisplacementL: 2.3, 3.0
#   4WD?         : Both
#   Hybrid?      : No
#   ACC?         : Both
#
# ('LB5T-14F403-CA', 'LB5T-14F397-AE')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2020']
#   Series       : Base, XLT, Limited, ST, Platinum, Standard, Reserve, Grand Touring
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
#
# ('LB5T-14F403-CA', 'LB5T-14F397-AF')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2020', '2021', '2022', '2023', '2024']
#   Series       : Base, XLT, Limited, ST, Platinum, Timberline, King Ranch, Standard, Reserve, Livery, Grand Touring
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
#
# ('LC5T-14F403-FA', 'LC5T-14F397-AH')
#   Model        : ['Aviator']
#   ModelYear    : ['2020', '2021']
#   Series       : Reserve
#   DisplacementL: 3.0
#   4WD?         : No
#   Hybrid?      : No
#   ACC?         : Yes
#
#
#
# # Ecu.eps
# ('GG13-14F079-AD', 'HB53-14D003-AF')
#   Model        : ['Explorer']
#   ModelYear    : ['2019']
#   Series       :
#   DisplacementL: 2.3, 3.5
#   4WD?         : Both
#   Hybrid?      : No
#   ACC?         : No
#
# ('L1MC-14F079-AE', 'L1MC-14D003-AJ')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2020']
#   Series       : Base, XLT, Limited, ST, Platinum, Standard, Reserve
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
#
# ('L1MC-14F079-AE', 'L1MC-14D003-AK')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2020']
#   Series       : Base, XLT, Limited, ST, Standard, Reserve, Grand Touring
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
#
# ('L1MC-14F079-AE', 'L1MC-14D003-AL')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2020', '2021']
#   Series       : Base, XLT, Limited, Standard, Reserve, Grand Touring
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
#
# ('L1MC-14F079-AE', 'M1MC-14D003-AB')
#   Model        : ['Explorer']
#   ModelYear    : ['2022']
#   Series       : Limited, Platinum
#   DisplacementL: 3.3
#   4WD?         : Yes
#   Hybrid?      : Yes
#   ACC?         : Yes
#
# ('L1MC-14F079-AE', 'M1MC-14D003-AC')
#   Model        : ['Explorer']
#   ModelYear    : ['2021']
#   Series       : Limited
#   DisplacementL: 3.3
#   4WD?         : No
#   Hybrid?      : Yes
#   ACC?         : Yes
#
# ('M1MC-14F079-AA', 'L1MC-14D003-AL')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2021', '2022']
#   Series       : Base, XLT, Limited, ST, Platinum, King Ranch, Reserve, Grand Touring
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
#
# ('M1MC-14F079-AA', 'M1MC-14D003-AB')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2021', '2022']
#   Series       : Base, XLT, Limited, ST, Platinum, Reserve, Livery
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
#
# ('M1MC-14F079-AA', 'M1MC-14D003-AC')
#   Model        : ['Aviator' 'Explorer']
#   ModelYear    : ['2021', '2022', '2023']
#   Series       : Base, XLT, Limited, ST, Platinum, Timberline, Reserve
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
#
# ('P1MC-14F079-AA', 'P1MC-14D003-AA')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2022', '2023', '2024']
#   Series       : XLT, Limited, ST, Platinum, Timberline, Grand Touring
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
#
#
#
# # Ecu.abs
# ('FB53-14F065-BA', 'HB53-2D053-BA')
#   Model        : ['Explorer']
#   ModelYear    : ['2019']
#   Series       :
#   DisplacementL: 2.3, 3.5
#   4WD?         : Both
#   Hybrid?      : No
#   ACC?         : No
#
# ('L1MC-14F065-AB', 'L1MC-2D053-AJ')
#   Model        : ['Explorer']
#   ModelYear    : ['2020']
#   Series       : Limited, ST
#   DisplacementL: 2.3, 3.0
#   4WD?         : Yes
#   Hybrid?      : No
#   ACC?         : Yes
#
# ('L1MC-14F065-AB', 'L1MC-2D053-BA')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2020']
#   Series       : Base, XLT, Limited, ST, Platinum, Standard, Reserve
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
#
# ('L1MC-14F065-AB', 'L1MC-2D053-BD')
#   Model        : ['Explorer']
#   ModelYear    : ['2020']
#   Series       : ST
#   DisplacementL: 3.0
#   4WD?         : Yes
#   Hybrid?      : No
#   ACC?         : Yes
#
# ('L1MC-14F065-AB', 'L1MC-2D053-BF')
#   Model        : ['Aviator']
#   ModelYear    : ['2020']
#   Series       : Reserve
#   DisplacementL: 3.0
#   4WD?         : No
#   Hybrid?      : No
#   ACC?         : Yes
#
# ('L1MC-14F065-AB', 'L1MC-2D053-BJ')
#   Model        : ['Aviator']
#   ModelYear    : ['2020']
#   Series       : Standard
#   DisplacementL: 3.0
#   4WD?         : No
#   Hybrid?      : No
#   ACC?         : No
#
# ('L1MC-14F065-CB', 'L1MC-2D053-BB')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2020']
#   Series       : Base, XLT, Limited, Standard
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : No
#   ACC?         : Both
#
# ('L1MC-14F065-CB', 'L1MC-2D053-BC')
#   Model        : ['Explorer']
#   ModelYear    : ['2020']
#   Series       : Base, XLT, Limited
#   DisplacementL: 2.3
#   4WD?         : Both
#   Hybrid?      : No
#   ACC?         : Both
#
# ('L1MC-14F065-CB', 'L1MC-2D053-BD')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2020']
#   Series       : Base, XLT, Standard, Reserve
#   DisplacementL: 2.3, 3.0
#   4WD?         : Both
#   Hybrid?      : No
#   ACC?         : Both
#
# ('L1MC-14F065-CB', 'L1MC-2D053-BE')
#   Model        : ['Explorer']
#   ModelYear    : ['2021']
#   Series       : Base, XLT
#   DisplacementL: 2.3
#   4WD?         : Both
#   Hybrid?      : No
#   ACC?         : Both
#
# ('L1MC-14F065-CB', 'L1MC-2D053-BF')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2021']
#   Series       : Base, XLT, Limited, ST, Platinum, King Ranch, Reserve
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
#
# ('L1MC-14F065-CB', 'L1MC-2D053-BJ')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2020', '2021', '2022']
#   Series       : Base, XLT, Limited, Platinum, Reserve, Livery, Grand Touring
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
#
# ('L1MC-14F065-DA', 'L1MC-2D053-KB')
#   Model        : ['Explorer' 'Aviator']
#   ModelYear    : ['2022', '2023', '2024']
#   Series       : Base, XLT, Limited, ST, Platinum, Timberline, Reserve, Grand Touring
#   DisplacementL: 2.3, 3.0, 3.3
#   4WD?         : Both
#   Hybrid?      : Both
#   ACC?         : Both
