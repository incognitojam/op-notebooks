# %%
import pandas as pd
from tqdm.contrib.concurrent import process_map

from notebooks.ford.asbuilt import AsBuiltData
from notebooks.ford.decode import print_breakdown, search

# TODO: handle non-US cars
df_nhtsa = await search(
  # min_model_year=2017,
  include_openpilot=True,
  include_police=True,
  skip_missing_asbuilt=True,
)

# pre-load asbuilt
process_map(AsBuiltData.from_vin, df_nhtsa['VIN'].unique(), desc='Loading AsBuilt Data', chunksize=100)

print()
print_breakdown(df_nhtsa, include_model_year=False)
# Out:
# Loaded 36766 VINs (filter_comment=None, include_openpilot=True, skipped=162, missing_asbuilt=0)
# Downloading NHTSA data: 100%|██████████| 36766/36766 [00:59<00:00, 621.05it/s]
# Loading AsBuilt Data:   0%|          | 0/36766 [00:00<?, ?it/s]
# Model
#                       2
# Aviator            1107
# Bronco              997
# Bronco Sport       1500
# C-Max                 5
# Continental          23
# Corsair             986
# E-Transit           157
# Ecosport            406
# Edge               2685
# Escape             3569
# Expedition          835
# Expedition MAX      733
# Explorer           3364
# F-150              8254
# F-150 Lightning     385
# F-250              1720
# F-350              1158
# F-450               207
# F-550                 1
# Fiesta              196
# Flex                189
# Focus               169
# Fusion             1163
# GT                    3
# MKC                  55
# MKT                   7
# MKZ                 100
# Maverick            994
# Mustang             952
# Mustang Mach-E      839
# Nautilus           1169
# Navigator           303
# Navigator L         230
# Ranger              533
# Taurus              122
# Transit            1234
# Transit Connect     414
# dtype: int64

# %%
from panda.python.uds import DATA_IDENTIFIER_TYPE
from notebooks.ford.ecu import FordEcu


def get_platform_code(row):
  abd = AsBuiltData.from_vin(row['VIN'])

  fw = abd.get_identifier(FordEcu.AntiLockBrakeSystem, DATA_IDENTIFIER_TYPE.VEHICLE_MANUFACTURER_ECU_SOFTWARE_NUMBER)
  # fw = abd.get_identifier(FordEcu.PowerSteeringControlModule, DATA_IDENTIFIER_TYPE.VEHICLE_MANUFACTURER_ECU_SOFTWARE_NUMBER)
  if fw is None:
    platform_code = None
  else:
    prefix, core, _ = fw.split('-')
    platform_code = f'{core}-{prefix[1:]}'

  return pd.Series({
    'PlatformCode': platform_code,
    'PlatformYear': prefix[0] if platform_code else None,
  })


df = df_nhtsa[['VIN', 'Make', 'Model', 'ModelYear']].copy()
df['CarName'] = df['Make'] + ' ' + df['Model'] + ' ' + df['ModelYear'].astype(str)
df.drop(columns=['Make', 'Model', 'ModelYear'], inplace=True)
df = df.join(df_nhtsa.apply(get_platform_code, axis=1))
df.head()
# Out:
#                  VIN                    CarName PlatformCode PlatformYear
# 0  1FTEW1E87NFB26658            FORD F-150 2022    2D053-L3V            N
# 1  2FMPK4J90LBA41465             FORD Edge 2020    2D053-2GC            L
# 2  1FT6W1EV4PWG01115  FORD F-150 Lightning 2023    2D053-L38            P
# 3  2FMPK4K92NBA10882             FORD Edge 2022    2D053-2GC            M
# 4  1FTEW1EP3PKF28680            FORD F-150 2023    2D053-L34            P

# %%
# which cars have the same platform code
for group in df.groupby(['PlatformCode', 'PlatformYear'], dropna=False):
  print(group[0])
  print(f'CarName: {group[1]["CarName"].unique()}')
  print()
# Out:
# ('14C036-1FC', 'F')
# CarName: ['FORD Focus 2018' 'FORD Focus 2017']
#
# ('14C036-B3C', 'K')
# CarName: ['FORD Ranger 2019' 'FORD Ranger 2023' 'FORD Ranger 2020'
#  'FORD Ranger 2021' 'FORD Ranger 2022']
#
# ('14C036-K41', 'F')
# CarName: ['FORD Transit 2019' 'FORD Transit 2018']
#
# ('14C036-V61', 'C')
# CarName: ['FORD Escape 2015']
#
# ('14C036-V61', 'G')
# CarName: ['FORD Escape 2018' 'FORD Escape 2019' 'FORD Transit Connect 2018']
#
# ('2D053-1MC', 'L')
# CarName: ['FORD Explorer 2023' 'FORD Explorer 2021' 'FORD Explorer 2020'
#  'LINCOLN Aviator 2020' 'FORD Explorer 2022' 'LINCOLN Aviator 2023'
#  'LINCOLN Aviator 2021' 'FORD Explorer 2024' 'LINCOLN Aviator 2022'
#  'LINCOLN Aviator 2024']
#
# ('2D053-2BC', 'D')
# CarName: ['FORD Fiesta 2019' 'FORD Fiesta 2018' 'FORD Fiesta 2017']
#
# ('2D053-2GC', 'F')
# CarName: ['FORD Edge 2018']
#
# ('2D053-2GC', 'K')
# CarName: ['FORD Edge 2019' 'LINCOLN Nautilus 2019']
#
# ('2D053-2GC', 'L')
# CarName: ['FORD Edge 2020' 'LINCOLN Nautilus 2020']
#
# ('2D053-2GC', 'M')
# CarName: ['FORD Edge 2022' 'FORD Edge 2021' 'LINCOLN Nautilus 2022'
#  'LINCOLN Nautilus 2021']
#
# ('2D053-2GC', 'N')
# CarName: ['LINCOLN Nautilus 2022' 'FORD Edge 2022']
#
# ('2D053-2GC', 'P')
# CarName: ['FORD Edge 2023' 'FORD Edge 2024' 'LINCOLN Nautilus 2023']
#
# ('2D053-3GC', 'G')
# CarName: ['LINCOLN Continental 2020' 'LINCOLN Continental 2019']
#
# ('2D053-B3C', 'M')
# CarName: ['FORD Bronco 2022' 'FORD Bronco 2023' 'FORD Bronco 2024'
#  'FORD Bronco 2021' 'FORD Ranger 2024']
#
# ('2D053-B3C', 'P')
# CarName: ['FORD Ranger 2024']
#
# ('2D053-B3V', 'N')
# CarName: ['FORD Bronco 2023' 'FORD Bronco 2022' 'FORD Bronco 2024']
#
# ('2D053-B53', 'H')
# CarName: ['FORD Explorer 2019' 'FORD Explorer 2018' 'FORD Explorer 2017']
#
# ('2D053-C3C', 'H')
# CarName: ['FORD F-350 2018' 'FORD F-250 2018' 'FORD F-450 2018']
#
# ('2D053-C3C', 'K')
# CarName: ['FORD F-250 2019' 'FORD F-350 2019' 'FORD F-450 2019']
#
# ('2D053-C3C', 'L')
# CarName: ['FORD F-250 2021' 'FORD F-350 2021' 'FORD F-250 2020' 'FORD F-450 2020'
#  'FORD F-350 2020' 'FORD F-450 2021']
#
# ('2D053-C3C', 'N')
# CarName: ['FORD F-250 2022' 'FORD F-350 2022' 'FORD F-450 2022' 'FORD F-550 2022']
#
# ('2D053-C3C', 'P')
# CarName: ['FORD F-350 2023' 'FORD F-250 2023' 'FORD F-450 2023']
#
# ('2D053-C3C', 'R')
# CarName: ['FORD F-250 2024' 'FORD F-450 2024' 'FORD F-350 2024']
#
# ('2D053-G13', 'F')
# CarName: ['FORD Flex 2019' 'FORD Flex 2018' 'FORD Taurus 2018' 'FORD Taurus 2019'
#  'LINCOLN MKT 2019']
#
# ('2D053-G7Y', 'H')
# CarName: ['FORD GT 2020']
#
# ('2D053-G9C', 'H')
# CarName: ['FORD Fusion 2018']
#
# ('2D053-G9C', 'K')
# CarName: ['FORD Fusion 2020' 'LINCOLN MKZ 2020' 'FORD Fusion 2019'
#  'LINCOLN MKZ 2019']
#
# ('2D053-J7C', 'K')
# CarName: ['LINCOLN MKC 2019']
#
# ('2D053-J9C', 'L')
# CarName: ['FORD Mustang Mach-E 2021']
#
# ('2D053-K41', 'L')
# CarName: ['FORD Transit 2020']
#
# ('2D053-K41', 'M')
# CarName: ['FORD Transit 2021']
#
# ('2D053-K41', 'N')
# CarName: ['FORD E-Transit 2023' 'FORD Transit 2024' 'FORD Transit 2023'
#  'FORD Transit 2022' 'FORD E-Transit 2022' 'FORD E-Transit 2024']
#
# ('2D053-K9C', 'L')
# CarName: ['FORD Mustang Mach-E 2021' 'FORD Mustang Mach-E 2022'
#  'FORD Mustang Mach-E 2023' 'FORD Mustang Mach-E 2024']
#
# ('2D053-L14', 'J')
# CarName: ['FORD Expedition MAX 2019' 'LINCOLN Navigator L 2019'
#  'FORD Expedition 2018' 'FORD Expedition 2019' 'FORD Expedition MAX 2018'
#  'LINCOLN  2019' 'LINCOLN Navigator 2019']
#
# ('2D053-L14', 'K')
# CarName: ['FORD Expedition MAX 2020' 'FORD Expedition 2020'
#  'LINCOLN Navigator L 2020' 'LINCOLN Navigator 2020']
#
# ('2D053-L14', 'M')
# CarName: ['FORD Expedition MAX 2021' 'FORD Expedition 2021'
#  'LINCOLN Navigator L 2021' 'LINCOLN Navigator 2021']
#
# ('2D053-L14', 'N')
# CarName: ['FORD Expedition 2022' 'LINCOLN Navigator 2022'
#  'LINCOLN Navigator L 2022' 'FORD Expedition MAX 2022']
#
# ('2D053-L14', 'P')
# CarName: ['LINCOLN Navigator 2023' 'FORD Expedition 2024' 'LINCOLN Navigator 2024'
#  'FORD Expedition 2023' 'FORD Expedition MAX 2023'
#  'LINCOLN Navigator L 2023' 'FORD Expedition MAX 2024'
#  'LINCOLN Navigator L 2024' 'LINCOLN Navigator 2022'
#  'LINCOLN Navigator L 2022']
#
# ('2D053-L14', 'R')
# CarName: ['LINCOLN Navigator 2023' 'LINCOLN Navigator 2022'
#  'FORD Expedition MAX 2023']
#
# ('2D053-L34', 'G')
# CarName: ['FORD F-150 2016']
#
# ('2D053-L34', 'H')
# CarName: ['FORD F-150 2018' 'FORD F-150 2017']
#
# ('2D053-L34', 'J')
# CarName: ['FORD F-150 2018']
#
# ('2D053-L34', 'K')
# CarName: ['FORD F-150 2019' 'FORD F-150 2020']
#
# ('2D053-L34', 'M')
# CarName: ['FORD F-150 2021']
#
# ('2D053-L34', 'N')
# CarName: ['FORD F-150 2022' 'FORD F-150 2021']
#
# ('2D053-L34', 'P')
# CarName: ['FORD F-150 2023' 'FORD F-150 2022' 'FORD F-150 2021']
#
# ('2D053-L34', 'R')
# CarName: ['FORD F-150 2024']
#
# ('2D053-L38', 'N')
# CarName: ['FORD F-150 Lightning 2022']
#
# ('2D053-L38', 'P')
# CarName: ['FORD F-150 Lightning 2023' 'FORD F-150 Lightning 2022']
#
# ('2D053-L38', 'R')
# CarName: ['FORD F-150 Lightning 2024']
#
# ('2D053-L3V', 'K')
# CarName: ['FORD F-150 2019' 'FORD F-150 2020']
#
# ('2D053-L3V', 'M')
# CarName: ['FORD F-150 2021']
#
# ('2D053-L3V', 'N')
# CarName: ['FORD F-150 2022']
#
# ('2D053-L3V', 'P')
# CarName: ['FORD F-150 2023' 'FORD F-150 2021' 'FORD F-150 2022']
#
# ('2D053-L3V', 'R')
# CarName: ['FORD F-150 2024']
#
# ('2D053-N15', 'G')
# CarName: ['FORD Ecosport 2020' 'FORD Ecosport 2018' 'FORD Ecosport 2019'
#  'FORD Ecosport 2021' 'FORD Ecosport 2022']
#
# ('2D053-R3C', 'G')
# CarName: ['FORD Mustang 2018']
#
# ('2D053-R3C', 'J')
# CarName: ['FORD Mustang 2018']
#
# ('2D053-R3C', 'K')
# CarName: ['FORD Mustang 2019' 'FORD Mustang 2020']
#
# ('2D053-R3C', 'L')
# CarName: ['FORD Mustang 2022' 'FORD Mustang 2020' 'FORD Mustang 2021']
#
# ('2D053-R3C', 'M')
# CarName: ['FORD Mustang 2021' 'FORD Mustang 2023' 'FORD Mustang 2022']
#
# ('2D053-R3C', 'P')
# CarName: ['FORD Mustang 2024']
#
# ('2D053-V68', 'E')
# CarName: ['FORD Focus 2018']
#
# ('2D053-V6C', 'G')
# CarName: ['FORD C-Max 2018']
#
# ('2D053-V6C', 'K')
# CarName: ['FORD Transit Connect 2020' 'FORD Transit Connect 2019'
#  'FORD Transit Connect 2022' 'FORD Transit Connect 2021'
#  'FORD Transit Connect 2023']
#
# ('2D053-X6C', 'L')
# CarName: ['FORD Bronco Sport 2021' 'LINCOLN Corsair 2021' 'FORD Escape 2021'
#  'LINCOLN Corsair 2022' 'FORD Escape 2020' 'FORD Bronco Sport 2024'
#  'LINCOLN Corsair 2020' 'FORD Escape 2022' 'FORD Bronco Sport 2022'
#  'FORD Bronco Sport 2023']
#
# ('2D053-Z1C', 'P')
# CarName: ['FORD Escape 2023' 'LINCOLN Corsair 2023' 'FORD Escape 2024'
#  'LINCOLN Corsair 2024' 'LINCOLN Nautilus 2024']
#
# ('2D053-Z6C', 'N')
# CarName: ['FORD Maverick 2022']
#
# ('2D053-Z6C', 'P')
# CarName: ['FORD Maverick 2023' 'FORD Maverick 2024' 'FORD Maverick 2022']
#
# (nan, nan)
# CarName: ['FORD F-150 2020']

# %%
from notebooks.ford.platforms import find_openpilot_platform


def get_openpilot_platform(row):
  return pd.Series({
    'CarInfoPlatform': find_openpilot_platform(row['CarName']),
  })


df_openpilot_platforms = df.join(df.apply(get_openpilot_platform, axis=1))
df_openpilot_platforms.head()
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /mnt/c/Users/camer/AppData/Local/Programs/Microsoft VS Code
#                  VIN                    CarName PlatformCode PlatformYear  \
# 0  1FTEW1E87NFB26658            FORD F-150 2022    2D053-L3V            N
# 1  2FMPK4J90LBA41465             FORD Edge 2020    2D053-2GC            L
# 2  1FT6W1EV4PWG01115  FORD F-150 Lightning 2023    2D053-L38            P
# 3  2FMPK4K92NBA10882             FORD Edge 2022    2D053-2GC            M
# 4  1FTEW1EP3PKF28680            FORD F-150 2023    2D053-L34            P
#
#                 CarInfoPlatform
# 0                          None
# 1                          None
# 2  FORD F-150 LIGHTNING 1ST GEN
# 3                          None
# 4           FORD F-150 14TH GEN

# %%
df_openpilot_platforms['CarInfoPlatform'].value_counts(dropna=False)
# Out:
# CarInfoPlatform
# None                            26681
# FORD EXPLORER 6TH GEN            3678
# FORD ESCAPE 4TH GEN              2164
# FORD F-150 14TH GEN              1338
# FORD BRONCO SPORT 1ST GEN         930
# FORD MUSTANG MACH-E 1ST GEN       813
# FORD MAVERICK 1ST GEN             788
# FORD F-150 LIGHTNING 1ST GEN      374
# Name: count, dtype: int64

# %%
for group in df_openpilot_platforms.groupby('CarInfoPlatform', dropna=False):
  print(group[0])
  print(f'CarName: {group[1]["CarName"].unique()}')
  print(f'PlatformCode: {group[1]["PlatformCode"].unique()}')
  print(f'PlatformYear: {group[1]["PlatformYear"].unique()}')
  print()
# Out:
# FORD BRONCO SPORT 1ST GEN
# CarName: ['FORD Bronco Sport 2021' 'FORD Bronco Sport 2022']
# PlatformCode: ['2D053-X6C']
# PlatformYear: ['L']
#
# FORD ESCAPE 4TH GEN
# CarName: ['FORD Escape 2021' 'FORD Escape 2020' 'FORD Escape 2022']
# PlatformCode: ['2D053-X6C']
# PlatformYear: ['L']
#
# FORD EXPLORER 6TH GEN
# CarName: ['FORD Explorer 2023' 'FORD Explorer 2021' 'FORD Explorer 2020'
#  'LINCOLN Aviator 2020' 'FORD Explorer 2022' 'LINCOLN Aviator 2023'
#  'LINCOLN Aviator 2021' 'LINCOLN Aviator 2022']
# PlatformCode: ['2D053-1MC']
# PlatformYear: ['L']
#
# FORD F-150 14TH GEN
# CarName: ['FORD F-150 2023']
# PlatformCode: ['2D053-L34' '2D053-L3V']
# PlatformYear: ['P']
#
# FORD F-150 LIGHTNING 1ST GEN
# CarName: ['FORD F-150 Lightning 2023' 'FORD F-150 Lightning 2022']
# PlatformCode: ['2D053-L38']
# PlatformYear: ['P' 'N']
#
# FORD MAVERICK 1ST GEN
# CarName: ['FORD Maverick 2022' 'FORD Maverick 2023']
# PlatformCode: ['2D053-Z6C']
# PlatformYear: ['N' 'P']
#
# FORD MUSTANG MACH-E 1ST GEN
# CarName: ['FORD Mustang Mach-E 2021' 'FORD Mustang Mach-E 2022'
#  'FORD Mustang Mach-E 2023']
# PlatformCode: ['2D053-K9C' '2D053-J9C']
# PlatformYear: ['L']
#
# nan
# CarName: ['FORD F-150 2022' 'FORD Edge 2020' 'FORD Edge 2022' 'FORD F-250 2021'
#  'FORD F-150 2021' 'FORD Mustang 2024' 'FORD F-350 2018'
#  'FORD Fusion 2018' 'FORD Ranger 2019' 'FORD Escape 2018'
#  'FORD Transit 2019' 'FORD F-150 2019' 'FORD Escape 2023'
#  'FORD E-Transit 2023' 'FORD Edge 2019' 'FORD Expedition MAX 2021'
#  'FORD Expedition MAX 2020' 'LINCOLN Corsair 2021' 'FORD F-350 2021'
#  'FORD F-150 2020' 'FORD Edge 2023' 'FORD F-250 2018' 'FORD F-250 2019'
#  'LINCOLN Corsair 2022' 'FORD Fiesta 2019' 'FORD Explorer 2019'
#  'FORD F-250 2020' 'FORD Focus 2018' 'FORD Transit 2021'
#  'FORD Transit Connect 2020' 'FORD F-150 2018' 'FORD F-350 2023'
#  'FORD F-450 2020' 'FORD Mustang 2021' 'FORD F-250 2024'
#  'FORD Bronco 2022' 'FORD Bronco Sport 2024' 'FORD Transit Connect 2019'
#  'FORD Edge 2021' 'FORD Fusion 2020' 'FORD F-250 2023' 'FORD Bronco 2023'
#  'LINCOLN Corsair 2023' 'FORD Explorer 2018' 'LINCOLN Corsair 2020'
#  'FORD Transit 2018' 'LINCOLN Nautilus 2020' 'FORD F-350 2019'
#  'FORD F-350 2020' 'LINCOLN Nautilus 2022' 'LINCOLN Nautilus 2021'
#  'LINCOLN MKZ 2020' 'FORD Escape 2019' 'FORD Expedition MAX 2019'
#  'FORD Flex 2019' 'FORD Expedition 2020' 'FORD Edge 2018' 'FORD Edge 2024'
#  'FORD Maverick 2024' 'FORD Transit 2024' 'FORD F-250 2022'
#  'LINCOLN Nautilus 2019' 'LINCOLN Navigator 2023' 'FORD Transit 2020'
#  'FORD Flex 2018' 'FORD F-450 2024' 'FORD Bronco 2024' 'FORD Escape 2024'
#  'FORD Ranger 2023' 'LINCOLN Navigator L 2019' 'FORD Bronco Sport 2023'
#  'FORD Expedition 2024' 'LINCOLN Corsair 2024' 'LINCOLN Navigator 2024'
#  'LINCOLN Nautilus 2024' 'FORD Fusion 2019' 'FORD F-350 2022'
#  'FORD Mustang 2022' 'FORD F-450 2021' 'FORD Expedition 2018'
#  'FORD Expedition 2019' 'FORD Ranger 2020' 'FORD F-450 2023'
#  'FORD Bronco 2021' 'FORD Mustang 2020' 'LINCOLN Nautilus 2023'
#  'LINCOLN Continental 2020' 'FORD Explorer 2024' 'LINCOLN MKC 2019'
#  'FORD F-450 2022' 'FORD Ranger 2024' 'FORD Expedition 2021'
#  'FORD Transit 2023' 'LINCOLN Continental 2019' 'FORD Ranger 2021'
#  'FORD Mustang 2023' 'FORD Mustang 2019' 'FORD Expedition 2023'
#  'FORD Expedition 2022' 'LINCOLN Navigator 2022' 'FORD Fiesta 2018'
#  'FORD Ecosport 2020' 'FORD Transit Connect 2022' 'FORD Taurus 2018'
#  'FORD Transit Connect 2021' 'FORD Expedition MAX 2023'
#  'LINCOLN Navigator L 2020' 'LINCOLN MKZ 2019' 'FORD Expedition MAX 2018'
#  'FORD Ecosport 2018' 'LINCOLN Navigator L 2022'
#  'FORD F-150 Lightning 2024' 'FORD Transit Connect 2018'
#  'LINCOLN Navigator 2020' 'LINCOLN Navigator L 2023' 'FORD Ecosport 2019'
#  'FORD Taurus 2019' 'FORD Transit 2022' 'FORD Fiesta 2017' 'FORD GT 2020'
#  'FORD Expedition MAX 2024' 'FORD Mustang Mach-E 2024'
#  'LINCOLN Aviator 2024' 'LINCOLN Navigator L 2021' 'FORD F-150 2024'
#  'FORD F-350 2024' 'FORD Expedition MAX 2022' 'FORD Mustang 2018'
#  'FORD Ecosport 2021' 'LINCOLN Navigator 2021' 'FORD Ranger 2022'
#  'LINCOLN Navigator L 2024' 'LINCOLN MKT 2019' 'LINCOLN  2019'
#  'FORD F-450 2019' 'FORD Ecosport 2022' 'FORD C-Max 2018'
#  'FORD F-450 2018' 'FORD F-150 2017' 'FORD Focus 2017'
#  'FORD Transit Connect 2023' 'LINCOLN Navigator 2019'
#  'FORD E-Transit 2022' 'FORD Escape 2015' 'FORD Explorer 2017'
#  'FORD F-550 2022' 'FORD E-Transit 2024' 'FORD F-150 2016']
# PlatformCode: ['2D053-L3V' '2D053-2GC' '2D053-C3C' '2D053-L34' '2D053-R3C' '2D053-G9C'
#  '14C036-B3C' '14C036-V61' '14C036-K41' '2D053-Z1C' '2D053-K41'
#  '2D053-L14' '2D053-X6C' '2D053-2BC' '2D053-B53' '14C036-1FC' '2D053-V6C'
#  '2D053-B3C' '2D053-G13' '2D053-Z6C' '2D053-B3V' '2D053-3GC' '2D053-1MC'
#  '2D053-J7C' '2D053-N15' '2D053-L38' '2D053-G7Y' '2D053-K9C' None
#  '2D053-V68']
# PlatformYear: ['N' 'L' 'M' 'P' 'H' 'K' 'G' 'F' 'D' 'J' 'R' 'C' None 'E']

# %%
# which openpilot platforms have the same platform code
for group in df_openpilot_platforms.groupby(['PlatformCode', 'PlatformYear'], dropna=False):
  platforms = group[1]['CarInfoPlatform'].unique()
  if len(platforms) == 1 and platforms[0] is None:
    continue
  print(group[0])
  print(f'CarInfoPlatform: {group[1]["CarInfoPlatform"].unique()}')
  print(f'CarName: {group[1]["CarName"].unique()}')
  print()
# Out:
# ('2D053-1MC', 'L')
# CarInfoPlatform: [<CAR.EXPLORER_MK6: 'FORD EXPLORER 6TH GEN'> None]
# CarName: ['FORD Explorer 2023' 'FORD Explorer 2021' 'FORD Explorer 2020'
#  'LINCOLN Aviator 2020' 'FORD Explorer 2022' 'LINCOLN Aviator 2023'
#  'LINCOLN Aviator 2021' 'FORD Explorer 2024' 'LINCOLN Aviator 2022'
#  'LINCOLN Aviator 2024']
#
# ('2D053-J9C', 'L')
# CarInfoPlatform: [<CAR.MUSTANG_MACH_E_MK1: 'FORD MUSTANG MACH-E 1ST GEN'>]
# CarName: ['FORD Mustang Mach-E 2021']
#
# ('2D053-K9C', 'L')
# CarInfoPlatform: [<CAR.MUSTANG_MACH_E_MK1: 'FORD MUSTANG MACH-E 1ST GEN'> None]
# CarName: ['FORD Mustang Mach-E 2021' 'FORD Mustang Mach-E 2022'
#  'FORD Mustang Mach-E 2023' 'FORD Mustang Mach-E 2024']
#
# ('2D053-L34', 'P')
# CarInfoPlatform: [<CAR.F_150_MK14: 'FORD F-150 14TH GEN'> None]
# CarName: ['FORD F-150 2023' 'FORD F-150 2022' 'FORD F-150 2021']
#
# ('2D053-L38', 'N')
# CarInfoPlatform: [<CAR.F_150_LIGHTNING_MK1: 'FORD F-150 LIGHTNING 1ST GEN'>]
# CarName: ['FORD F-150 Lightning 2022']
#
# ('2D053-L38', 'P')
# CarInfoPlatform: [<CAR.F_150_LIGHTNING_MK1: 'FORD F-150 LIGHTNING 1ST GEN'>]
# CarName: ['FORD F-150 Lightning 2023' 'FORD F-150 Lightning 2022']
#
# ('2D053-L3V', 'P')
# CarInfoPlatform: [<CAR.F_150_MK14: 'FORD F-150 14TH GEN'> None]
# CarName: ['FORD F-150 2023' 'FORD F-150 2021' 'FORD F-150 2022']
#
# ('2D053-X6C', 'L')
# CarInfoPlatform: [<CAR.BRONCO_SPORT_MK1: 'FORD BRONCO SPORT 1ST GEN'> None
#  <CAR.ESCAPE_MK4: 'FORD ESCAPE 4TH GEN'>]
# CarName: ['FORD Bronco Sport 2021' 'LINCOLN Corsair 2021' 'FORD Escape 2021'
#  'LINCOLN Corsair 2022' 'FORD Escape 2020' 'FORD Bronco Sport 2024'
#  'LINCOLN Corsair 2020' 'FORD Escape 2022' 'FORD Bronco Sport 2022'
#  'FORD Bronco Sport 2023']
#
# ('2D053-Z6C', 'N')
# CarInfoPlatform: [<CAR.MAVERICK_MK1: 'FORD MAVERICK 1ST GEN'>]
# CarName: ['FORD Maverick 2022']
#
# ('2D053-Z6C', 'P')
# CarInfoPlatform: [<CAR.MAVERICK_MK1: 'FORD MAVERICK 1ST GEN'> None]
# CarName: ['FORD Maverick 2023' 'FORD Maverick 2024' 'FORD Maverick 2022']

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

df_openpilot_platforms.groupby(['PlatformCode', 'PlatformYear'], dropna=False).agg(lambda x: ', '.join(sorted((str(x) for x in set(x)))))[['CarName', 'CarInfoPlatform']]
# Out:
#                                                                                                                                                                                                                                                                         CarName  \
# PlatformCode PlatformYear
# 14C036-1FC   F                                                                                                                                                                                                                                 FORD Focus 2017, FORD Focus 2018
# 14C036-B3C   K                                                                                                                                                                         FORD Ranger 2019, FORD Ranger 2020, FORD Ranger 2021, FORD Ranger 2022, FORD Ranger 2023
# 14C036-K41   F                                                                                                                                                                                                                             FORD Transit 2018, FORD Transit 2019
# 14C036-V61   C                                                                                                                                                                                                                                                 FORD Escape 2015
#              G                                                                                                                                                                                                    FORD Escape 2018, FORD Escape 2019, FORD Transit Connect 2018
# 2D053-1MC    L                                                 FORD Explorer 2020, FORD Explorer 2021, FORD Explorer 2022, FORD Explorer 2023, FORD Explorer 2024, LINCOLN Aviator 2020, LINCOLN Aviator 2021, LINCOLN Aviator 2022, LINCOLN Aviator 2023, LINCOLN Aviator 2024
# 2D053-2BC    D                                                                                                                                                                                                             FORD Fiesta 2017, FORD Fiesta 2018, FORD Fiesta 2019
# 2D053-2GC    F                                                                                                                                                                                                                                                   FORD Edge 2018
#              K                                                                                                                                                                                                                            FORD Edge 2019, LINCOLN Nautilus 2019
#              L                                                                                                                                                                                                                            FORD Edge 2020, LINCOLN Nautilus 2020
#              M                                                                                                                                                                                     FORD Edge 2021, FORD Edge 2022, LINCOLN Nautilus 2021, LINCOLN Nautilus 2022
#              N                                                                                                                                                                                                                            FORD Edge 2022, LINCOLN Nautilus 2022
#              P                                                                                                                                                                                                            FORD Edge 2023, FORD Edge 2024, LINCOLN Nautilus 2023
# 2D053-3GC    G                                                                                                                                                                                                               LINCOLN Continental 2019, LINCOLN Continental 2020
# 2D053-B3C    M                                                                                                                                                                         FORD Bronco 2021, FORD Bronco 2022, FORD Bronco 2023, FORD Bronco 2024, FORD Ranger 2024
#              P                                                                                                                                                                                                                                                 FORD Ranger 2024
# 2D053-B3V    N                                                                                                                                                                                                             FORD Bronco 2022, FORD Bronco 2023, FORD Bronco 2024
# 2D053-B53    H                                                                                                                                                                                                       FORD Explorer 2017, FORD Explorer 2018, FORD Explorer 2019
# 2D053-C3C    H                                                                                                                                                                                                                FORD F-250 2018, FORD F-350 2018, FORD F-450 2018
#              K                                                                                                                                                                                                                FORD F-250 2019, FORD F-350 2019, FORD F-450 2019
#              L                                                                                                                                                             FORD F-250 2020, FORD F-250 2021, FORD F-350 2020, FORD F-350 2021, FORD F-450 2020, FORD F-450 2021
#              N                                                                                                                                                                                               FORD F-250 2022, FORD F-350 2022, FORD F-450 2022, FORD F-550 2022
#              P                                                                                                                                                                                                                FORD F-250 2023, FORD F-350 2023, FORD F-450 2023
#              R                                                                                                                                                                                                                FORD F-250 2024, FORD F-350 2024, FORD F-450 2024
# 2D053-G13    F                                                                                                                                                                             FORD Flex 2018, FORD Flex 2019, FORD Taurus 2018, FORD Taurus 2019, LINCOLN MKT 2019
# 2D053-G7Y    H                                                                                                                                                                                                                                                     FORD GT 2020
# 2D053-G9C    H                                                                                                                                                                                                                                                 FORD Fusion 2018
#              K                                                                                                                                                                                           FORD Fusion 2019, FORD Fusion 2020, LINCOLN MKZ 2019, LINCOLN MKZ 2020
# 2D053-J7C    K                                                                                                                                                                                                                                                 LINCOLN MKC 2019
# 2D053-J9C    L                                                                                                                                                                                                                                         FORD Mustang Mach-E 2021
# 2D053-K41    L                                                                                                                                                                                                                                                FORD Transit 2020
#              M                                                                                                                                                                                                                                                FORD Transit 2021
#              N                                                                                                                                           FORD E-Transit 2022, FORD E-Transit 2023, FORD E-Transit 2024, FORD Transit 2022, FORD Transit 2023, FORD Transit 2024
# 2D053-K9C    L                                                                                                                                                           FORD Mustang Mach-E 2021, FORD Mustang Mach-E 2022, FORD Mustang Mach-E 2023, FORD Mustang Mach-E 2024
# 2D053-L14    J                                                                                                  FORD Expedition 2018, FORD Expedition 2019, FORD Expedition MAX 2018, FORD Expedition MAX 2019, LINCOLN  2019, LINCOLN Navigator 2019, LINCOLN Navigator L 2019
#              K                                                                                                                                                                 FORD Expedition 2020, FORD Expedition MAX 2020, LINCOLN Navigator 2020, LINCOLN Navigator L 2020
#              M                                                                                                                                                                 FORD Expedition 2021, FORD Expedition MAX 2021, LINCOLN Navigator 2021, LINCOLN Navigator L 2021
#              N                                                                                                                                                                 FORD Expedition 2022, FORD Expedition MAX 2022, LINCOLN Navigator 2022, LINCOLN Navigator L 2022
#              P             FORD Expedition 2023, FORD Expedition 2024, FORD Expedition MAX 2023, FORD Expedition MAX 2024, LINCOLN Navigator 2022, LINCOLN Navigator 2023, LINCOLN Navigator 2024, LINCOLN Navigator L 2022, LINCOLN Navigator L 2023, LINCOLN Navigator L 2024
#              R                                                                                                                                                                                         FORD Expedition MAX 2023, LINCOLN Navigator 2022, LINCOLN Navigator 2023
# 2D053-L34    G                                                                                                                                                                                                                                                  FORD F-150 2016
#              H                                                                                                                                                                                                                                 FORD F-150 2017, FORD F-150 2018
#              J                                                                                                                                                                                                                                                  FORD F-150 2018
#              K                                                                                                                                                                                                                                 FORD F-150 2019, FORD F-150 2020
#              M                                                                                                                                                                                                                                                  FORD F-150 2021
#              N                                                                                                                                                                                                                                 FORD F-150 2021, FORD F-150 2022
#              P                                                                                                                                                                                                                FORD F-150 2021, FORD F-150 2022, FORD F-150 2023
#              R                                                                                                                                                                                                                                                  FORD F-150 2024
# 2D053-L38    N                                                                                                                                                                                                                                        FORD F-150 Lightning 2022
#              P                                                                                                                                                                                                             FORD F-150 Lightning 2022, FORD F-150 Lightning 2023
#              R                                                                                                                                                                                                                                        FORD F-150 Lightning 2024
# 2D053-L3V    K                                                                                                                                                                                                                                 FORD F-150 2019, FORD F-150 2020
#              M                                                                                                                                                                                                                                                  FORD F-150 2021
#              N                                                                                                                                                                                                                                                  FORD F-150 2022
#              P                                                                                                                                                                                                                FORD F-150 2021, FORD F-150 2022, FORD F-150 2023
#              R                                                                                                                                                                                                                                                  FORD F-150 2024
# 2D053-N15    G                                                                                                                                                               FORD Ecosport 2018, FORD Ecosport 2019, FORD Ecosport 2020, FORD Ecosport 2021, FORD Ecosport 2022
# 2D053-R3C    G                                                                                                                                                                                                                                                FORD Mustang 2018
#              J                                                                                                                                                                                                                                                FORD Mustang 2018
#              K                                                                                                                                                                                                                             FORD Mustang 2019, FORD Mustang 2020
#              L                                                                                                                                                                                                          FORD Mustang 2020, FORD Mustang 2021, FORD Mustang 2022
#              M                                                                                                                                                                                                          FORD Mustang 2021, FORD Mustang 2022, FORD Mustang 2023
#              P                                                                                                                                                                                                                                                FORD Mustang 2024
# 2D053-V68    E                                                                                                                                                                                                                                                  FORD Focus 2018
# 2D053-V6C    G                                                                                                                                                                                                                                                  FORD C-Max 2018
#              K                                                                                                                            FORD Transit Connect 2019, FORD Transit Connect 2020, FORD Transit Connect 2021, FORD Transit Connect 2022, FORD Transit Connect 2023
# 2D053-X6C    L                                           FORD Bronco Sport 2021, FORD Bronco Sport 2022, FORD Bronco Sport 2023, FORD Bronco Sport 2024, FORD Escape 2020, FORD Escape 2021, FORD Escape 2022, LINCOLN Corsair 2020, LINCOLN Corsair 2021, LINCOLN Corsair 2022
# 2D053-Z1C    P                                                                                                                                                            FORD Escape 2023, FORD Escape 2024, LINCOLN Corsair 2023, LINCOLN Corsair 2024, LINCOLN Nautilus 2024
# 2D053-Z6C    N                                                                                                                                                                                                                                               FORD Maverick 2022
#              P                                                                                                                                                                                                       FORD Maverick 2022, FORD Maverick 2023, FORD Maverick 2024
# NaN          NaN                                                                                                                                                                                                                                                FORD F-150 2020
#
#                                                                 CarInfoPlatform
# PlatformCode PlatformYear
# 14C036-1FC   F                                                             None
# 14C036-B3C   K                                                             None
# 14C036-K41   F                                                             None
# 14C036-V61   C                                                             None
#              G                                                             None
# 2D053-1MC    L                                      FORD EXPLORER 6TH GEN, None
# 2D053-2BC    D                                                             None
# 2D053-2GC    F                                                             None
#              K                                                             None
#              L                                                             None
#              M                                                             None
#              N                                                             None
#              P                                                             None
# 2D053-3GC    G                                                             None
# 2D053-B3C    M                                                             None
#              P                                                             None
# 2D053-B3V    N                                                             None
# 2D053-B53    H                                                             None
# 2D053-C3C    H                                                             None
#              K                                                             None
#              L                                                             None
#              N                                                             None
#              P                                                             None
#              R                                                             None
# 2D053-G13    F                                                             None
# 2D053-G7Y    H                                                             None
# 2D053-G9C    H                                                             None
#              K                                                             None
# 2D053-J7C    K                                                             None
# 2D053-J9C    L                                      FORD MUSTANG MACH-E 1ST GEN
# 2D053-K41    L                                                             None
#              M                                                             None
#              N                                                             None
# 2D053-K9C    L                                FORD MUSTANG MACH-E 1ST GEN, None
# 2D053-L14    J                                                             None
#              K                                                             None
#              M                                                             None
#              N                                                             None
#              P                                                             None
#              R                                                             None
# 2D053-L34    G                                                             None
#              H                                                             None
#              J                                                             None
#              K                                                             None
#              M                                                             None
#              N                                                             None
#              P                                        FORD F-150 14TH GEN, None
#              R                                                             None
# 2D053-L38    N                                     FORD F-150 LIGHTNING 1ST GEN
#              P                                     FORD F-150 LIGHTNING 1ST GEN
#              R                                                             None
# 2D053-L3V    K                                                             None
#              M                                                             None
#              N                                                             None
#              P                                        FORD F-150 14TH GEN, None
#              R                                                             None
# 2D053-N15    G                                                             None
# 2D053-R3C    G                                                             None
#              J                                                             None
#              K                                                             None
#              L                                                             None
#              M                                                             None
#              P                                                             None
# 2D053-V68    E                                                             None
# 2D053-V6C    G                                                             None
#              K                                                             None
# 2D053-X6C    L             FORD BRONCO SPORT 1ST GEN, FORD ESCAPE 4TH GEN, None
# 2D053-Z1C    P                                                             None
# 2D053-Z6C    N                                            FORD MAVERICK 1ST GEN
#              P                                      FORD MAVERICK 1ST GEN, None
# NaN          NaN                                                           None
