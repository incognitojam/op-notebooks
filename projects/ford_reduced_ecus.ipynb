# %%
from openpilot.tools.lib.comma_car_segments import get_comma_car_segments_database
from openpilot.selfdrive.car.ford.values import CAR

database = get_comma_car_segments_database()
platforms = [c.value for c in CAR] + ['mock']
segments = []

for platform in platforms:
  if platform not in database:
    print(f'Skipping platform: {platform}, no data available')
    continue

  platform_segments = database[platform]
  print(f'Got {len(platform_segments)} segments for platform {platform}')
  segments += platform_segments

print(f'Got {len(segments)} segments total')
# Out:
# kj/filesystem-disk-unix.c++:1703: warning: PWD environment variable doesn't match current directory; pwd = /mnt/c/Users/camer/AppData/Local/Programs/Microsoft VS Code
# Got 287 segments for platform FORD BRONCO SPORT 1ST GEN
# Got 137 segments for platform FORD ESCAPE 4TH GEN
# Got 1041 segments for platform FORD EXPLORER 6TH GEN
# Got 5 segments for platform FORD F-150 14TH GEN
# Got 56 segments for platform FORD FOCUS 4TH GEN
# Got 637 segments for platform FORD MAVERICK 1ST GEN
# Got 3 segments for platform FORD F-150 LIGHTNING 1ST GEN
# Got 3 segments for platform FORD MUSTANG MACH-E 1ST GEN
# Got 343 segments for platform mock
# Got 2512 segments total

# %%
from collections import defaultdict
from multiprocessing import Pool

from tqdm import tqdm

from openpilot.tools.lib.logreader import LogReader


def get_car_params(segment):
  lr = LogReader(segment)
  return lr.first('carParams')


def get_car_params_key(CP):
  fw_versions_dict = defaultdict(set)
  for fw in CP.carFw:
    if not fw.logging:
      sub_addr = fw.subAddress if fw.subAddress != 0 else None
      fw_versions_dict[(fw.address, sub_addr)].add(fw.fwVersion)
  fw_versions_dict = { addr: frozenset(fws) for addr, fws in fw_versions_dict.items() }
  return (CP.carVin, frozenset(fw_versions_dict.items()))


CAR_PARAMS_TO_CHECK = []
CAR_PARAMS_KEYS = set()

with Pool(processes=8) as p:
  with tqdm(total=len(segments)) as pbar:
    for CP in p.imap_unordered(get_car_params, segments):
      pbar.update()
      if CP is None:
        continue
      key = get_car_params_key(CP)
      if key in CAR_PARAMS_KEYS:
        continue
      CAR_PARAMS_KEYS.add(key)
      CAR_PARAMS_TO_CHECK.append(CP)

print(f'Got {len(CAR_PARAMS_TO_CHECK)} car params to check')
# Out:
#  76%|███████▌  | 1915/2512 [12:07<07:57,  1.25it/s]  Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectionResetError(104, 'Connection reset by peer')': /repos/62/e0/62e05c7a28179f905d6d62c2f0b5909b22298e6e56a619dbad1bd920893f66e1/73b1decbfa45dc426d4ece8b2db417754dfe5328f45af16d9735a4072c91a735?Expires=1706839707&Policy=_&Signature=kjnWS8YsAaLf8KptgRexOfFFloFNmZIGT418AtIOb5hCIO36OUiocdh0HzTKmAR55wV5R3b8TpzGNAZElsokbWR4rxHBgnNw2lsJqiQCbM%7EqjGWzZI4q3xqQopZUTYKf0B1rXGCT6Q9Zl0nVw0MkdqsOOFb2ih0KMVPzDN7UxYE7Cqc%7EuxAv2mWEwAcccdOY5UwPvwFJj02ESogYqi6E-C-bpFZ0-Ptlw0BWQIZ%7EexjYnylcnkXWoQCSvs1ed%7E1zGZX73DvKf86qrQlH9icl835okzF6ZdyKeCDJFeOI3UrIFisSF2IfSdB8s3JvXinAukWzTOWW3gMkyKmQG83fvQ__&Key-Pair-Id=KCD77M1F0VK2B
# 100%|██████████| 2512/2512 [17:03<00:00,  2.45it/s]
# Got 74 car params to check

# %%
import pandas as pd

from openpilot.selfdrive.car.fw_versions import build_fw_dict, match_fw_to_car

results = []
for CP in CAR_PARAMS_TO_CHECK:
  vin = CP.carVin
  real_fingerprint, real_fuzzy, source = CP.carFingerprint, CP.fuzzyFingerprint, CP.fingerprintSource
  car_fw = CP.carFw

  exact_match, determined_fingerprint = match_fw_to_car(car_fw, log=False)
  determined_fuzzy = not exact_match

  if len(determined_fingerprint) == 1:
    determined_fingerprint = determined_fingerprint.pop()
  elif len(determined_fingerprint) == 0:
    determined_fingerprint = 'mock'
  else:
    determined_fingerprint = 'multiple'

  fw_dict = build_fw_dict(CP.carFw)
  has_radar = (0x764, None) in fw_dict.keys()

  changed = (real_fingerprint != determined_fingerprint) or (real_fuzzy != determined_fuzzy)
  results.append((vin, has_radar,
                  real_fingerprint, real_fuzzy, determined_fingerprint, determined_fuzzy,
                  changed))

  if changed:
    print(f'{vin=}  {real_fingerprint=:<28}  source={source}  {determined_fingerprint=:<28} ({exact_match=})')
    if determined_fingerprint != real_fingerprint:
      for addr, fw in build_fw_dict(car_fw).items():
        print(f'  addr={hex(addr[0])} {fw=}')
    print()

df = pd.DataFrame(results, columns=['vin', 'has_radar',
                                    'real_fingerprint', 'real_fuzzy', 'determined_fingerprint', 'determined_fuzzy',
                                    'changed'])
print(df.to_string())
# Out:
# /tmp/ipykernel_232053/1701990771.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# vin='00000000000XXXXXX'  real_fingerprint=FORD F-150 14TH GEN           source=fixed  determined_fingerprint=mock                         (exact_match=True)
#
# vin='3FTTW8E3XPRXXXXXX'  real_fingerprint=FORD MAVERICK 1ST GEN         source=fw  determined_fingerprint=mock                         (exact_match=True)
#   addr=0x7e0 fw={b'PZ6A-14C204-JE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'}
#   addr=0x730 fw={b'NZ6C-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'}
#   addr=0x760 fw={b'PZ6C-2D053-ED\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'}
#   addr=0x706 fw={b'NZ6T-14F397-AC\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'}
#
# vin='3FTTW8E34PRXXXXXX'  real_fingerprint=FORD MAVERICK 1ST GEN         source=fw  determined_fingerprint=mock                         (exact_match=True)
#   addr=0x7e0 fw={b'PZ6A-14C204-JE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'}
#   addr=0x730 fw={b'NZ6C-14D003-AL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'}
#   addr=0x760 fw={b'PZ6C-2D053-ED\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'}
#
# vin='2C4RC3BG4PRXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA 2020       (exact_match=False)
#   addr=0x747 fw={b'68593395AA'}
#   addr=0x742 fw={b'68594994AB'}
#   addr=0x753 fw={b'68598670AC'}
#   addr=0x75a fw={b'68594337AB'}
#   addr=0x744 fw={b'68526663AB'}
#   addr=0x7e1 fw={b'68586233AD', b'11122233344', b'\xf1\x00\x00H\x00\x01'}
#   addr=0x7e0 fw={b'68700304AB ', b'           '}
#
# vin='2T3UWRFV5RWXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=TOYOTA RAV4 2023             (exact_match=True)
#   addr=0x7b0 fw={b'\x01F152642F8000\x00\x00\x00\x00'}
#   addr=0x700 fw={b'\x01896634AE1001\x00\x00\x00\x00'}
#   addr=0x7a1 fw={b'\x028965B0R11000\x00\x00\x00\x008965B0R12000\x00\x00\x00\x00'}
#   addr=0x750 fw={b'\x018821F0R03100\x00\x00\x00\x00'}
#   addr=0x750 fw={b'\x028646F0R11000\x00\x00\x00\x008646G0R04000\x00\x00\x00\x00'}
#   addr=0x7d0 fw={b'\xf1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x10\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'}
#   addr=0x730 fw={b'\x01F152642F8000\x00\x00\x00\x00'}
#
# vin='2C4RC1GG5HRXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA 2018       (exact_match=True)
#   addr=0x747 fw={b'68330876AA'}
#   addr=0x742 fw={b'68227902AG'}
#   addr=0x753 fw={b'68226356AI'}
#   addr=0x75a fw={b'68525338AA'}
#   addr=0x744 fw={b'68211617AG'}
#   addr=0x7e1 fw={b'68277374AB', b'\xf1\x00\x00B\x00\x01', b'11122233344'}
#   addr=0x7e0 fw={b'68352652AE ', b'           '}
#
# vin='00000000000XXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=HYUNDAI TUCSON HYBRID 4TH GEN (exact_match=True)
#   addr=0x7c4 fw={b'\xf1\x00NX4 FR_CMR AT USA LHD 1.00 1.00 99211-N9260 14Y'}
#   addr=0x7d0 fw={b'\xf1\x00NX4__               1.01 1.00 99110-N9100         '}
#
# vin='00000000000XXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=HYUNDAI IONIQ ELECTRIC 2020  (exact_match=True)
#   addr=0x7d4 fw={b'\xf1\x00AE  MDPS C 1.00 1.01 56310/G7310 4APEC101'}
#   addr=0x7c4 fw={b'\xf1\x00AEE MFC  AT EUR LHD 1.00 1.00 95740-G2700 201027'}
#   addr=0x7d0 fw={b'\xf1\x00AEev SCC F-CUP      1.00 1.00 99110-G7500         '}
#
# vin='00000000000XXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=KIA SORENTO PLUG-IN HYBRID 4TH GEN (exact_match=True)
#   addr=0x7d0 fw={b'\xf1\x00MQhe SCC FHCUP      1.00 1.06 99110-P4000         '}
#   addr=0x7c4 fw={b'\xf1\x00MQ4HMFC  AT USA LHD 1.00 1.10 99210-P2000 210406'}
#
# vin='2C4RC3PG6NRXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA 2020       (exact_match=True)
#   addr=0x747 fw={b'68577676AA'}
#   addr=0x742 fw={b'68529067AA'}
#   addr=0x753 fw={b'68540436AC'}
#   addr=0x75a fw={b'68524936AB'}
#   addr=0x744 fw={b'68526663AB'}
#   addr=0x7e1 fw={b'68527223AB', b'\xf1\x00\x00B\x01\x01', b'11122233344'}
#   addr=0x7e0 fw={b'           ', b'68526752AE '}
#
# vin='2T3UWRFV5RWXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=TOYOTA RAV4 2023             (exact_match=True)
#   addr=0x7b0 fw={b'\x01F152642F8000\x00\x00\x00\x00'}
#   addr=0x700 fw={b'\x01896634AE1001\x00\x00\x00\x00'}
#   addr=0x7a1 fw={b'\x028965B0R11000\x00\x00\x00\x008965B0R12000\x00\x00\x00\x00'}
#   addr=0x750 fw={b'\x018821F0R03100\x00\x00\x00\x00'}
#   addr=0x750 fw={b'\x028646F0R11000\x00\x00\x00\x008646G0R04000\x00\x00\x00\x00'}
#   addr=0x7d0 fw={b'\xf1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x10\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'}
#
# vin='1C4RJFCG6JCXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=JEEP GRAND CHEROKEE V6 2018  (exact_match=True)
#   addr=0x747 fw={b'68336276AB'}
#   addr=0x742 fw={b'68331687AC'}
#   addr=0x753 fw={b'04672627AB'}
#   addr=0x75a fw={b'68321644AC'}
#   addr=0x744 fw={b'68355363AB'}
#   addr=0x7e1 fw={b'68361911AE', b'\xf1\x00\x00E\x01\x01'}
#   addr=0x7e0 fw={b'           ', b'68325565AI '}
#
# vin='2C4RC1GG3KRXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA 2020       (exact_match=True)
#   addr=0x747 fw={b'68397394AA'}
#   addr=0x742 fw={b'68405327AC'}
#   addr=0x753 fw={b'04672758AA'}
#   addr=0x75a fw={b'68416742AA'}
#   addr=0x744 fw={b'68405565AB'}
#   addr=0x7e1 fw={b'\xf1\x00\x00B\x01\x01', b'11122233344', b'68414271AC'}
#   addr=0x7e0 fw={b'           ', b'68413871AD '}
#
# vin='2C4RC1N75NRXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA HYBRID 2019 (exact_match=True)
#   addr=0x742 fw={b'68529064AB'}
#   addr=0x753 fw={b'68540436AC'}
#   addr=0x75a fw={b'68525339AA'}
#   addr=0x744 fw={b'68526665AB'}
#   addr=0x7e0 fw={b'           ', b'68526772AD '}
#
# vin='2C4RC1N7XMRXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA HYBRID 2019 (exact_match=True)
#   addr=0x742 fw={b'68434960AE'}
#   addr=0x753 fw={b'68540436AA'}
#   addr=0x75a fw={b'68460392AA'}
#   addr=0x744 fw={b'68480710AC'}
#   addr=0x7e0 fw={b'           ', b'68499122AF '}
#
# vin='00000000000XXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=TOYOTA CAMRY 2021            (exact_match=True)
#   addr=0x7b0 fw={b'F152633D00\x00\x00\x00\x00\x00\x00'}
#   addr=0x7a1 fw={b'8965B33630\x00\x00\x00\x00\x00\x00'}
#   addr=0x700 fw={b'\x018966306Q6000\x00\x00\x00\x00'}
#   addr=0x7d2 fw={b'\x02899830621000\x00\x00\x00\x00899853313000\x00\x00\x00\x00'}
#   addr=0x750 fw={b'\x018821F6201400\x00\x00\x00\x00'}
#   addr=0x750 fw={b'\x028646F3305300\x00\x00\x00\x008646G5301200\x00\x00\x00\x00'}
#
# vin='2C4RC1S73MRXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA HYBRID 2019 (exact_match=True)
#   addr=0x742 fw={b'68434960AE'}
#   addr=0x753 fw={b'68540436AA'}
#   addr=0x75a fw={b'68460392AA'}
#   addr=0x744 fw={b'68480710AC'}
#   addr=0x7e0 fw={b'           ', b'68499122AD '}
#
# vin='2C4RC3BG6NRXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA 2020       (exact_match=True)
#   addr=0x747 fw={b'68577676AA'}
#   addr=0x753 fw={b'68540436AC'}
#   addr=0x742 fw={b'68529067AA'}
#   addr=0x75a fw={b'68524936AB'}
#   addr=0x744 fw={b'68526663AB'}
#   addr=0x7e1 fw={b'68527223AB', b'\xf1\x00\x00B\x01\x01', b'11122233344'}
#   addr=0x7e0 fw={b'           ', b'68526752AE '}
#
# vin='2C4RC1S79MRXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA HYBRID 2019 (exact_match=True)
#   addr=0x753 fw={b'68540436AB'}
#   addr=0x742 fw={b'68434960AE'}
#   addr=0x75a fw={b'68460392AA'}
#   addr=0x744 fw={b'68480710AC'}
#   addr=0x7e0 fw={b'           ', b'68499122AF '}
#
# vin='2C4RC1BG1MRXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA 2020       (exact_match=False)
#   addr=0x747 fw={b'68453575AF'}
#   addr=0x742 fw={b'68436250AE'}
#   addr=0x753 fw={b'68540436AA'}
#   addr=0x75a fw={b'68460393AA'}
#   addr=0x744 fw={b'68480708AC'}
#   addr=0x7e1 fw={b'\xf1\x00\x00B\x01\x01', b'11122233344', b'68501050AD'}
#   addr=0x7e0 fw={b'           ', b'68496650AH '}
#
# vin='00000000000XXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA 2020       (exact_match=True)
#   addr=0x747 fw={b'68433480AB'}
#   addr=0x742 fw={b'68436233AB'}
#   addr=0x753 fw={b'04672758AB'}
#   addr=0x75a fw={b'68460393AA'}
#   addr=0x744 fw={b'68405565AC'}
#   addr=0x7e1 fw={b'68443154AB'}
#   addr=0x7e0 fw={b'68443123AC '}
#
# vin='2C4RC1N71KRXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA HYBRID 2019 (exact_match=True)
#   addr=0x742 fw={b'68405292AC'}
#   addr=0x753 fw={b'04672758AB'}
#   addr=0x75a fw={b'68416741AA'}
#   addr=0x744 fw={b'68405567AB'}
#   addr=0x7e0 fw={b'           ', b'68416680AF '}
#
# vin='2C4RC1GG5HRXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=CHRYSLER PACIFICA 2018       (exact_match=True)
#   addr=0x742 fw={b'68227902AH'}
#   addr=0x747 fw={b'68330876AA'}
#   addr=0x753 fw={b'68226356AI'}
#   addr=0x75a fw={b'68288891AE'}
#   addr=0x744 fw={b'68211617AG'}
#   addr=0x7e1 fw={b'\xf1\x00\x00B\x00\x01', b'***********', b'68277372AN'}
#   addr=0x7e0 fw={b'           ', b'68267020AJ '}
#
# vin='1C4RJFBG1HCXXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=JEEP GRAND CHEROKEE V6 2018  (exact_match=True)
#   addr=0x747 fw={b'68306178AD'}
#   addr=0x742 fw={b'68302246AC'}
#   addr=0x753 fw={b'68332015AB'}
#   addr=0x75a fw={b'68321644AB'}
#   addr=0x744 fw={b'68316742AB'}
#   addr=0x7e1 fw={b'\xf1\x00\x00@\x18\x01', b'68311218AC'}
#   addr=0x7e0 fw={b'           ', b'68284455AI '}
#
# vin='00000000000XXXXXX'  real_fingerprint=mock                          source=can  determined_fingerprint=TOYOTA RAV4 2023             (exact_match=True)
#   addr=0x7b0 fw={b'\x01F152642F8000\x00\x00\x00\x00'}
#   addr=0x700 fw={b'\x01896634AE1001\x00\x00\x00\x00'}
#   addr=0x7a1 fw={b'\x028965B0R11000\x00\x00\x00\x008965B0R12000\x00\x00\x00\x00'}
#   addr=0x750 fw={b'\x018821F0R03100\x00\x00\x00\x00'}
#   addr=0x750 fw={b'\x028646F0R11000\x00\x00\x00\x008646G0R04000\x00\x00\x00\x00'}
#   addr=0x7d0 fw={b'\xf1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x10\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'}
#
#                   vin  has_radar              real_fingerprint  real_fuzzy              determined_fingerprint  determined_fuzzy  changed
# 0   3FMCR9B69NRXXXXXX       True     FORD BRONCO SPORT 1ST GEN       False           FORD BRONCO SPORT 1ST GEN             False    False
# 1   3FMCR9B69NRXXXXXX       True     FORD BRONCO SPORT 1ST GEN       False           FORD BRONCO SPORT 1ST GEN             False    False
# 2   00000000000XXXXXX       True           FORD ESCAPE 4TH GEN       False                 FORD ESCAPE 4TH GEN             False    False
# 3   1FMCU9J94MUXXXXXX       True           FORD ESCAPE 4TH GEN       False                 FORD ESCAPE 4TH GEN             False    False
# 4   1FM5K7LC0MGXXXXXX       True         FORD EXPLORER 6TH GEN       False               FORD EXPLORER 6TH GEN             False    False
# 5   1FM5K8GC7LGXXXXXX       True         FORD EXPLORER 6TH GEN       False               FORD EXPLORER 6TH GEN             False    False
# 6   5LM5J7XC9LGXXXXXX       True         FORD EXPLORER 6TH GEN       False               FORD EXPLORER 6TH GEN             False    False
# 7   1FM5K8GC7NGXXXXXX       True         FORD EXPLORER 6TH GEN       False               FORD EXPLORER 6TH GEN             False    False
# 8   5LM5J7XC8MGXXXXXX       True         FORD EXPLORER 6TH GEN       False               FORD EXPLORER 6TH GEN             False    False
# 9   1FM5K8HC7MGXXXXXX       True         FORD EXPLORER 6TH GEN       False               FORD EXPLORER 6TH GEN             False    False
# 10  5LM5J7XC1LGXXXXXX       True         FORD EXPLORER 6TH GEN       False               FORD EXPLORER 6TH GEN             False    False
# 11  1FM5K8HC7MGXXXXXX       True         FORD EXPLORER 6TH GEN       False               FORD EXPLORER 6TH GEN             False    False
# 12  1FM5K8HC2LGXXXXXX       True         FORD EXPLORER 6TH GEN       False               FORD EXPLORER 6TH GEN             False    False
# 13  1FMSK8DHXNGXXXXXX       True         FORD EXPLORER 6TH GEN       False               FORD EXPLORER 6TH GEN             False    False
# 14  1FMSK8DH0NGXXXXXX       True         FORD EXPLORER 6TH GEN       False               FORD EXPLORER 6TH GEN             False    False
# 15  00000000000XXXXXX      False           FORD F-150 14TH GEN       False                                mock             False     True
# 16  WF0NXXGCHNJXXXXXX       True            FORD FOCUS 4TH GEN       False                  FORD FOCUS 4TH GEN             False    False
# 17  3FTTW8E31PRXXXXXX       True         FORD MAVERICK 1ST GEN       False               FORD MAVERICK 1ST GEN             False    False
# 18  3FTTW8E99NRXXXXXX       True         FORD MAVERICK 1ST GEN       False               FORD MAVERICK 1ST GEN             False    False
# 19  3FTTW8E33NRXXXXXX       True         FORD MAVERICK 1ST GEN       False               FORD MAVERICK 1ST GEN             False    False
# 20  3FTTW8E3XPRXXXXXX      False         FORD MAVERICK 1ST GEN        True                                mock             False     True
# 21  3FTTW8F98NRXXXXXX       True         FORD MAVERICK 1ST GEN       False               FORD MAVERICK 1ST GEN             False    False
# 22  3FTTW8F97NRXXXXXX       True         FORD MAVERICK 1ST GEN       False               FORD MAVERICK 1ST GEN             False    False
# 23  3FTTW8E34PRXXXXXX       True         FORD MAVERICK 1ST GEN       False               FORD MAVERICK 1ST GEN             False    False
# 24  00000000000XXXXXX       True         FORD MAVERICK 1ST GEN       False               FORD MAVERICK 1ST GEN             False    False
# 25  3FTTW8E33PRXXXXXX       True         FORD MAVERICK 1ST GEN       False               FORD MAVERICK 1ST GEN             False    False
# 26  3FTTW8E34PRXXXXXX      False         FORD MAVERICK 1ST GEN        True                                mock             False     True
# 27  3FTTW8E31PRXXXXXX       True         FORD MAVERICK 1ST GEN       False               FORD MAVERICK 1ST GEN             False    False
# 28  3FTTW8E36PRXXXXXX       True         FORD MAVERICK 1ST GEN       False               FORD MAVERICK 1ST GEN             False    False
# 29  1FTVW1EL4NWXXXXXX       True  FORD F-150 LIGHTNING 1ST GEN       False        FORD F-150 LIGHTNING 1ST GEN             False    False
# 30  3FMTK3SU0MMXXXXXX       True   FORD MUSTANG MACH-E 1ST GEN       False         FORD MUSTANG MACH-E 1ST GEN             False    False
# 31  2C4RC3BG4PRXXXXXX      False                          mock       False              CHRYSLER PACIFICA 2020              True     True
# 32  KMTF34JA5KUXXXXXX      False                          mock       False                                mock             False    False
# 33  2T3UWRFV5RWXXXXXX      False                          mock       False                    TOYOTA RAV4 2023             False     True
# 34  2C4RC1GG5HRXXXXXX      False                          mock       False              CHRYSLER PACIFICA 2018             False     True
# 35  1C4SDJCT0LCXXXXXX      False                          mock       False                                mock             False    False
# 36  00000000000XXXXXX      False                          mock       False       HYUNDAI TUCSON HYBRID 4TH GEN             False     True
# 37  00000000000XXXXXX      False                          mock       False                                mock             False    False
# 38  00000000000XXXXXX      False                          mock       False                                mock             False    False
# 39  00000000000XXXXXX      False                          mock       False         HYUNDAI IONIQ ELECTRIC 2020             False     True
# 40  JM3KFBCMXN1XXXXXX       True                          mock       False                                mock             False    False
# 41  00000000000XXXXXX      False                          mock       False  KIA SORENTO PLUG-IN HYBRID 4TH GEN             False     True
# 42  2C4RC3PG6NRXXXXXX      False                          mock       False              CHRYSLER PACIFICA 2020             False     True
# 43  2T3UWRFV5RWXXXXXX      False                          mock       False                    TOYOTA RAV4 2023             False     True
# 44  1C4RJFCG6JCXXXXXX      False                          mock       False         JEEP GRAND CHEROKEE V6 2018             False     True
# 45  00000000000XXXXXX      False                          mock       False                                mock             False    False
# 46  JM3KFBEM0N0XXXXXX       True                          mock       False                                mock             False    False
# 47  2C4RC1GG3KRXXXXXX      False                          mock       False              CHRYSLER PACIFICA 2020             False     True
# 48  00000000000XXXXXX      False                          mock       False                                mock             False    False
# 49  2C4RC1N75NRXXXXXX      False                          mock       False       CHRYSLER PACIFICA HYBRID 2019             False     True
# 50  2C4RC1N7XMRXXXXXX      False                          mock       False       CHRYSLER PACIFICA HYBRID 2019             False     True
# 51  JM3KFBEM2P0XXXXXX       True                          mock       False                                mock             False    False
# 52  00000000000XXXXXX      False                          mock       False                                mock             False    False
# 53  00000000000XXXXXX      False                          mock       False                   TOYOTA CAMRY 2021             False     True
# 54  1G1RD6S55JUXXXXXX      False                          mock       False                                mock             False    False
# 55  2C4RC1S73MRXXXXXX      False                          mock       False       CHRYSLER PACIFICA HYBRID 2019             False     True
# 56  KMHC751DGNUXXXXXX      False                          mock       False                                mock             False    False
# 57  2C4RC3BG6NRXXXXXX      False                          mock       False              CHRYSLER PACIFICA 2020             False     True
# 58  2C4RC1S79MRXXXXXX      False                          mock       False       CHRYSLER PACIFICA HYBRID 2019             False     True
# 59  00000000000XXXXXX      False                          mock       False                                mock             False    False
# 60  2C4RC1BG1MRXXXXXX      False                          mock       False              CHRYSLER PACIFICA 2020              True     True
# 61  1C4RJFJMXJCXXXXXX      False                          mock       False                                mock             False    False
# 62  00000000000XXXXXX      False                          mock       False                                mock             False    False
# 63  00000000000XXXXXX      False                          mock       False              CHRYSLER PACIFICA 2020             False     True
# 64  00000000000XXXXXX      False                          mock       False                                mock             False    False
# 65  2C4RC1N71KRXXXXXX      False                          mock       False       CHRYSLER PACIFICA HYBRID 2019             False     True
# 66  2C4RC1GG5HRXXXXXX      False                          mock       False              CHRYSLER PACIFICA 2018             False     True
# 67  00000000000XXXXXX      False                          mock       False                                mock             False    False
# 68  KMHR381ADLUXXXXXX      False                          mock       False                                mock             False    False
# 69  1C4RJFBG1HCXXXXXX      False                          mock       False         JEEP GRAND CHEROKEE V6 2018             False     True
# 70  00000000000XXXXXX      False                          mock       False                    TOYOTA RAV4 2023             False     True
# 71  00000000000XXXXXX      False                          mock       False                                mock             False    False
# 72  JM3KFBBM2P0XXXXXX       True                          mock       False                                mock             False    False
# 73  3GKALVEV2LLXXXXXX      False                          mock       False                                mock             False    False
