# %%
# %load_ext autoreload
# %autoreload 2

# %%
from vins import load_vins

vins = load_vins()
# vins = ['WF0NXXGCHNJR69712']
# Out:
# Loaded 1263 VINs (filter_comment=None, include_openpilot=False, skipped=80)
# Loaded AsBuilt data for 1263 VINs

# %%
import random

import pandas as pd

from asbuilt import AsBuiltData
from settings import VEHICLE_SETTINGS

pd.set_option('display.max_columns', None)

rows = []
for vin in ('WF0NXXGCHNJR69712', *random.sample(vins, 10)):
  abd = AsBuiltData.from_vin(vin)
  rows.append([vin, *map(lambda s: abd.get_setting_value(s), VEHICLE_SETTINGS)])

columns = [('', 'VIN'), *map(lambda s: (s.ecu.name, s.comment), VEHICLE_SETTINGS)]

df = pd.DataFrame(rows, columns=pd.MultiIndex.from_tuples(columns))
df
# Out:
#                       ImageProcessingModuleA                          \
#                   VIN                Vehicle   Enable ACC Enable TJA
# 0   WF0NXXGCHNJR69712           C519 (Focus)          Off        Off
# 1   3FMTK3SS1NMA58514         Unknown (0x50)  RadarFusion  Undefined
# 2   1FMEE5BP1PLC07175         Unknown (0x4B)          Off        Off
# 3   1FMSK8DHXLGA77872        U625 (Explorer)  RadarFusion         On
# 4   1FM5K8FW9MNA06541        U625 (Explorer)  RadarFusion         On
# 5   3FADP4EJXKM109612                Missing      Missing    Missing
# 6   1FMSK8FH7LGC10911        U625 (Explorer)  RadarFusion         On
# 7   2FMPK3K95LBB20798           CD539 (Edge)  RadarFusion         On
# 8   5LM5J7WC5LGL21128         U611 (Aviator)  RadarFusion         On
# 9   1FMCU9G64LUA83697    CX482 (Escape/Kuga)  RadarFusion        Off
# 10  1FMCU0H62LUB07697    CX482 (Escape/Kuga)  RadarFusion        Off
# 11  2FMPK3K91MBA39041           CD539 (Edge)  RadarFusion         On
# 12  1FMJK2AT6MEA71940             Expedition  RadarFusion        Off
# 13  1FADP3M2XHL223494                Missing      Missing    Missing
# 14  3FMCR9D95PRE06734         Unknown (0x3C)  RadarFusion         On
# 15  1FMCU9H98MUA10312    CX482 (Escape/Kuga)  RadarFusion         On
# 16  2FMPK4K9XPBA14665           CD539 (Edge)          Off        Off
# 17  1FMDE5BH4NLB89630         Unknown (0x4B)          Off        Off
# 18  1FMSK7BH5LGB80386        U625 (Explorer)          Off        Off
# 19  5LMCJ2C92LUL06476        CX483 (Corsair)  RadarFusion         On
# 20  3FMTK4SE8PMA57654         Unknown (0x50)  RadarFusion  Undefined
#
#    AntiLockBrakeSystem                                      \
#      Wheel base preset   Steering Gear Cruise Control Mode
# 0             Reserved       EPAS 21:1              Normal
# 1             Reserved       EPAS 17:1      Unknown (0x01)
# 2                141in       EPAS 21:1      Unknown (0x01)
# 3             Reserved       EPAS 17:1      Unknown (0x01)
# 4             Reserved        Reserved      Unknown (0x01)
# 5                141in  Unknown (0x03)      Unknown (0x00)
# 6             Reserved       EPAS 17:1      Unknown (0x01)
# 7                141in       EPAS 17:1            Adaptive
# 8             Reserved       EPAS 17:1      Unknown (0x01)
# 9             Reserved       EPAS 17:1              Normal
# 10            Reserved       EPAS 17:1      Unknown (0x01)
# 11               141in       EPAS 17:1            Adaptive
# 12               141in        Reserved      Unknown (0x00)
# 13             Missing         Missing             Missing
# 14            Reserved       EPAS 17:1              Normal
# 15            Reserved       EPAS 17:1              Normal
# 16               122in       EPAS 17:1            Adaptive
# 17               122in  Unknown (0x03)            Adaptive
# 18            Reserved       EPAS 17:1      Unknown (0x01)
# 19            Reserved       EPAS 17:1      Unknown (0x01)
# 20            Reserved       EPAS 17:1      Unknown (0x01)
#
#                                             AccessoryProtocolInterfaceModule  \
#    Collision Mitigation by Braking (CMbB) Steering Wheel Angle Sensor (SWAS)
# 0                                 Without                           Absolute
# 1                                 Without                           Absolute
# 2                                    With                           Absolute
# 3                                 Without                           Absolute
# 4                                 Without                           Absolute
# 5                                 Missing                           Relative
# 6                                 Without                           Absolute
# 7                                    With                           Absolute
# 8                                 Without                           Absolute
# 9                                 Without                           Absolute
# 10                                Without                           Absolute
# 11                                   With                           Absolute
# 12                                   With                           Absolute
# 13                                Missing                           Absolute
# 14                                Without                           Absolute
# 15                                Without                           Absolute
# 16                                   With                           Absolute
# 17                                   With                           Absolute
# 18                                Without                           Absolute
# 19                                Without                           Absolute
# 20                                Without                           Absolute
#
#                                                                   \
#    Brand Identification Hybrid (HEV) Transmission Type Fuel Type
# 0                  Ford           No            Manual    Diesel
# 1                  Ford          Yes         Automatic  Gasoline
# 2                  Ford           No         Automatic  Gasoline
# 3                  Ford           No         Automatic  Gasoline
# 4                  Ford          Yes         Automatic  Gasoline
# 5              Reserved           No         Automatic  Gasoline
# 6                  Ford           No         Automatic  Gasoline
# 7                  Ford           No         Automatic  Gasoline
# 8               Lincoln           No         Automatic  Gasoline
# 9                  Ford           No         Automatic  Gasoline
# 10                 Ford           No         Automatic  Gasoline
# 11                 Ford           No         Automatic  Gasoline
# 12                 Ford           No         Automatic  Gasoline
# 13                 Ford           No         Automatic  Gasoline
# 14                 Ford           No         Automatic  Gasoline
# 15                 Ford           No         Automatic  Gasoline
# 16                 Ford           No         Automatic  Gasoline
# 17                 Ford           No         Automatic  Gasoline
# 18                 Ford           No         Automatic  Gasoline
# 19              Lincoln           No         Automatic  Gasoline
# 20                 Ford          Yes         Automatic  Gasoline
#
#                                                                        \
#    Plug-in Hybrid (PHEV) Common Global Electrical Architecture (CGEA)
# 0                     No                                     CGEA 1.3
# 1                     No                                     CGEA 1.3
# 2                     No                            CGEA 1.2 or C1MCA
# 3                     No                                     CGEA 1.3
# 4                     No                                     CGEA 1.3
# 5                     No                                      Missing
# 6                     No                                     CGEA 1.3
# 7                     No                                     CGEA 1.3
# 8                     No                                     CGEA 1.3
# 9                     No                                     CGEA 1.3
# 10                    No                                     CGEA 1.3
# 11                    No                            CGEA 1.2 or C1MCA
# 12                    No                                     CGEA 1.3
# 13                    No                            CGEA 1.2 or C1MCA
# 14                    No                                     CGEA 1.3
# 15                    No                                     CGEA 1.3
# 16                    No                            CGEA 1.2 or C1MCA
# 17                    No                            CGEA 1.2 or C1MCA
# 18                    No                                     CGEA 1.3
# 19                    No                                     CGEA 1.3
# 20                    No                                     CGEA 1.3
#
#                                                                                \
#    Heated Windshield Country Code (First Letter) Country Code (Second Letter)
# 0                Yes                           U                            K
# 1                 No              Unknown (0x04)               Unknown (0x02)
# 2                 No              Unknown (0x04)               Unknown (0x12)
# 3                 No                           U                            S
# 4                 No                           U                            S
# 5            Missing              Unknown (0x04)                            U
# 6                 No                           C                            A
# 7                 No                           U                            S
# 8                 No                           U                            S
# 9                 No                           U                            S
# 10                No                           U                            S
# 11                No              Unknown (0x04)               Unknown (0x02)
# 12                No                           U                            S
# 13                No                           U                            S
# 14                No                           U                            S
# 15                No                           U                            S
# 16                No              Unknown (0x04)               Unknown (0x02)
# 17                No              Unknown (0x04)               Unknown (0x12)
# 18                No                           U                            S
# 19                No                           U                            S
# 20                No              Unknown (0x04)               Unknown (0x02)
#
#                                                                     \
#            Vehicle Style           GPS Antenna Location/Mount Type
# 0                  Focus                   Roof Mount (UK Default)
# 1         Unknown (0x8B)                            Unknown (0x05)
# 2                 Fiesta                            Unknown (0x05)
# 3                SUV/CUV                   Roof Mount (UK Default)
# 4                SUV/CUV                   Roof Mount (UK Default)
# 5                   None                   Roof Mount (UK Default)
# 6                SUV/CUV                   Roof Mount (UK Default)
# 7                SUV/CUV                   Roof Mount (UK Default)
# 8   Large Commercial Van                   Roof Mount (UK Default)
# 9                SUV/CUV                   Roof Mount (UK Default)
# 10               SUV/CUV                   Roof Mount (UK Default)
# 11        Unknown (0x88)                            Unknown (0x05)
# 12               SUV/CUV                   Roof Mount (UK Default)
# 13             Hatchback                   Roof Mount (UK Default)
# 14               SUV/CUV                   Roof Mount (UK Default)
# 15               SUV/CUV                   Roof Mount (UK Default)
# 16        Unknown (0x8A)                            Unknown (0x05)
# 17                Fiesta  Windshield Mount (Non-heated Windscreen)
# 18               SUV/CUV                   Roof Mount (UK Default)
# 19               SUV/CUV                   Roof Mount (UK Default)
# 20        Unknown (0x8B)                            Unknown (0x05)
#
#                                                                                \
#               Electric Vehicle Drivetrain Type Bluetooth Vehicle Nameplate ID
# 0           Non-HEV, BEV, PHEV             FWD                     Ford Focus
# 1               Unknown (0x53)             AWD                           SYNC
# 2               Unknown (0x53)  Unknown (0x0C)                           SYNC
# 3              U625 (Explorer)             AWD                  Ford Explorer
# 4              U625 (Explorer)             AWD                  Ford Explorer
# 5           Non-HEV, BEV, PHEV             FWD                        Missing
# 6              U625 (Explorer)             AWD                  Ford Explorer
# 7           Non-HEV, BEV, PHEV             FWD                      Ford Edge
# 8               U611 (Aviator)             RWD                Lincoln Aviator
# 9          CX482 (Escape/Kuga)             AWD                    Ford Escape
# 10         CX482 (Escape/Kuga)             FWD                    Ford Escape
# 11              Unknown (0x53)      Dually 2WD                           SYNC
# 12          Non-HEV, BEV, PHEV             4WD                Ford Expedition
# 13  C346/C519 (Focus Electric)             FWD                     Ford Focus
# 14          Non-HEV, BEV, PHEV             AWD                           SYNC
# 15         CX482 (Escape/Kuga)             AWD                    Ford Escape
# 16              Unknown (0x53)      Dually 2WD                           SYNC
# 17              Unknown (0x41)  Unknown (0x0C)                           SYNC
# 18             U625 (Explorer)             RWD                  Ford Explorer
# 19             CX483 (Corsair)             FWD                Lincoln Corsair
# 20              Unknown (0x53)             AWD                           SYNC
#
#
#                                                               \
#     ACC Menu Forward Collision Warning  FCW Menu FCW Braking
# 0    Enabled                      None   Enabled     Enabled
# 1    Enabled                       FCW  Disabled     Enabled
# 2   Disabled                       FCW   Enabled     Enabled
# 3    Enabled                       FCW  Disabled     Enabled
# 4    Enabled                       FCW  Disabled     Enabled
# 5    Missing                   Missing   Missing     Missing
# 6    Enabled                       FCW  Disabled     Enabled
# 7   Disabled                      None  Disabled    Disabled
# 8    Enabled                       FCW  Disabled     Enabled
# 9    Enabled                       FCW  Disabled     Enabled
# 10   Enabled                       FCW  Disabled     Enabled
# 11  Disabled                      None  Disabled    Disabled
# 12  Disabled                      None  Disabled    Disabled
# 13   Missing                   Missing   Missing     Missing
# 14   Enabled                       FCW  Disabled     Enabled
# 15   Enabled                       FCW  Disabled     Enabled
# 16  Disabled                      None  Disabled    Disabled
# 17  Disabled                       FCW   Enabled     Enabled
# 18  Disabled                       FCW  Disabled     Enabled
# 19   Enabled                       FCW  Disabled     Enabled
# 20   Enabled                       FCW  Disabled     Enabled
#
#                                                            \
#    Evasive Steering Assist (ESA) Lane Change Assist (LCA)
# 0                        Enabled                  Enabled
# 1                        Enabled                  Enabled
# 2                       Disabled                  Enabled
# 3                        Enabled                  Enabled
# 4                        Enabled                  Enabled
# 5                        Missing                  Missing
# 6                        Enabled                  Enabled
# 7                       Disabled                 Disabled
# 8                        Enabled                  Enabled
# 9                        Enabled                  Enabled
# 10                       Enabled                  Enabled
# 11                      Disabled                 Disabled
# 12                      Disabled                 Disabled
# 13                       Missing                  Missing
# 14                       Enabled                  Enabled
# 15                       Enabled                  Enabled
# 16                      Disabled                 Disabled
# 17                      Disabled                  Enabled
# 18                      Disabled                  Enabled
# 19                       Enabled                  Enabled
# 20                       Enabled                  Enabled
#
#                                                                \
#    Lane Keeping Sensitivity  ACC Mode    Lane Assist NCAP Aid
# 0                   Enabled   Enabled  Off, Reduced, Enhanced
# 1                  Disabled   Enabled                Disabled
# 2                  Disabled  Disabled                Disabled
# 3                  Disabled   Enabled                Disabled
# 4                  Disabled   Enabled                Disabled
# 5                   Missing   Missing                 Missing
# 6                  Disabled   Enabled                Disabled
# 7                  Disabled  Disabled                Disabled
# 8                  Disabled   Enabled                Disabled
# 9                  Disabled   Enabled                Disabled
# 10                 Disabled   Enabled                Disabled
# 11                 Disabled  Disabled                Disabled
# 12                 Disabled  Disabled                Disabled
# 13                  Missing   Missing                 Missing
# 14                 Disabled   Enabled                Disabled
# 15                 Disabled   Enabled                Disabled
# 16                 Disabled  Disabled                Disabled
# 17                 Disabled  Disabled                Disabled
# 18                 Disabled  Disabled                Disabled
# 19                 Disabled   Enabled                Disabled
# 20                 Disabled   Enabled                Disabled
#
#
#    Lane Assist NCAP Alert
# 0       High, Normal, Low
# 1                Disabled
# 2                Disabled
# 3                Disabled
# 4                Disabled
# 5                 Missing
# 6                Disabled
# 7                Disabled
# 8                Disabled
# 9                Disabled
# 10               Disabled
# 11               Disabled
# 12               Disabled
# 13                Missing
# 14               Disabled
# 15               Disabled
# 16               Disabled
# 17               Disabled
# 18               Disabled
# 19               Disabled
# 20               Disabled
